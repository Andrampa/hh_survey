# %%
import pandas as pd
import xlrd, re
import arcpy
from pandas import ExcelWriter
from datetime import datetime
import os

# %%
startTime = datetime.now()
now = datetime.now().strftime('%Y%m%d%H%M%S')
temp_path = r'C:\temp\data_processing_exports'
#questionnaire_file = r'C:\git\hh_survey\household_questionnaire_geopoll_202105.xlsx' #the questionnaire file that we use for creating the table
questionnaire_file = r'C:\git\hh_survey\household_questionnaire_geopoll_EN_template_20210720_ISO3.xlsx'
coded_values_file = os.path.join(temp_path, "coded_values_%s.xlsx" % now) #intermediary output file with all categories and codes extracted from the questionnaire
writer = pd.ExcelWriter(coded_values_file, engine='xlsxwriter')
field_names_list = []
max_counter = 3000 #for testing purposes, we may need to limit the execution only to some items

# %%
def importallsheets(in_excel, out_gdb):
    ###this function import all sheets of an xlsx file into separate tables inside a GDB (with same name)
    print("max_counter: %s" % max_counter)
    counter = 0
    workbook = xlrd.open_workbook(in_excel)
    sheets = [sheet.name for sheet in workbook.sheets()]

    print('{} sheets found: {}'.format(len(sheets), ','.join(sheets)))
    for sheet in sheets:
        counter +=1
        if counter <= max_counter:
            # The out_table is based on the input excel file name
            # a underscore (_) separator followed by the sheet name
            out_table = os.path.join(
                out_gdb,
                arcpy.ValidateTableName(
                    "{0}".format(sheet),
                    out_gdb))

            print('Converting {} to {}'.format(sheet, out_table))

            # Perform the conversion
            arcpy.ExcelToTable_conversion(in_excel, out_table, sheet)
            

def make_attribute_dict(fc, code_field, value_field):
    #this function creates a dictionary based on a GDB table
    attdict = {}
    with arcpy.da.SearchCursor(fc, [code_field, value_field]) as cursor:
        for row in cursor:
            attdict[row[0]] = row[1]
    return attdict

def fix_category_formatting(category):
    #this function improves and standardizes the formatting of the categories' descriptions
    category = re.sub('--[^--]+--', '', category)
    return category.replace("[","(").replace("]",")").replace("(specify)","").replace("/ ",", ").capitalize().replace("adps","ADPs").replace("idp","IDP").replace("covid","COVID").replace(" , ",", ").replace("staplec","staple") 

def insert_element_in_list_after_element(old_list, new_item,after_item): 
    new_list = []
    found = False
    for each in old_list:
        new_list.append(each)
        if each == after_item:
            found = True
            new_list.append(new_item)
    if found == False:
        print('WARNING ------------------------------------ELEMENT %s NOT FOUND------ITEM %s NOT ADDED !!' % (after_item, new_item))
    return new_list

# %%
language_domains = [[1,'English'],[2,'French'],[3,'Spanish'],[4,'Arabic'],[5,'Portuguese'],[6,'Dari'],[7,'Pashto'],[8,'Sangho'],[9,'Shona'],[10,'Ndebele'],[11,'Swahili'],[12,'Tshiluba'],[13,'Lingala'],[14,'Kikongo'],[15,'Fula'],[16,'Songhai'],[17,'Dogon'],[18,'Hausa'],[19,'Zarma'],[20,'Kanouri'],[21,'Somali'],[22,'Xichangana'],[23,'Xichope'],[24,'Ndau'],[25,'Xicena'],[26,'Machuabo'],[27,'Chichewa'],[28,'Lomwe'],[29,'Macua'],[30,'Makonde']]

# %%
##this section of the script reads the survey excel file and creates an excel file with multiple sheets:
### each sheet contains the coded value and description for a "Single choice" or "Open Ended-Select All That Apply" question.
###moreover, it creates and populates several lists that will be used later for defining each field of the final table names, types and domains

print("Opening questionnaire DF")
quest_df = pd.read_excel(open(questionnaire_file, 'rb'), sheet_name='survey',skiprows=2)
#create a list of all possible numbering
numbering = ["%s)" % n for n in range(1,200)] ## 1), 2), ... 200)
# initialize list of lists that will store the results
dict_derived_fieldnames = {} #this dict will group all derived fields in case of "Select All That Apply" type of questions
field_names_list = [] ##this list will contain all fields of the final table
text_type_fields = [] ##this list will contain all fields of the final table with TEXT type
range_type_fields = [] ##this list will contain all fields of the final table storing RANGE data  (will be LONG type)
double_type_fields = [] ##this list will contain all fields of the final table storing DOUBLE data  
##iterate the following for each row (so each question of the questionnaire)
all_derived_fieldnames = []
all_answers_with_other_option = [] ##this list will contain all "Other: specify" fields in Select all that apply type of questions
single_choice_questions_with_other_categories = [] ##this list will contain all "Other: specify" fields in single choice type of questions
quest_df = quest_df[quest_df['Suggested Qname'].notna()]
yes_no_reclassified_list = []
for index, row in quest_df.iterrows():
    try:
        first_derived_fieldname = "" #the name of the first derived field will be the main of the domain table
        derived_fieldnames = []
        codes_and_labels = []
        categories = str(row['English']).replace("\t","")
        question_name = row['Suggested Qname'].strip()  #Q Name
        
        #renaming some fields
        if question_name == 'language2':
            question_name = 'language'

        
        question_type = row['Q Type']
        programming_instructions = row['Programming Instructions'] #this field contains coded values for crop_main
        print("\n\n----%s----" % question_name)
        #only for questions with pre-defined categories need domains
        if question_type in ("StartRecording","Single Choice","Open Ended-Single Choice", "Open Ended - Single Choice", "Open Ended-Select All That Apply",
                             "Select All That Apply","Open Ended - Select All That Apply "):
            if question_name == 'crp_main': #for this question only, coded values should be taken from field programming_instructions
                programming_lines = programming_instructions.splitlines()
                for programming_line in programming_lines:
                    if ")" in programming_line:
                        #print(programming_line)
                        index, category = programming_line.split(")")
                        category = fix_category_formatting(category)
                        codes_and_labels.append([int(float(index.replace(",","."))*1000), category])
                crp_final = codes_and_labels
            else:
                #find all numbering present in the category string
                numbering_in_text = [n for n in numbering if n in categories]
                #print(numbering_in_text)
                ##the following loop creates a list "codes_and_labels" with all available codes&labels for each question
                for index in range(0,len(numbering_in_text)):
                    start = categories.find(numbering_in_text[index]) + len(numbering_in_text[index])
                    try:
                        end = categories.find(numbering_in_text[index + 1])
                        substring = categories[start:end].strip()
                    except:
                        # it fails during the last loop -> the last option is usually at the end of the string
                        substring = categories[start:].strip()
                    #print(substring)
                    category = fix_category_formatting(substring)
                    codes_and_labels.append([index +1, category])
                print("codes_and_labels: ", codes_and_labels)
                if codes_and_labels == [[1, 'Yes'], [2, 'No'], [3, "Don't know"], [4, 'Refused']]:
                    #in order to accomodate Amandine request, Yes No questions need to be reclassified
                    yes_no_reclassified_list.append(question_name)
                    codes_and_labels = [[0, 'No'], [1, 'Yes'], [2, "Don't know"], [3, 'Refused']]
                if question_name == 'language': #domains for languages are not included in the questionnaire
                    codes_and_labels = language_domains
                
            if question_type not in ["Open Ended-Select All That Apply","Select All That Apply","Open Ended - Select All That Apply "]:
                #so questions with NO derived fields
                field_names_list.append(question_name.strip())
                codes_and_labels_df = pd.DataFrame(codes_and_labels, columns=['code', 'label'])
                codes_and_labels_df.to_excel(writer, sheet_name=question_name)
                ##check if one of the option is other -> the question need 1 additional field for keeping the specified text
                if any(s[1].lower().strip() == "other" for s in codes_and_labels):
                    other_categories = [s[1] for s in codes_and_labels if s[1].lower().strip() == "other" ]
                    single_choice_derived_other_field = "%s_otherspecify" % question_name.strip()
                    single_choice_questions_with_other_categories.append(single_choice_derived_other_field)
                    field_names_list.append(single_choice_derived_other_field)
                    
            else:
                #so questions with derived fields
                numbering_in_qname = [n for n in numbering if n in question_name]
                for index in range(0, len(numbering_in_qname)):
                    start = question_name.find(numbering_in_qname[index]) + len(numbering_in_qname[index])
                    try:
                        end = question_name.find(numbering_in_qname[index + 1])
                        derived_field_name = question_name[start:end].strip()
                    except:
                        # it fails during the last loop -> the last option is usually at the end of the string
                        derived_field_name = question_name[start:].strip()
                    all_derived_fieldnames.append(derived_field_name)
                    derived_fieldnames.append(derived_field_name)
                    field_names_list.append(derived_field_name)
                    if derived_field_name[-6:] == "_other": ##this field will need to be STRING - with no domain (since it's a 'other specify')
                        all_answers_with_other_option.append(derived_field_name)
                    if index == 0:
                        first_derived_fieldname = derived_field_name
                        codes_and_labels_df = pd.DataFrame(codes_and_labels, columns=['code', 'label'])
                        #codes_and_labels_df.to_excel(writer, sheet_name=derived_field_name) #we don't need domain table for derived fields, since they will use YES NOT domain table
                dict_derived_fieldnames[first_derived_fieldname] = all_derived_fieldnames
        elif question_type == "Range":
            #these questions will be associated to LONG type fields
            field_names_list.append(question_name.strip())
            range_type_fields.append(question_name)
        elif question_type == "Open Ended":
            #these questions will be associated to TEXT type fields
            if not pd.isnull(question_name): #NaN rows we want to skip (i.e. OptIn question without a name in the survey)
                field_names_list.append(question_name)
                text_type_fields.append(question_name)
        else:
            print("QUESTION SKIPPED ---------", question_name, question_type)
    except:
        print("failed for some reasons")

#adding Yes No table (for derived fields domain)
d = {1:"Yes",0:"No"}
yesno_df = pd.DataFrame(d.items(), columns=['code', 'label'])
yesno_df.to_excel(writer, sheet_name='yes_no')
print("Saving codes and labels %s" % coded_values_file)

#print(all_answers_with_other_option)

#creating additional sheet with all derived fields, that will be used for a script that ensures that also these values are within the domains in the output table, in a later stage
list_of_yes_no_fields = []
for derived_field in all_derived_fieldnames:
    if derived_field not in all_answers_with_other_option:
        list_of_yes_no_fields.append(derived_field)
        
derived_fields_df = pd.DataFrame(list_of_yes_no_fields) 
#print(derived_fields_df.head())
derived_fields_df.to_excel(writer, sheet_name='derived_fields') 

# Close the Pandas Excel writer and output the Excel file.
writer.save()
# Out:
# Opening questionnaire DF
#
#
# ----calldispo----
# codes_and_labels:  [[1, 'Someone answers'], [2, 'Answering machine'], [3, 'No answer'], [4, 'Hang up or refusal'], [5, 'Call back'], [6, 'Under review'], [7, 'Disconnected']]
#
#
# ----calldispo_answeringmachine----
# QUESTION SKIPPED --------- calldispo_answeringmachine nan
#
#
# ----calldispo_noanswer----
# QUESTION SKIPPED --------- calldispo_noanswer nan
#
#
# ----calldispo_underreview----
# QUESTION SKIPPED --------- calldispo_underreview nan
#
#
# ----calldispo_disconnected----
# QUESTION SKIPPED --------- calldispo_disconnected nan
#
#
# ----resp_language----
# codes_and_labels:  [[1, 'English'], [2, 'Other options (add as many as necessary)']]
#
#
# ----introduction----
# codes_and_labels:  [[1, 'Continue']]
#
#
# ----resp_agree----
# codes_and_labels:  [[1, 'Yes'], [2, 'Not now but another time in the week'], [3, 'No']]
#
#
# ----resp_refusalwhy----
# codes_and_labels:  [[1, 'Not interested'], [2, 'Do not want to be recorded'], [3, 'Other ']]
#
#
# ----resp_whencallback----
#
#
# ----callbackmessage_en----
#
#
# ----NA----
# QUESTION SKIPPED --------- NA nan
#
#
# ----resp_age----
#
#
# ----resp_gender----
# codes_and_labels:  [[1, 'Male'], [2, 'Female'], [3, "Don't know"], [4, 'Refused']]
#
#
# ----hh_admin1----
# codes_and_labels:  [[1, '…'], [2, '…'], [3, "Don't know"], [4, 'Refused']]
#
#
# ----hh_admin2_1----
# codes_and_labels:  [[1, '…'], [2, '…'], [3, "Don't know"], [4, 'Refused']]
#
#
# ----hh_admin2_2----
# codes_and_labels:  [[1, '…'], [2, '…'], [3, "Don't know"], [4, 'Refused']]
#
#
# ----quotareached----
# codes_and_labels:  [[1, 'The goal for this location has been achieved - end survey'], [2, 'The goal for this location is open - continue survey']]
#
#
# ----hh_agricactivity----
# codes_and_labels:  [[1, 'Yes - crop production'], [2, 'Yes - livestock production'], [3, 'Yes - both crop and livestock production'], [4, 'No'], [5, "Don't know"], [6, 'Refused']]
#
#
# ----hh_gender----
# codes_and_labels:  [[1, 'Male'], [2, 'Female'], [3, "Don't know"], [4, 'Refused']]
#
#
# ----hh_education----
# codes_and_labels:  [[1, 'None or did not complete primary school'], [2, 'Completed primary school'], [3, 'Completed secondary school'], [4, 'Completed higher education (university, college) degree'], [5, 'Islamic or other religious education'], [6, "Don't know"], [7, 'Refused']]
#
#
# ----hh_wealth_water----
# codes_and_labels:  [[1, 'Private tap from piped water'], [2, 'Public tap'], [3, 'Protected well'], [4, 'Bottled water'], [5, 'Other safe source'], [6, 'River'], [7, 'Unprotected well'], [8, 'Spring water'], [9, 'Canal or other surface water'], [10, 'Other unsafe source'], [11, "Don't know"], [12, 'Refused']]
#
#
# ----hh_wealth_toilet----
# codes_and_labels:  [[1, 'Flush latrine (toilet with water)'], [2, 'Traditional pit latrine (no water)'], [3, 'Open pit (whole in the ground for excrement without water, roof or wall)'], [4, 'Communal latrine (with or without water)'], [5, 'None – bush'], [6, "Don't know"], [7, 'Refused']]
#
#
# ----hh_wealth_light----
# codes_and_labels:  [[1, 'Electricity (from generator or electrical grid)'], [2, 'Candle'], [3, 'Petrol lamp'], [4, 'Lamp with batteries'], [5, 'Other (no electric supply to the house)'], [6, "Don't know"], [7, 'Refused']]
#
#
# ----hh_residencetype----
# codes_and_labels:  [[1, 'Permanent resident - you have been living in your village, town for longer than two years and this is what you consider your habitual residence'], [2, 'Recent migrant not forcefully displaced - you have been living in your current place of residence for less than two years and you moved there voluntarily for work, family or other reasons that are not related to conflict or natural disaster'], [3, 'Returnee - you have only come back to this residence in the last two years after having been forced to move to another location having fled conflict or natural disaster (if return was over 2 years ago the respondent is considered a permanent resident)'], [4, 'Internally displaced person (IDP) - you were forced to flee your village or town because of conflict or natural disaster and you are now an internally displaced person in your current place of residence'], [5, 'Refugee - you were forced to flee your country because of conflict or natural disaster and you are now a refugee in your current place of residence'], [6, "Don't know"], [7, 'Refused']]
#
#
# ----hh_size----
#
#
# ----hh_maritalstat----
# codes_and_labels:  [[1, 'Single, never married'], [2, 'Married'], [3, 'Separated'], [4, 'Divorced'], [5, 'Widowed'], [6, 'Don’t know'], [7, 'Refused']]
#
#
# ----hh_age----
# codes_and_labels:  [[1, 'Under 18'], [2, '18 to 40'], [3, '41 to 65'], [4, 'Over 65'], [5, "Don't know"], [6, 'Refused']]
#
#
# ----income_main----
# codes_and_labels:  [[1, 'Farmer, production and sale of staple crops'], [2, 'Farmer, production and sale of vegetable or fruit'], [3, 'Farmer, production and sale of cashcrops'], [4, 'Farmer, production and sale of livestock and livestock products'], [5, 'Farmer, production and sale of fish'], [6, 'Collection and sale of forestry or bush products'], [7, 'Informal agricultural trade excluding producers'], [8, 'Formal agricultural trade excluding producers'], [9, 'Daily wage on farms and other casual employment in agricultural sector'], [10, 'Stable employment in agricultural sector'], [11, 'Non-agricultural self-employed or liberal profession, doctor, architect, lawyer, including restaurant'], [12, 'Off-farm daily wages and other non-agricultural casual employment'], [13, 'Stable employment in non-agricultural sector'], [14, 'Public employment'], [15, 'Income not derived from work, charity'], [16, 'Income not derived from work, welfare transfer, pension, humanitarian aid'], [17, 'Income not derived from work, remittances'], [18, 'Income not derived from work, income from other rents'], [19, 'No income source in the last 3 months and used exclusively savings'], [20, 'No income source in the last 3 months and used exclusively debt'], [21, 'Refused']]
#
#
# ----income_main_amount----
#
#
# ----income_main_amount_conf----
# codes_and_labels:  [[1, 'Continue']]
#
#
# ----income_main_comp----
# codes_and_labels:  [[1, 'A lot more (increased by more than 50%)'], [2, 'More'], [3, 'Same'], [4, 'Less'], [5, 'A lot less (less than half as much)'], [6, "Don't know"], [7, 'Refused']]
#
#
# ----income_sec----
# codes_and_labels:  [[1, 'Farmer, production and sale of staple crops'], [2, 'Farmer, production and sale of vegetable or fruit'], [3, 'Farmer, production and sale of cashcrops'], [4, 'Farmer, production and sale of livestock and livestock products'], [5, 'Farmer, production and sale of fish'], [6, 'Collection and sale of forestry or bush products'], [7, 'Informal agricultural trade excluding producers'], [8, 'Formal agricultural trade excluding producers'], [9, 'Daily wage on farms and other casual employment in agricultural sector'], [10, 'Stable employment in agricultural sector'], [11, 'Non-agricultural self-employed or liberal profession, doctor, architect, lawyer, including restaurant'], [12, 'Off-farm daily wages and other non-agricultural casual employment'], [13, 'Stable employment in non-agricultural sector'], [14, 'Public employment'], [15, 'Income not derived from work, charity'], [16, 'Income not derived from work, welfare transfer, pension, humanitarian aid'], [17, 'Income not derived from work, remittances'], [18, 'Income not derived from work, income from other rents'], [19, 'No second most important source of income'], [20, "Don't know"], [21, 'Refused']]
#
#
# ----income_sec_amount----
#
#
# ----income_sec_amount_conf----
# codes_and_labels:  [[1, 'Continue']]
#
#
# ----income_sec_comp----
# codes_and_labels:  [[1, 'A lot more (increased by more than 50%)'], [2, 'More'], [3, 'Same'], [4, 'Less'], [5, 'A lot less (less than half as much)'], [6, "Don't know"], [7, 'Refused']]
#
#
# ----income_third----
# codes_and_labels:  [[1, 'Farmer, production and sale of staple crops'], [2, 'Farmer, production and sale of vegetable or fruit'], [3, 'Farmer, production and sale of cashcrops'], [4, 'Farmer, production and sale of livestock and livestock products'], [5, 'Farmer, production and sale of fish'], [6, 'Collection and sale of forestry or bush products'], [7, 'Informal agricultural trade excluding producers'], [8, 'Formal agricultural trade excluding producers'], [9, 'Daily wage on farms and other casual employment in agricultural sector'], [10, 'Stable employment in agricultural sector'], [11, 'Non-agricultural self-employed or liberal profession, doctor, architect, lawyer, including restaurant'], [12, 'Off-farm daily wages and other non-agricultural casual employment'], [13, 'Stable employment in non-agricultural sector'], [14, 'Public employment'], [15, 'Income not derived from work, charity'], [16, 'Income not derived from work, welfare transfer, pension, humanitarian aid'], [17, 'Income not derived from work, remittances'], [18, 'Income not derived from work, income from other rents'], [19, 'No third most important source of income'], [20, "Don't know"], [21, 'Refused']]
#
#
# ----income_third_amount----
#
#
# ----income_third_amount_conf----
# codes_and_labels:  [[1, 'Continue']]
#
#
# ----income_third_comp----
# codes_and_labels:  [[1, 'A lot more (increased by more than 50%)'], [2, 'More'], [3, 'Same'], [4, 'Less'], [5, 'A lot less (less than half as much)'], [6, "Don't know"], [7, 'Refused']]
#
#
# ----covid_
#
# 1) covid_goodstransp
# 2) covid_marketclosed
# 3) covid_borderclosed
# 4) covid_stayhome
# 5) covid_gatherings
# 6) covid_processclosed
# 7) covid_other
# 8) covid_none
# 9) covid_dk
# 10) covid_ref----
# codes_and_labels:  [[1, 'Movement restrictions for goods impeding or delaying ability to transport goods to markets'], [2, 'Closure of food markets'], [3, 'Closure of international borders (affecting the purchase of imported inputs or the sale of goods for export or transhumance)'], [4, 'Stay at home order'], [5, 'Ban on gatherings'], [6, 'Closure of food processors (slaughterhouse, dairy cooperatives, etc) or restaurants'], [7, 'Other '], [8, 'Not affected by restrictions'], [9, "Don't know"], [10, 'Refused']]
#
#
# ----shock_
#
# 1) shock_noshock
# 2) shock_sicknessordeathofhh
# 3) shock_lostemplorwork
# 4) shock_otherintrahhshock
# 5) shock_higherfoodprices
# 6) shock_higherfuelprices
# 7) shock_cantworkordobusiness
# 8) shock_othereconomicshock
# 9) shock_pestoutbreak
# 10) shock_plantdisease
# 11) shock_animaldisease
# 12) shock_napasture
# 13) shock_othercropandlivests
# 14) shock_coldtemporhail
# 15) shock_flood
# 16) shock_hurricane
# 17) shock_drought
# 18) shock_earthquake
# 19) shock_landslides
# 20) shock_firenatural
# 21) shock_othernathazard
# 22) shock_violenceinsecconf
# 23) shock_theftofprodassets
# 24) shock_fire
# 25) shock_othermanmadehazard
# 26) shock_dk
# 27) shock_ref----
# codes_and_labels:  [[1, 'No shock'], [2, 'Sickness or death of household member(s) (sickness of breadwinner, unusually high medical expenditure, funeral expenses, death of breadwinner)'], [3, 'Lost employment or working opportunities'], [4, 'Other intra household shock'], [5, 'Much higher than usual food prices'], [6, 'Much higher than usual fuel prices'], [7, 'External event impeding the continuation of work or business affecting all - laws closing markets, businesses, road infrastructure to markets destroyed, etc.'], [8, 'Other economic shock'], [9, 'Pest outbreak'], [10, 'Plant disease'], [11, 'Animal disease affecting many animals'], [12, 'Lack of physical access to pasture (because of conflict, infrastructure damage, COVID-19 restrictions)'], [13, 'Other crop and livestock shock'], [14, 'Cold temperatures or hail'], [15, 'Flood'], [16, 'Hurricane, cyclone'], [17, 'Drought'], [18, 'Earthquake'], [19, 'Landslides'], [20, 'Fire from natural disaster'], [21, 'Other natural hazard'], [22, 'Violence and insecurity, conflict'], [23, 'Theft of production assets (land, livestock, tools, etc)'], [24, 'Fire from man-made disaster'], [25, 'Other man-made hazard'], [26, "Don't know"], [27, 'Refused']]
#
#
# ----shock_otherspecify----
#
#
# ----hh_explanation----
#
#
# ----crp_main----
# 1,1)Rice
# 1,2)Wheat
# 1,3)Millet
# 1,4)Sorghum
# 1,5)Maize
# 1,6)Barley
# 1,99)Other Cereal
# 2,1)Cassava
# 2,2)Potatoe
# 2,3)Sweet Potatoes
# 2,4)Yams
# 2,5)Carrots
# 2,6)Cocoyam
# 2,99)Other tubers
# 3,1)Beans
# 3,2)Lentils
# 3,3)Peas
# 3,4)Soybeans
# 3,99)Other pulses
# 4,1)Cabbage
# 4,2)Lettuce
# 4,3)Spinach-Amaranth
# 4,4)Cassava leaves
# 4,5)Potatoe leaves
# 4,6)Moringa
# 4,7)Sorrel Hibiscus / Rosselle
# 4,99)Other leafy vegetables
# 5,1)Tomatoes
# 5,2)Cucumber
# 5,3)Pumpkin
# 5,4)Eggplant/aubergine
# 5,5)Zucchini
# 5,6)Okra
# 5,7)Pepper
# 5,8)Onions
# 5,99)Other non leafy vegs
# 6,1)Orange
# 6,2)Lemon
# 6,3)Grapefruit
# 6,99)Other citrus fruit
# 7,1)Sweet Banana
# 7,2)Plantains
# 7,3)Papaya
# 7,4)Mango
# 7,5)Guava
# 7,6)Pineapple
# 7,7)Avocado
# 7,8)Watermelon
# 7,9)Dates
# 7,101)Figs
# 7,11)Grapes
# 7,12)Olives
# 7,99)Other fruit
# 8,1)Coconuts
# 8,2)Groundnut/peanut
# 8,3)Cashew Nut
# 8,4)Kola Nut
# 8,5)Sesame
# 8,6)Bambara nut
# 8,99)Other nuts
# 9,1)Cocoa
# 9,2)Coffee
# 9,3)Tea
# 9,4)Sugarcane
# 9,5)Sunflower
# 9,99)Other food cash crop
# 10,1)Cotton
# 10,2)Rubber
# 10,3)Jute
# 10,4)Fodder
# 10,5)Tobacco
# 10,99)Other non-food cash crop
# 777)No crop production
# 888)DON'T KNOW
# 999)REFUSED
#
#
# ----crp_landsize----
# codes_and_labels:  [[1, 'Less than 1 ha'], [2, '1 to 5 ha'], [3, '5 to 10 ha'], [4, 'More than 10 ha'], [5, 'Don’t know'], [6, 'Refused']]
#
#
# ----crp_landright----
# codes_and_labels:  [[1, 'Inherited'], [2, 'Right given by community leader'], [3, 'Cleared from bush or forest'], [4, 'Purchased'], [5, 'Received from state'], [6, 'Sharecrop'], [7, 'Rental'], [8, 'Other '], [9, "Don't know"], [10, 'Refused']]
#
#
# ----crp_irrigation----
# codes_and_labels:  [[1, 'Rainfed'], [2, 'Canal'], [3, 'Pump or mechanized'], [4, 'Manually from water surface, well or other water source'], [5, 'Flood irrigation'], [6, 'Other '], [7, "Don't know"], [8, 'Refused']]
#
#
# ----crp_seed_supply
#
# 1) crp_seed_ownprod
# 2) crp_seed_market
# 3) crp_seed_company
# 4) crp_seed_freedist
# 5) crp_seed_bank
# 6) crp_seed_gov
# 7) crp_seed_other
# 8) crp_seed_dk
# 9) crp_seed_ref----
# codes_and_labels:  [[1, 'Own production'], [2, 'Purchased at market or agro-input shop'], [3, 'Purchased directly from seed company'], [4, 'Free distribution'], [5, 'Community seed banks, farmer networks, etc.'], [6, 'Government suppliers'], [7, 'Other '], [8, "Don't know"], [9, 'Refused']]
#
#
# ----crp_area_change----
# codes_and_labels:  [[1, 'A lot more (increased by more than 50%)'], [2, 'More'], [3, 'Same'], [4, 'Less'], [5, 'A lot less (less than half as much)'], [6, "Don't know"], [7, 'Refused']]
#
#
# ----crp_harv_change----
# codes_and_labels:  [[1, 'A lot more (increased by more than 50%)'], [2, 'More'], [3, 'Same'], [4, 'Less'], [5, 'A lot less (less than half as much)'], [6, "Don't know"], [7, 'Refused']]
#
#
# ----crp_proddif----
# codes_and_labels:  [[1, 'Yes'], [2, 'No'], [3, "Don't know"], [4, 'Refused']]
#
#
# ----crp_proddif_
#
# 1) crp_proddif_plantdisease
# 2) crp_proddif_seedquality
# 3) crp_proddif_lostordamaged
# 4) crp_proddif_naplot
# 5) crp_proddif_nafertilizer
# 6) crp_proddif_naseeds
# 7) crp_proddif_nainsecticides
# 8) crp_proddif_nalabour
# 9) crp_proddif_namachinery
# 10) crp_proddif_nafuelorelect
# 11) crp_proddif_soilerosion
# 12) crp_proddif_irrigation
# 13) crp_proddif_other
# 14) crp_proddif_dk
# 15) crp_proddif_ref----
# codes_and_labels:  [[1, 'Plant disease'], [2, 'Low quality of seeds'], [3, 'Crop lost or damaged during growing season (locust, armyworm, or disasters other than plant disease)'], [4, 'Could not access plot'], [5, 'Could not  access fertilizer (not available on markets or prices too high)'], [6, 'Could not access enough seeds (not available on markets or prices too high)'], [7, 'Could not access insecticides'], [8, 'Could not access extra labour or manpower'], [9, 'Could not access machinery'], [10, 'Could not access  fuel or electricity to power agricultural equipment'], [11, 'Soil erosion'], [12, 'Not enough irrigation or rainfall water'], [13, 'Other '], [14, "Don't know"], [15, 'Refused']]
#
#
# ----crp_salesdif----
# codes_and_labels:  [[1, 'Yes'], [2, 'No'], [3, "Don't know"], [4, 'Refused']]
#
#
# ----crp_saledif_
#
# 1) crp_saledif_marketing_cost
# 2) crp_saledif_damagelosses
# 3) crp_saledif_lowdemand
# 4) crp_saledif_lowprice
# 5) crp_saledif_dif_processing
# 6) crp_saledif_other
# 7) crp_saledif_dk
# 8) crp_saledif_ref----
# codes_and_labels:  [[1, 'Higher marketing costs (such as transportation)'], [2, 'Damage and losses due to delay or inability to physically access markets'], [3, 'Usual traders or local customers are not buying as much as usual'], [4, 'Prices are too low'], [5, 'Difficulty processing product (lack of processing inputs, equipment, etc)'], [6, 'Other '], [7, "Don't know"], [8, 'Refused']]
#
#
# ----crp_salesprice----
# codes_and_labels:  [[1, 'A lot more (increased by more than 50%)'], [2, 'More'], [3, 'Same'], [4, 'Less'], [5, 'A lot less (less than half as much)'], [6, "Don't know"], [7, 'Refused']]
#
#
# ----crp_proc----
# codes_and_labels:  [[1, 'Yes'], [2, 'No'], [3, "Don't know"], [4, 'Refused']]
#
#
# ----crp_proc_mach_
#
# 1) crp_proc_mach_mill
# 2) crp_proc_mach_thresher
# 3) crp_proc_mach_dryingfacilit
# 4)crp_proc_mach_none
# 5) crp_proc_mach_other
# 6) crp_proc_mach_dk
# 7) crp_proc_mach_ref----
# codes_and_labels:  [[1, 'Mill'], [2, 'Thresher'], [3, 'Drying facilities'], [4, 'None'], [5, 'Other '], [6, "Don't know"], [7, 'Refused']]
#
#
# ----crp_proc_owner_
#
# 1) crp_proc_owner_yours
# 2) crp_proc_owner_farmin
# 3) crp_proc_owner_farmout
# 4) crp_proc_owner_millin
# 5) crp_proc_owner_millout
# 6) crp_proc_owner_other
# 7) crp_proc_owner_dk
# 8) crp_proc_owner_ref----
# codes_and_labels:  [[1, 'Yourself'], [2, 'Farm cooperative within community'], [3, 'Farm cooperative outside of community'], [4, 'Private shop or mill within community'], [5, 'Private mill outside community'], [6, 'Other '], [7, "Don't know"], [8, 'Refused']]
#
#
# ----crp_proc_state----
# codes_and_labels:  [[1, 'Yes'], [2, 'No'], [3, "Don't know"], [4, 'Refused']]
#
#
# ----ls_main----
# codes_and_labels:  [[1, 'Cattle (cow, beef, veal, yak, buffalo)'], [2, 'Goats'], [3, 'Sheeps'], [4, 'Swine'], [5, 'Equine (donkey, horse, etc)'], [6, 'Small domesticated mammals (rabbits, minks, guinea pigs, etc)'], [7, 'Poultry (chicken, guineafowl, duck, etc)'], [8, 'Camelids'], [9, 'Other '], [10, "Don't know"], [11, 'Refused']]
#
#
# ----ls_num_lastyr----
#
#
# ----ls_num_now----
#
#
# ----ls_num_
#
# 1)ls_num_nochange
# 2) ls_num_inc_didnotsellasmany
# 3) ls_num_inc_moreborn
# 4) ls_num_inc_purchbarterdmore
# 5) ls_num_inc_receivedfree
# 6)ls_num_dec_animalsdied
# 7)ls_num_dec_soldmoregoodprice
# 8)ls_num_dec_soldmoredistsale
# 9)ls_num_dec_anmlescloststolen
# 10)ls_num_dec_killedorgaveanml
# 11)ls_num_inc_dec_other
# 12)ls_num_inc_dec_dk
# 13)ls_num_inc_dec_ref----
# codes_and_labels:  [[1, 'No change in livestock number'], [2, 'Did not sell as many'], [3, 'Many more born'], [4, 'Purchased or bartered more animals this year'], [5, 'Received animals for free (restocking, gift)'], [6, 'Animals died of poor health, malnutrition or injury'], [7, 'Sold more than usual because of good prices'], [8, 'Sold more than usual because of distress sales (unable to feed animal, need money urgently for household basic needs even if sales were unsustainable)'], [9, 'Animal escaped or was lost or stolen'], [10, 'Killed or gave away more animals than usual for household consumption or celebrations (marriage, funerals, etc)'], [11, 'Other '], [12, 'Don’t know'], [13, 'Refused']]
#
#
# ----ls_food_supply
#
# 1) ls_food_supply_openpasture
# 2) ls_food_supply_commonpasture
# 3) ls_food_supply_fieldselfprodfod
# 4) ls_food_supply_purchased
# 5) ls_food_supply_other
# 6) ls_food_supply_dk
# 7) ls_food_supply_ref----
# codes_and_labels:  [[1, 'Open pasture'], [2, 'Community-managed pasture land'], [3, 'Owned or rented field or self-produced fodder'], [4, 'Purchase feed or fodder on markets'], [5, 'Other '], [6, "Don't know"], [7, 'Refused']]
#
#
# ----ls_proddif----
# codes_and_labels:  [[1, 'Yes'], [2, 'No'], [3, "Don't know"], [4, 'Refused']]
#
#
# ----ls_proddif_
#
# 1) ls_proddif_diffeedpurchase
# 2) ls_proddif_constaccesstopasture
# 3) ls_proddif_constaccesstowater
# 4) ls_proddif_difaccessvetserv
# 5) ls_proddif_difaccessvetinp
# 6) ls_proddif_diseases
# 7) ls_proddif_theftorinsecurity
# 8) ls_proddif_pooraccesstolmarket
# 9) ls_proddif_noaccesstocredit
# 10) ls_proddif_lackoflabour
# 11) ls_proddif_other
# 12) ls_proddif_dk
# 13) ls_proddif_ref----
# codes_and_labels:  [[1, 'Difficulty to purchase feed (prices or access to market)'], [2, 'Constrained access to pasture'], [3, 'Constrained access to water'], [4, 'Difficulty to access veterinary services'], [5, 'Difficulty to access veterinary inputs (medicine for animals, tools for animal health, etc)'], [6, 'Livestock diseases'], [7, 'Livestock theft or insecurity'], [8, 'Poor access to livestock market to buy young animals'], [9, 'No access to  credit'], [10, 'Labour too expensive or income insufficient to hire labour or labourers are unavailable'], [11, 'Other '], [12, "Don't know"], [13, 'Refused']]
#
#
# ----ls_salesmain----
# codes_and_labels:  [[1, 'Cattle (cow, beef, veal, yak, buffalo)'], [2, 'Goats'], [3, 'Sheeps'], [4, 'Swine'], [5, 'Equine (donkey, horse, etc.)'], [6, 'Small domesticated mammals (rabbits, minks, guinea pigs, etc)'], [7, 'Poultry (chicken, guineafowl, duck, etc.)'], [8, 'Camelids'], [9, 'Eggs'], [10, 'Milk or dairy products'], [11, 'Skin or leather'], [12, "Don't know"], [13, 'Refused']]
#
#
# ----ls_salesdif----
# codes_and_labels:  [[1, 'Yes'], [2, 'No'], [3, "Don't know"], [4, 'Refused']]
#
#
# ----ls_salesdif_
#
# 1) ls_salesdif_smallerprofits
# 2) ls_salesdif_damageandlosses
# 3) ls_salesdif_lowdemand
# 4) ls_salesdif_lowprices
# 5)  ls_salesdif_slaughterhouse
# 6) ls_salesdif_processing
# 7) ls_salesdif_other
# 8) ls_salesdif_dk
# 9) ls_salesdif_ref----
# codes_and_labels:  [[1, 'Higher marketing costs (such as transportation)'], [2, 'Damage and losses due to delay or inability to physically access markets (including limited storage capacity)'], [3, 'Usual traders or local customers are not buying as much as usual'], [4, 'Prices are too low'], [5, 'Closure of slaughterhouses or difficulties accessing slaughterhouses'], [6, 'Difficulties to process product other than closure of slaughterhouse (lack of access to processing inputs, equipment, etc)'], [7, 'Other '], [8, "Don't know"], [9, 'Refused']]
#
#
# ----ls_salesprice----
# codes_and_labels:  [[1, 'A lot more (increased by more than 50%)'], [2, 'More'], [3, 'Same'], [4, 'Less'], [5, 'A lot less (less than half as much)'], [6, "Don't know"], [7, 'Refused']]
#
#
# ----ls_proc----
# codes_and_labels:  [[1, 'Yes'], [2, 'No'], [3, "Don't know"], [4, 'Refused']]
#
#
# ----ls_proc_
# 1) ls_proc_slaughter
# 2)ls_proc_meatprocess
# 3) ls_proc_dairyprocess
# 4) ls_proc_leather
# 5) ls_proc_other
# 6) ls_proc_dk
# 7) ls_proc_ref----
# codes_and_labels:  [[1, 'Slaughter'], [2, 'Meat processing after slaughtering (drying, roasting, smoking, fresh meat)'], [3, 'Dairy processing'], [4, 'Leather'], [5, 'Other '], [6, "Don't know"], [7, 'Refused']]
#
#
# ----ls_proc_fac_
# 1) ls_proc_fac_priv_cold_transp
# 2) ls_proc_fac_coop_cold_transp
# 3) ls_proc_fac_slaughterinncomm
# 4) ls_proc_fac_slaughteroutofcomm
# 5) ls_proc_fac_farm_dairy
# 6) ls_proc_fac_coop_dairy
# 7) ls_proc_fac_other
# 8)ls_proc_fac_none
# 9) ls_proc_fac_dk
# 10) ls_proc_fac_ref----
# codes_and_labels:  [[1, 'Purchase private cold transportation services'], [2, 'Cold transport from farm cooperative'], [3, 'Slaughterhouse within community'], [4, 'Slaughterhouse outside of community'], [5, 'Dairy processing at farm'], [6, 'Dairy processing in cooperative'], [7, 'None'], [8, 'Other '], [9, "Don't know"], [10, 'Refused']]
#
#
# ----ls_proc_fac_state----
# codes_and_labels:  [[1, 'Yes'], [2, 'No'], [3, "Don't know"], [4, 'Refused']]
#
#
# ----fish_main_
#
# 1) fish_main_coastal
# 2) fish_main_opensea
# 3) fish_main_lakespondsrivers
# 4) fish_main_aquaculture
# 5) fish_main_dk
# 6) fish_main_ref----
# codes_and_labels:  [[1, 'Coastal fishing'], [2, 'Open sea fishing'], [3, 'Fishing (in lakes, in ponds, in rivers)'], [4, 'Aquaculture'], [5, "Don't know"], [6, 'Refused']]
#
#
# ----fish_change----
# codes_and_labels:  [[1, 'A lot more (increased by more than 50%)'], [2, 'More'], [3, 'Same'], [4, 'Less'], [5, 'A lot less (less than half as much)'], [6, "Don't know"], [7, 'Refused']]
#
#
# ----fish_proddif----
# codes_and_labels:  [[1, 'Yes'], [2, 'No'], [3, "Don't know"], [4, 'Refused']]
#
#
# ----fish_proddif_
#
# 1) fish_proddif_find
# 2) fish_proddif_covid
# 3) fish_proddif_fuel
# 4) fish_proddif_inputs
# 5) fish_proddif_labour
# 6) fish_proddif_other
# 7) fish_proddif_dk
# 8) fish_proddif_ref----
# codes_and_labels:  [[1, 'Fish is more difficult to find than in previous years  in the same season'], [2, 'Concerns and restrictions related to COVID-19 pandemic'], [3, 'Difficulty accessing fuel (prices higher or not available)'], [4, 'Difficulty accessing fishing material and-or other inputs (prices higher or not available)'], [5, 'Labour too expensive or income insufficient to hire labour'], [6, 'Other '], [7, "Don't know"], [8, 'Refused']]
#
#
# ----fish_inputdif_
#
# 1) fish_inputdif_bait
# 2)fish_inputdif_net
# 3) fish_inputdif_gear
# 4) fish_inputdif_ice
# 5) fish_inputdif_fuel
# 6) fish_inputdif_boatrepairs
# 7) fish_inputdif_other
# 8)fish_inputdif_dk
# 9) fish_inputdif_ref----
# codes_and_labels:  [[1, 'Bait'], [2, 'Net'], [3, 'Gear'], [4, 'Ice'], [5, 'Fuel'], [6, 'Boat repairs'], [7, 'Other '], [8, "Don't know"], [9, 'Refused']]
#
#
# ----fish_salesmain----
# codes_and_labels:  [[1, 'Fresh fish (any kind)'], [2, 'Dry fish (any kind)'], [3, 'Smoked fish'], [4, 'Seafood (any kind)'], [5, 'Other '], [6, "Don't know"], [7, 'Refused']]
#
#
# ----fish_salesdif----
# codes_and_labels:  [[1, 'Yes'], [2, 'No'], [3, "Don't know"], [4, 'Refused']]
#
#
# ----fish_saledif_
#
# 1) fish_saledif_smallerprofits
# 2) fish_saledif_damageandlosses
# 3) fish_saledif_lowdemand
# 4) fish_saledif_lowprices
# 5) fish_saledif_processing
# 6) fish_saledif_other
# 7) fish_saledif_dk
# 8) fish_saledif_ref----
# codes_and_labels:  [[1, 'Higher marketing costs (such as transportation costs, fuel costs, etc)'], [2, 'Damage and losses due to delay or inability to physically access markets (including limited storage capacity and closure of markets)'], [3, 'Usual traders or local customers are not buying as much as usual'], [4, 'Prices are too low'], [5, 'Difficulties to process product (lack of access to processing inputs, equipment, etc)'], [6, 'Other '], [7, "Don't know"], [8, 'Refused']]
#
#
# ----fish_salesprice----
# codes_and_labels:  [[1, 'A lot more (increased by more than 50%)'], [2, 'More'], [3, 'Same'], [4, 'Less'], [5, 'A lot less (less than half as much)'], [6, "Don't know"], [7, 'Refused']]
#
#
# ----fies----
# codes_and_labels:  [[1, 'Next']]
#
#
# ----fies_worried----
# codes_and_labels:  [[1, 'Yes'], [2, 'No'], [3, "Don't know"], [4, 'Refused']]
#
#
# ----fies_healthy----
# codes_and_labels:  [[1, 'Yes'], [2, 'No'], [3, "Don't know"], [4, 'Refused']]
#
#
# ----fies_fewfoods----
# codes_and_labels:  [[1, 'Yes'], [2, 'No'], [3, "Don't know"], [4, 'Refused']]
#
#
# ----fies_skipped----
# codes_and_labels:  [[1, 'Yes'], [2, 'No'], [3, "Don't know"], [4, 'Refused']]
#
#
# ----fies_ateless----
# codes_and_labels:  [[1, 'Yes'], [2, 'No'], [3, "Don't know"], [4, 'Refused']]
#
#
# ----fies_ranout----
# codes_and_labels:  [[1, 'Yes'], [2, 'No'], [3, "Don't know"], [4, 'Refused']]
#
#
# ----fies_ranout_hhs----
# codes_and_labels:  [[1, 'Rarely (once or twice)'], [2, 'Sometimes (in some weeks but not every week)'], [3, 'Often (every week)'], [4, "Don't know"], [5, 'Refused']]
#
#
# ----fies_hungry----
# codes_and_labels:  [[1, 'Yes'], [2, 'No'], [3, "Don't know"], [4, 'Refused']]
#
#
# ----fies_hungry_hhs----
# codes_and_labels:  [[1, 'Rarely (once or twice)'], [2, 'Sometimes (in some weeks but not every week)'], [3, 'Often (every week)'], [4, "Don't know"], [5, 'Refused']]
#
#
# ----fies_whlday----
# codes_and_labels:  [[1, 'Yes'], [2, 'No'], [3, "Don't know"], [4, 'Refused']]
#
#
# ----fies_whlday_hhs----
# codes_and_labels:  [[1, 'Rarely (once or twice)'], [2, 'Sometimes (in some weeks but not every week)'], [3, 'Often (every week)'], [4, "Don't know"], [5, 'Refused']]
#
#
# ----copingstrategies----
# codes_and_labels:  [[1, 'Next']]
#
#
# ----cs_stress_hh_assets----
# codes_and_labels:  [[1, 'Yes'], [2, 'No - because it wasn’t necessary'], [3, 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it'], [4, 'Not applicable'], [5, "Don't know"], [6, 'Refused']]
#
#
# ----cs_stress_spent_savings----
# codes_and_labels:  [[1, 'Yes'], [2, 'No - because it wasn’t necessary'], [3, 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it'], [4, 'Not applicable'], [5, "Don't know"], [6, 'Refused']]
#
#
# ----cs_stress_sold_more_animals----
# codes_and_labels:  [[1, 'Yes'], [2, 'No - because it wasn’t necessary'], [3, 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it'], [4, 'Not applicable'], [5, "Don't know"], [6, 'Refused']]
#
#
# ----cs_stress_eat_elsewhere----
# codes_and_labels:  [[1, 'Yes'], [2, 'No - because it wasn’t necessary'], [3, 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it'], [4, 'Not applicable'], [5, "Don't know"], [6, 'Refused']]
#
#
# ----cs_stress_borrowed_or_helped----
# codes_and_labels:  [[1, 'Yes'], [2, 'No - because it wasn’t necessary'], [3, 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it'], [4, 'Not applicable'], [5, "Don't know"], [6, 'Refused']]
#
#
# ----cs_stress_credit----
# codes_and_labels:  [[1, 'Yes'], [2, 'No - because it wasn’t necessary'], [3, 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it'], [4, 'Not applicable'], [5, "Don't know"], [6, 'Refused']]
#
#
# ----cs_stress_borrowed_money----
# codes_and_labels:  [[1, 'Yes'], [2, 'No - because it wasn’t necessary'], [3, 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it'], [4, 'Not applicable'], [5, "Don't know"], [6, 'Refused']]
#
#
# ----cs_stress_changed_school----
# codes_and_labels:  [[1, 'Yes'], [2, 'No - because it wasn’t necessary'], [3, 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it'], [4, 'Not applicable'], [5, "Don't know"], [6, 'Refused']]
#
#
# ----cs_crisis_sold_prod_assets----
# codes_and_labels:  [[1, 'Yes'], [2, 'No - because it wasn’t necessary'], [3, 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it'], [4, 'Not applicable'], [5, "Don't know"], [6, 'Refused']]
#
#
# ----cs_crisis_no_school----
# codes_and_labels:  [[1, 'Yes'], [2, 'No - because it wasn’t necessary'], [3, 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it'], [4, 'Not applicable'], [5, "Don't know"], [6, 'Refused']]
#
#
# ----cs_crisis_reduced_health_exp----
# codes_and_labels:  [[1, 'Yes'], [2, 'No - because it wasn’t necessary'], [3, 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it'], [4, 'Not applicable'], [5, "Don't know"], [6, 'Refused']]
#
#
# ----cs_crisis_harv_immature_crops----
# codes_and_labels:  [[1, 'Yes'], [2, 'No - because it wasn’t necessary'], [3, 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it'], [4, 'Not applicable'], [5, "Don't know"], [6, 'Refused']]
#
#
# ----cs_crisis_consumed_seed_stocks----
# codes_and_labels:  [[1, 'Yes'], [2, 'No - because it wasn’t necessary'], [3, 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it'], [4, 'Not applicable'], [5, "Don't know"], [6, 'Refused']]
#
#
# ----cs_crisis_decr_agric_input_exp----
# codes_and_labels:  [[1, 'Yes'], [2, 'No - because it wasn’t necessary'], [3, 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it'], [4, 'Not applicable'], [5, "Don't know"], [6, 'Refused']]
#
#
# ----cs_emergency_sold_house----
# codes_and_labels:  [[1, 'Yes'], [2, 'No - because it wasn’t necessary'], [3, 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it'], [4, 'Not applicable'], [5, "Don't know"], [6, 'Refused']]
#
#
# ----cs_emergency_begged----
# codes_and_labels:  [[1, 'Yes'], [2, 'No - because it wasn’t necessary'], [3, 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it'], [4, 'Not applicable'], [5, "Don't know"], [6, 'Refused']]
#
#
# ----cs_emergency_illegal----
# codes_and_labels:  [[1, 'Yes'], [2, 'No - because it wasn’t necessary'], [3, 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it'], [4, 'Not applicable'], [5, "Don't know"], [6, 'Refused']]
#
#
# ----cs_emergency_sold_last_female----
# codes_and_labels:  [[1, 'Yes'], [2, 'No - because it wasn’t necessary'], [3, 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it'], [4, 'Not applicable'], [5, "Don't know"], [6, 'Refused']]
#
#
# ----cs_emergency_hh_migration----
# codes_and_labels:  [[1, 'Yes'], [2, 'No - because it wasn’t necessary'], [3, 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it'], [4, 'Not applicable'], [5, "Don't know"], [6, 'Refused']]
#
#
# ----hdds
#
# 1) hdds_cereals
# 2) hdds_rootstubers
# 3) hdds_vegetables
# 4) hdds_fruits
# 5) hdds_meat
# 6) hdds_eggs
# 7) hdds_fish
# 8) hdds_legumes
# 9) hdds_milkdairy
# 10) hdds_oils
# 11)hdds_sugar
# 12) hdds_condiments----
# codes_and_labels:  [[1, 'Cereals (sorghum, millet, corn, wheat, rice, spaghetti, bread or insert any other locally available grain)'], [2, 'Roots and tubers (white sweet potato, potato, yam, cassava or other tubers)'], [3, 'Vegetables (all)'], [4, 'Fruits (all)'], [5, 'Meat, poultry and offal (beef, pork, lamb, goat, rabbit, wild game, chicken, duck, liver, kidney, heart, or other organ meats)'], [6, 'Eggs'], [7, 'Fish or shellfish (fresh or dried fish, shellfish)'], [8, 'Legumes and nuts (beans, peas, peanut, lentils, almond, other nuts)'], [9, 'Milk and other dairy products (fresh milk, sour, yogurt, cheese, other dairy products)'], [10, 'Oils and fat (cooking, butter, margarine, fat, oil, other oil)'], [11, 'Sugar or sugary products (honey, jam, donuts, candy, chocolate, biscuits, pastries, cakes and other sweet products)'], [12, 'Condiments (cocoa, salt, garlic, spices, yeast, baking powder, tomato or tomato sauce, meat or fish as a condiment) and coffee, tea']]
#
#
# ----hdds_confirmation----
# codes_and_labels:  [[1, 'Continue']]
#
#
# ----need----
# codes_and_labels:  [[1, 'Yes'], [2, 'No'], [3, "Don't know"], [4, 'Refused']]
#
#
# ----need_
#
# 1) need_seeds
# 2) need_fertilizers
# 3) need_pesticides
# 4) need_tools
# 5) need_accesstoirrigationwater
# 6) need_accesstoland
# 7) need_animalfeed
# 8) need_veterinaryservices
# 9) need_veterinaryinputs
# 10) need_animalsalemingarantdprice
# 11) need_restockinganimals
# 12) need_supportforprocessprod
# 13) need_supptransofanimalsorprod
# 14) need_acstomechanisedequipprod
# 15) need_marketingsupport
# 16) need_cashassistance
# 17) need_loans
# 18) need_storageequipmentorfaci
# 19) need_techsupporextensionserv
# 20) need_landrehabilitation
# 21) need_fishequiorothersuppforfish
# 22) need_infoonsafetymeasures
# 23) need_other
# 24) need_dk
# 25) need_ref----
# codes_and_labels:  [[1, 'Seeds'], [2, 'Fertilizers'], [3, 'Pesticides'], [4, 'Tools'], [5, 'Access to irrigation water'], [6, 'Access to land'], [7, 'Animal feed'], [8, 'Veterinary services'], [9, 'Veterinary inputs'], [10, 'Sales of animals with minimum garanteed price'], [11, 'Restocking animals'], [12, 'Support for processing product'], [13, 'Support for transportation of animals or animal product (e.g. cold chains for milk)'], [14, 'Access to tractors'], [15, 'Marketing support'], [16, 'Cash assistance'], [17, 'Loans'], [18, 'Storage equipment or facility (bags, containers, etc.)'], [19, 'Technical support or extension services'], [20, 'Land rehabilitation (in case of a disaster)'], [21, 'Fisheries equipment or other support for fisheries'], [22, 'Information on safety measures to carry out agricultural work in the context of the COVID-19 epidemic'], [23, 'Other '], [24, "Don't know"], [25, 'Refused']]
#
#
# ----need_received_
#
# 1) need_received_food
# 2) need_received_cashvouchers
# 3) need_received_seeds
# 4) need_received_extensionservices
# 5) need_received_livestockfeed
# 6) need_received_other
# 7) need_received_noassistreceived
# 8) need_received_dk
# 9) need_received_ref----
# codes_and_labels:  [[1, 'Food'], [2, 'Cash vouchers'], [3, 'Seeds'], [4, 'Extension services'], [5, 'Livestock feed'], [6, 'Other '], [7, 'No assistance received'], [8, "Don't know"], [9, 'Refused']]
#
#
# ----callback----
# codes_and_labels:  [[1, 'Yes'], [2, 'No']]
#
#
# ----language----
# codes_and_labels:  [[1, 'English'], [2, 'Other languages (consistent with resp_language)']]
#
#
# ----closeout----
# QUESTION SKIPPED --------- closeout nan
# Saving codes and labels C:\temp\data_processing_exports\coded_values_20210805161405.xlsx
# C:\envs\arcgispro-coco\lib\site-packages\xlsxwriter\workbook.py:329: UserWarning: Calling close() on already closed file.
#   warn("Calling close() on already closed file.")

# %%
for i in crp_final:
    print(i)
# Out:
# [1100, 'Rice']
# [1200, 'Wheat']
# [1300, 'Millet']
# [1400, 'Sorghum']
# [1500, 'Maize']
# [1600, 'Barley']
# [1990, 'Other cereal']
# [2100, 'Cassava']
# [2200, 'Potatoe']
# [2300, 'Sweet potatoes']
# [2400, 'Yams']
# [2500, 'Carrots']
# [2600, 'Cocoyam']
# [2990, 'Other tubers']
# [3100, 'Beans']
# [3200, 'Lentils']
# [3300, 'Peas']
# [3400, 'Soybeans']
# [3990, 'Other pulses']
# [4100, 'Cabbage']
# [4200, 'Lettuce']
# [4300, 'Spinach-amaranth']
# [4400, 'Cassava leaves']
# [4500, 'Potatoe leaves']
# [4600, 'Moringa']
# [4700, 'Sorrel hibiscus, rosselle']
# [4990, 'Other leafy vegetables']
# [5100, 'Tomatoes']
# [5200, 'Cucumber']
# [5300, 'Pumpkin']
# [5400, 'Eggplant/aubergine']
# [5500, 'Zucchini']
# [5600, 'Okra']
# [5700, 'Pepper']
# [5800, 'Onions']
# [5990, 'Other non leafy vegs']
# [6100, 'Orange']
# [6200, 'Lemon']
# [6300, 'Grapefruit']
# [6990, 'Other citrus fruit']
# [7100, 'Sweet banana']
# [7200, 'Plantains']
# [7300, 'Papaya']
# [7400, 'Mango']
# [7500, 'Guava']
# [7600, 'Pineapple']
# [7700, 'Avocado']
# [7800, 'Watermelon']
# [7900, 'Dates']
# [7101, 'Figs']
# [7110, 'Grapes']
# [7120, 'Olives']
# [7990, 'Other fruit']
# [8100, 'Coconuts']
# [8200, 'Groundnut/peanut']
# [8300, 'Cashew nut']
# [8400, 'Kola nut']
# [8500, 'Sesame']
# [8600, 'Bambara nut']
# [8990, 'Other nuts']
# [9100, 'Cocoa']
# [9200, 'Coffee']
# [9300, 'Tea']
# [9400, 'Sugarcane']
# [9500, 'Sunflower']
# [9990, 'Other food cash crop']
# [10100, 'Cotton']
# [10200, 'Rubber']
# [10300, 'Jute']
# [10400, 'Fodder']
# [10500, 'Tobacco']
# [10990, 'Other non-food cash crop']
# [777000, 'No crop production']
# [888000, "Don't know"]
# [999000, 'Refused']

# %%
###this section creates a new GDB
gdb_name = "fGDB_with_coded_values_%s.gdb" % now
output_gdb = os.path.join(temp_path, gdb_name)
arcpy.CreateFileGDB_management(temp_path,gdb_name)
# Out:
# <Result 'C:\\temp\\data_processing_exports\\fGDB_with_coded_values_20210802172812.gdb'>

# %%
# print(single_choice_derived_other_field )
# print(single_choice_questions_with_other_categories)
# print(all_answers_with_other_option)

# %%
##here we and import each table with coded values and description into the GDB
###it can take up to 5 seconds per table - and we normally process hundreds of table.
####for this reason, for testing purposes edit variable max_counter in the first cell of this notebook


importallsheets(coded_values_file, output_gdb)
# Out:
# max_counter: 3000
# 89 sheets found: calldispo,resp_language,introduction,resp_agree,resp_refusalwhy,resp_gender,hh_admin1,hh_admin2_1,hh_admin2_2,quotareached,hh_agricactivity,hh_gender,hh_education,hh_wealth_water,hh_wealth_toilet,hh_wealth_light,hh_residencetype,hh_maritalstat,hh_age,income_main,income_main_amount_conf,income_main_comp,income_sec,income_sec_amount_conf,income_sec_comp,income_third,income_third_amount_conf,income_third_comp,crp_main,crp_landsize,crp_landright,crp_irrigation,crp_area_change,crp_harv_change,crp_proddif,crp_salesdif,crp_salesprice,crp_proc,crp_proc_state,ls_main,ls_proddif,ls_salesmain,ls_salesdif,ls_salesprice,ls_proc,ls_proc_fac_state,fish_change,fish_proddif,fish_salesmain,fish_salesdif,fish_salesprice,fies,fies_worried,fies_healthy,fies_fewfoods,fies_skipped,fies_ateless,fies_ranout,fies_ranout_hhs,fies_hungry,fies_hungry_hhs,fies_whlday,fies_whlday_hhs,copingstrategies,cs_stress_hh_assets,cs_stress_spent_savings,cs_stress_sold_more_animals,cs_stress_eat_elsewhere,cs_stress_borrowed_or_helped,cs_stress_credit,cs_stress_borrowed_money,cs_stress_changed_school,cs_crisis_sold_prod_assets,cs_crisis_no_school,cs_crisis_reduced_health_exp,cs_crisis_harv_immature_crops,cs_crisis_consumed_seed_stocks,cs_crisis_decr_agric_input_exp,cs_emergency_sold_house,cs_emergency_begged,cs_emergency_illegal,cs_emergency_sold_last_female,cs_emergency_hh_migration,hdds_confirmation,need,callback,language,yes_no,derived_fields
# Converting calldispo to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\calldispo
# Converting resp_language to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\resp_language
# Converting introduction to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\introduction
# Converting resp_agree to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\resp_agree
# Converting resp_refusalwhy to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\resp_refusalwhy
# Converting resp_gender to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\resp_gender
# Converting hh_admin1 to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\hh_admin1
# Converting hh_admin2_1 to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\hh_admin2_1
# Converting hh_admin2_2 to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\hh_admin2_2
# Converting quotareached to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\quotareached
# Converting hh_agricactivity to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\hh_agricactivity
# Converting hh_gender to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\hh_gender
# Converting hh_education to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\hh_education
# Converting hh_wealth_water to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\hh_wealth_water
# Converting hh_wealth_toilet to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\hh_wealth_toilet
# Converting hh_wealth_light to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\hh_wealth_light
# Converting hh_residencetype to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\hh_residencetype
# Converting hh_maritalstat to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\hh_maritalstat
# Converting hh_age to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\hh_age
# Converting income_main to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\income_main
# Converting income_main_amount_conf to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\income_main_amount_conf
# Converting income_main_comp to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\income_main_comp
# Converting income_sec to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\income_sec
# Converting income_sec_amount_conf to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\income_sec_amount_conf
# Converting income_sec_comp to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\income_sec_comp
# Converting income_third to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\income_third
# Converting income_third_amount_conf to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\income_third_amount_conf
# Converting income_third_comp to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\income_third_comp
# Converting crp_main to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\crp_main
# Converting crp_landsize to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\crp_landsize
# Converting crp_landright to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\crp_landright
# Converting crp_irrigation to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\crp_irrigation
# Converting crp_area_change to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\crp_area_change
# Converting crp_harv_change to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\crp_harv_change
# Converting crp_proddif to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\crp_proddif
# Converting crp_salesdif to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\crp_salesdif
# Converting crp_salesprice to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\crp_salesprice
# Converting crp_proc to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\crp_proc
# Converting crp_proc_state to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\crp_proc_state
# Converting ls_main to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\ls_main
# Converting ls_proddif to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\ls_proddif
# Converting ls_salesmain to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\ls_salesmain
# Converting ls_salesdif to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\ls_salesdif
# Converting ls_salesprice to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\ls_salesprice
# Converting ls_proc to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\ls_proc
# Converting ls_proc_fac_state to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\ls_proc_fac_state
# Converting fish_change to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\fish_change
# Converting fish_proddif to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\fish_proddif
# Converting fish_salesmain to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\fish_salesmain
# Converting fish_salesdif to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\fish_salesdif
# Converting fish_salesprice to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\fish_salesprice
# Converting fies to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\fies
# Converting fies_worried to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\fies_worried
# Converting fies_healthy to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\fies_healthy
# Converting fies_fewfoods to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\fies_fewfoods
# Converting fies_skipped to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\fies_skipped
# Converting fies_ateless to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\fies_ateless
# Converting fies_ranout to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\fies_ranout
# Converting fies_ranout_hhs to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\fies_ranout_hhs
# Converting fies_hungry to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\fies_hungry
# Converting fies_hungry_hhs to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\fies_hungry_hhs
# Converting fies_whlday to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\fies_whlday
# Converting fies_whlday_hhs to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\fies_whlday_hhs
# Converting copingstrategies to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\copingstrategies
# Converting cs_stress_hh_assets to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\cs_stress_hh_assets
# Converting cs_stress_spent_savings to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\cs_stress_spent_savings
# Converting cs_stress_sold_more_animals to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\cs_stress_sold_more_animals
# Converting cs_stress_eat_elsewhere to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\cs_stress_eat_elsewhere
# Converting cs_stress_borrowed_or_helped to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\cs_stress_borrowed_or_helped
# Converting cs_stress_credit to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\cs_stress_credit
# Converting cs_stress_borrowed_money to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\cs_stress_borrowed_money
# Converting cs_stress_changed_school to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\cs_stress_changed_school
# Converting cs_crisis_sold_prod_assets to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\cs_crisis_sold_prod_assets
# Converting cs_crisis_no_school to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\cs_crisis_no_school
# Converting cs_crisis_reduced_health_exp to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\cs_crisis_reduced_health_exp
# Converting cs_crisis_harv_immature_crops to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\cs_crisis_harv_immature_crops
# Converting cs_crisis_consumed_seed_stocks to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\cs_crisis_consumed_seed_stocks
# Converting cs_crisis_decr_agric_input_exp to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\cs_crisis_decr_agric_input_exp
# Converting cs_emergency_sold_house to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\cs_emergency_sold_house
# Converting cs_emergency_begged to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\cs_emergency_begged
# Converting cs_emergency_illegal to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\cs_emergency_illegal
# Converting cs_emergency_sold_last_female to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\cs_emergency_sold_last_female
# Converting cs_emergency_hh_migration to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\cs_emergency_hh_migration
# Converting hdds_confirmation to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\hdds_confirmation
# Converting need to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\need
# Converting callback to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\callback
# Converting language to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\language
# Converting yes_no to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\yes_no
# Converting derived_fields to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\derived_fields

# %%
###it reads the survey file and creates an excel file with all field names of the outputs table.
###then it imports the empty output table template to the GDB, and calls it master_table. this table will be the future master table
###coded values will be enforced there.
#print(field_names_list)

#insert opening fields that come from Geopoll and are not captured by the questionnaire file
opening_fields = [["survey_id",'TEXT'],["operator_id",'TEXT'],["adm0_name",'TEXT'],["adm0_iso3",'TEXT'],["adm1_pcode",'TEXT'],
                  ["adm1_name",'TEXT'],["adm2_pcode",'TEXT'],["adm2_name",'TEXT'],
["survey_created_date",'TEXT'],["survey_date",'DATE'],["survey_date_text",'TEXT'],["total_case_duration",'SHORT']]#,["weight",'DOUBLE']]


#manage opening fields type
opening_fields_names_text = [i[0] for i in opening_fields if i[1] == 'TEXT']
opening_fields_names_short = [i[0] for i in opening_fields if i[1] == 'SHORT']
opening_fields_names_range = [i[0] for i in opening_fields if i[1] == 'RANGE']
opening_fields_names_date = [i[0] for i in opening_fields if i[1] == 'DATE']
opening_fields_names_double = [i[0] for i in opening_fields if i[1] == 'DOUBLE']

text_type_fields += opening_fields_names_text + single_choice_questions_with_other_categories
#text_type_fields += all_answers_with_other_option
range_type_fields += opening_fields_names_range
double_type_fields += opening_fields_names_double
date_type_fields = opening_fields_names_date

opening_field_names = [i[0] for i in opening_fields]
field_names_list = opening_field_names + field_names_list

#some fields in the questionnaire should be removed from the master table
useless_fields = ['resp_agree', 'callbackmessage_en', 'hh_admin1', 'calldispo', 'hh_admin2_1', 'hh_admin2_2', 'quotareached',
                  'resp_refusalwhy', 'resp_whencallback', 'fies','copingstrategies',
                 "introduction",'hdds_confirmation','income_main_amount_conf','income_sec_amount_conf','income_third_amount_conf',
                  'resp_language','survey_created_date','resp_refusalwhy_otherspecify']


s_useless_fields = set(useless_fields)  

field_names_list = [x for x in field_names_list if x not in s_useless_fields]

#adding specific fields in specific places in the table
field_names_list = insert_element_in_list_after_element(field_names_list, "adm3_pcode", "adm2_name")
field_names_list = insert_element_in_list_after_element(field_names_list, "adm3_name", "adm3_pcode") 
field_names_list = insert_element_in_list_after_element(field_names_list, "round", "survey_date_text") 
field_names_list = insert_element_in_list_after_element(field_names_list, "resp_age_rng", "resp_age") 
field_names_list = insert_element_in_list_after_element(field_names_list, "hh_size_rng", "hh_size")
field_names_list = insert_element_in_list_after_element(field_names_list, "hh_age_rng", "hh_age") 
field_names_list = insert_element_in_list_after_element(field_names_list, "ls_num_diff", "ls_num_now") 

field_names_list = insert_element_in_list_after_element(field_names_list, "tot_income", "income_third_comp") #double
field_names_list = insert_element_in_list_after_element(field_names_list, "crp_main_cc", "crp_proc_state") # long
field_names_list = insert_element_in_list_after_element(field_names_list, "fies_rawscore", "fies_whlday_hhs") #short
field_names_list = insert_element_in_list_after_element(field_names_list, "fies_moderate", "fies_rawscore")
field_names_list = insert_element_in_list_after_element(field_names_list, "fies_severe", "fies_moderate")
field_names_list = insert_element_in_list_after_element(field_names_list, "fies_mod_and_sev", "fies_severe")
field_names_list = insert_element_in_list_after_element(field_names_list, "fies_phase_1", "fies_mod_and_sev")
field_names_list = insert_element_in_list_after_element(field_names_list, "fies_phase_2", "fies_phase_1")
field_names_list = insert_element_in_list_after_element(field_names_list, "fies_phase_3", "fies_phase_2")
field_names_list = insert_element_in_list_after_element(field_names_list, "fies_phase_4", "fies_phase_3")
field_names_list = insert_element_in_list_after_element(field_names_list, "fies_phase_5", "fies_phase_4")
field_names_list = insert_element_in_list_after_element(field_names_list, "lcsi", "cs_emergency_hh_migration") #short
field_names_list = insert_element_in_list_after_element(field_names_list, "hdds_score", "hdds_condiments") #short
field_names_list = insert_element_in_list_after_element(field_names_list, "hdds_class", "hdds_score") #short
field_names_list = insert_element_in_list_after_element(field_names_list, "fcs", "fies_phase_5") #short
field_names_list = insert_element_in_list_after_element(field_names_list, "fcg", "fcs") #short
field_names_list = insert_element_in_list_after_element(field_names_list, "hhs", "fcg") #short
field_names_list = insert_element_in_list_after_element(field_names_list, "hhg", "hhs") #short

FCS_fields = ["fcs_cereal_days","fcs_tubers_days","fcs_staple_days","fcs_pulses_days","fcs_fruit_days","fcs_meat_fish_days",
              "fcs_dairy_days","fcs_sugar_days","fcs_oil_days","fcs_cereal_source","fcs_tubers_source","fcs_staple_source",
              "fcs_pulses_source","fcs_fruit_source","fcs_meat_fish_source","fcs_dairy_source","fcs_sugar_source",
              "fcs_oil_source"] #they are all short, so no need to specify the field type


fcs_counter = 0
for FCS_field in FCS_fields:
    if fcs_counter == 0:
        field_names_list = insert_element_in_list_after_element(field_names_list, FCS_field, "fcs") #short
    else:
        field_names_list = insert_element_in_list_after_element(field_names_list, FCS_field, FCS_fields[fcs_counter-1]) #short
    fcs_counter += 1


rcsi_fields = ["rcsi_less_preferred_foods","rcsi_borrowed_food","rcsi_limit_portions","rcsi_restrict_adult_consumption",
               "rcsi_reduce_number_meals","rcsi_score","rcsi_class"] #they are all short, so no need to specify the field type
rcsi_counter = 0
for rcsi_field in rcsi_fields:
    if rcsi_counter == 0:
        field_names_list = insert_element_in_list_after_element(field_names_list, rcsi_field, "lcsi") #short
    else:
        field_names_list = insert_element_in_list_after_element(field_names_list, rcsi_field, rcsi_fields[rcsi_counter-1]) #short
    rcsi_counter += 1


#declaring type of specific fields just added (if not declared, it will be integer)
text_type_fields.append("adm3_pcode")
text_type_fields.append("adm3_name")
text_type_fields.append("resp_age_rng")
text_type_fields.append("hh_size_rng")
text_type_fields.append("hh_age_rng") 
text_type_fields.append("survey_date_text")
double_type_fields.append("ls_num_diff") #double because it can store negative numbers
range_type_fields.append("crp_main_cc")
double_type_fields.append("ls_num_diff")
double_type_fields.extend(["fies_moderate","fies_severe","fies_mod_and_sev","fies_phase_1","fies_phase_2",
                           "fies_phase_3","fies_phase_4","fies_phase_5"])


other_fields_list = ['covid_other','crp_proc_mach_other','crp_proc_owner_other',
                     'crp_proddif_other','crp_saledif_other','crp_seed_other','fish_inputdif_other','fish_proddif_other',
                     'fish_saledif_other','ls_food_supply_other','ls_num_inc_dec_other',
                     'ls_proc_fac_other','ls_proc_other','ls_proddif_other','ls_salesdif_other','need_other','need_received_other']
for other_field in other_fields_list:
    field_names_list = insert_element_in_list_after_element(field_names_list, other_field + "specify", other_field) 
    text_type_fields.append(other_field + "specify")

field_names_list = insert_element_in_list_after_element(field_names_list, 'crp_otherspecify', "crp_main") 
text_type_fields.append("crp_otherspecify")


#insert closing fields that come from Geopoll and are not captured by the questionnaire file
closing_fields = [["weight_base",'DOUBLE'],["weight_quota",'DOUBLE'],["weight_crop_prod",'DOUBLE'],["weight_livestock_prod",'DOUBLE'],
                  ["weight_wealth",'DOUBLE'], ["weight_gender",'DOUBLE'],["weight_educ",'DOUBLE'],["weight_final",'DOUBLE'],
                  ["percentage",'DOUBLE']
                 ,["qc_step0_date",'DATE'],["qc_step1_date",'DATE'],["qc_step1_username",'TEXT'],["qc_step2_date",'DATE'],
                  ["qc_step2_username",'TEXT'],["qc_enumerator",'TEXT'],["qc_method",'TEXT']]

#manage closing fields type
closing_fields_names_text = [i[0] for i in closing_fields if i[1] == 'TEXT']
closing_fields_names_short = [i[0] for i in closing_fields if i[1] == 'SHORT']
closing_fields_names_range = [i[0] for i in closing_fields if i[1] == 'RANGE']
closing_fields_names_date = [i[0] for i in closing_fields if i[1] == 'DATE']
closing_fields_names_double = [i[0] for i in closing_fields if i[1] == 'DOUBLE']

text_type_fields += closing_fields_names_text
#text_type_fields += all_answers_with_other_option
range_type_fields += closing_fields_names_range
double_type_fields += closing_fields_names_double
date_type_fields += closing_fields_names_date

closing_field_names = [i[0] for i in closing_fields]
field_names_list =  field_names_list + closing_field_names

#we need to collect all 'other' fields from select all that apply (they are all followed by another field called 
# '_otherspecify'), and apply yes no domain
#field_names_list
other_fields_multiple_choice_yes_no_domain = []
for f in field_names_list:
    if f[-6:] == '_other':
        other_fields_multiple_choice_yes_no_domain.append(f)

survey_empty_table_df = pd.DataFrame(columns=[field_names_list])
survey_empty_table_xlsx = os.path.join(temp_path, "survey_empty_table_%s.xlsx" % now)
writer = pd.ExcelWriter(survey_empty_table_xlsx, engine='xlsxwriter')
survey_empty_table_df.to_excel(writer, sheet_name="hh_master_table")
writer.save()
#print(field_names_list)

# %% [markdown]
# field_names_list

# %%
###this section imports the excel file just created into the GDB

importallsheets(survey_empty_table_xlsx, output_gdb)
# Out:
# max_counter: 3000
# 1 sheets found: hh_master_table
# Converting hh_master_table to C:\temp\data_processing_exports\fGDB_with_coded_values_20210802172812.gdb\hh_master_table

# %%
##there is always an unwanted field to remove
try:
    arcpy.DeleteField_management(os.path.join(output_gdb, "hh_master_table"),"COL_A")
except:
    print ("field COL_A does not exist")

# %%
### This section alters each fields type in the survey master table
###domain related fiels shuld be integer, in order to enforce coded values, except crop_main

##string fields: open ended questions + crop_main
##long fields: range and numbers related questions (age, currency, hh size...)
##short fields: coded values questions

GDB_survey_table = os.path.join(output_gdb,"hh_master_table")
field_names = [f.name for f in arcpy.ListFields(GDB_survey_table)]
counter = 0
for field in field_names:
    if field in field_names_list:
        counter +=1
        print("%s) changing type for field %s" % (counter,field))
        try:
            if field in text_type_fields: #crp_main is associated to text codes since they have possible dots (.) for subcategories
                arcpy.management.AlterField(GDB_survey_table, field, field_type = "TEXT")
            elif field == 'crp_main' or field in range_type_fields: #i.e. currencies
                arcpy.management.AlterField(GDB_survey_table, field, field_type = "LONG")
            elif field in double_type_fields: #i.e. weight
                arcpy.management.AlterField(GDB_survey_table, field, field_type = "DOUBLE")
            elif field in date_type_fields: #i.e. survey date
                arcpy.management.AlterField(GDB_survey_table, field, field_type = "DATE")
            else: #all other fields are short integer (simple  code values)
                arcpy.management.AlterField(GDB_survey_table, field, field_type = "SHORT")
        except:
            pass
# Out:
# 1) changing type for field survey_id
# 2) changing type for field operator_id
# 3) changing type for field adm0_name
# 4) changing type for field adm0_iso3
# 5) changing type for field adm1_pcode
# 6) changing type for field adm1_name
# 7) changing type for field adm2_pcode
# 8) changing type for field adm2_name
# 9) changing type for field adm3_pcode
# 10) changing type for field adm3_name
# 11) changing type for field survey_date
# 12) changing type for field survey_date_text
# 13) changing type for field round
# 14) changing type for field total_case_duration
# 15) changing type for field resp_age
# 16) changing type for field resp_age_rng
# 17) changing type for field resp_gender
# 18) changing type for field hh_agricactivity
# 19) changing type for field hh_gender
# 20) changing type for field hh_education
# 21) changing type for field hh_wealth_water
# 22) changing type for field hh_wealth_toilet
# 23) changing type for field hh_wealth_light
# 24) changing type for field hh_residencetype
# 25) changing type for field hh_size
# 26) changing type for field hh_size_rng
# 27) changing type for field hh_maritalstat
# 28) changing type for field hh_age
# 29) changing type for field hh_age_rng
# 30) changing type for field income_main
# 31) changing type for field income_main_amount
# 32) changing type for field income_main_comp
# 33) changing type for field income_sec
# 34) changing type for field income_sec_amount
# 35) changing type for field income_sec_comp
# 36) changing type for field income_third
# 37) changing type for field income_third_amount
# 38) changing type for field income_third_comp
# 39) changing type for field tot_income
# 40) changing type for field covid_goodstransp
# 41) changing type for field covid_marketclosed
# 42) changing type for field covid_borderclosed
# 43) changing type for field covid_stayhome
# 44) changing type for field covid_gatherings
# 45) changing type for field covid_processclosed
# 46) changing type for field covid_other
# 47) changing type for field covid_otherspecify
# 48) changing type for field covid_none
# 49) changing type for field covid_dk
# 50) changing type for field covid_ref
# 51) changing type for field shock_noshock
# 52) changing type for field shock_sicknessordeathofhh
# 53) changing type for field shock_lostemplorwork
# 54) changing type for field shock_otherintrahhshock
# 55) changing type for field shock_higherfoodprices
# 56) changing type for field shock_higherfuelprices
# 57) changing type for field shock_cantworkordobusiness
# 58) changing type for field shock_othereconomicshock
# 59) changing type for field shock_pestoutbreak
# 60) changing type for field shock_plantdisease
# 61) changing type for field shock_animaldisease
# 62) changing type for field shock_napasture
# 63) changing type for field shock_othercropandlivests
# 64) changing type for field shock_coldtemporhail
# 65) changing type for field shock_flood
# 66) changing type for field shock_hurricane
# 67) changing type for field shock_drought
# 68) changing type for field shock_earthquake
# 69) changing type for field shock_landslides
# 70) changing type for field shock_firenatural
# 71) changing type for field shock_othernathazard
# 72) changing type for field shock_violenceinsecconf
# 73) changing type for field shock_theftofprodassets
# 74) changing type for field shock_fire
# 75) changing type for field shock_othermanmadehazard
# 76) changing type for field shock_dk
# 77) changing type for field shock_ref
# 78) changing type for field shock_otherspecify
# 79) changing type for field hh_explanation
# 80) changing type for field crp_main
# 81) changing type for field crp_otherspecify
# 82) changing type for field crp_landsize
# 83) changing type for field crp_landright
# 84) changing type for field crp_landright_otherspecify
# 85) changing type for field crp_irrigation
# 86) changing type for field crp_irrigation_otherspecify
# 87) changing type for field crp_seed_ownprod
# 88) changing type for field crp_seed_market
# 89) changing type for field crp_seed_company
# 90) changing type for field crp_seed_freedist
# 91) changing type for field crp_seed_bank
# 92) changing type for field crp_seed_gov
# 93) changing type for field crp_seed_other
# 94) changing type for field crp_seed_otherspecify
# 95) changing type for field crp_seed_dk
# 96) changing type for field crp_seed_ref
# 97) changing type for field crp_area_change
# 98) changing type for field crp_harv_change
# 99) changing type for field crp_proddif
# 100) changing type for field crp_proddif_plantdisease
# 101) changing type for field crp_proddif_seedquality
# 102) changing type for field crp_proddif_lostordamaged
# 103) changing type for field crp_proddif_naplot
# 104) changing type for field crp_proddif_nafertilizer
# 105) changing type for field crp_proddif_naseeds
# 106) changing type for field crp_proddif_nainsecticides
# 107) changing type for field crp_proddif_nalabour
# 108) changing type for field crp_proddif_namachinery
# 109) changing type for field crp_proddif_nafuelorelect
# 110) changing type for field crp_proddif_soilerosion
# 111) changing type for field crp_proddif_irrigation
# 112) changing type for field crp_proddif_other
# 113) changing type for field crp_proddif_otherspecify
# 114) changing type for field crp_proddif_dk
# 115) changing type for field crp_proddif_ref
# 116) changing type for field crp_salesdif
# 117) changing type for field crp_saledif_marketing_cost
# 118) changing type for field crp_saledif_damagelosses
# 119) changing type for field crp_saledif_lowdemand
# 120) changing type for field crp_saledif_lowprice
# 121) changing type for field crp_saledif_dif_processing
# 122) changing type for field crp_saledif_other
# 123) changing type for field crp_saledif_otherspecify
# 124) changing type for field crp_saledif_dk
# 125) changing type for field crp_saledif_ref
# 126) changing type for field crp_salesprice
# 127) changing type for field crp_proc
# 128) changing type for field crp_proc_mach_mill
# 129) changing type for field crp_proc_mach_thresher
# 130) changing type for field crp_proc_mach_dryingfacilit
# 131) changing type for field crp_proc_mach_none
# 132) changing type for field crp_proc_mach_other
# 133) changing type for field crp_proc_mach_otherspecify
# 134) changing type for field crp_proc_mach_dk
# 135) changing type for field crp_proc_mach_ref
# 136) changing type for field crp_proc_owner_yours
# 137) changing type for field crp_proc_owner_farmin
# 138) changing type for field crp_proc_owner_farmout
# 139) changing type for field crp_proc_owner_millin
# 140) changing type for field crp_proc_owner_millout
# 141) changing type for field crp_proc_owner_other
# 142) changing type for field crp_proc_owner_otherspecify
# 143) changing type for field crp_proc_owner_dk
# 144) changing type for field crp_proc_owner_ref
# 145) changing type for field crp_proc_state
# 146) changing type for field crp_main_cc
# 147) changing type for field ls_main
# 148) changing type for field ls_main_otherspecify
# 149) changing type for field ls_num_lastyr
# 150) changing type for field ls_num_now
# 151) changing type for field ls_num_diff
# 152) changing type for field ls_num_nochange
# 153) changing type for field ls_num_inc_didnotsellasmany
# 154) changing type for field ls_num_inc_moreborn
# 155) changing type for field ls_num_inc_purchbarterdmore
# 156) changing type for field ls_num_inc_receivedfree
# 157) changing type for field ls_num_dec_animalsdied
# 158) changing type for field ls_num_dec_soldmoregoodprice
# 159) changing type for field ls_num_dec_soldmoredistsale
# 160) changing type for field ls_num_dec_anmlescloststolen
# 161) changing type for field ls_num_dec_killedorgaveanml
# 162) changing type for field ls_num_inc_dec_other
# 163) changing type for field ls_num_inc_dec_otherspecify
# 164) changing type for field ls_num_inc_dec_dk
# 165) changing type for field ls_num_inc_dec_ref
# 166) changing type for field ls_food_supply_openpasture
# 167) changing type for field ls_food_supply_commonpasture
# 168) changing type for field ls_food_supply_fieldselfprodfod
# 169) changing type for field ls_food_supply_purchased
# 170) changing type for field ls_food_supply_other
# 171) changing type for field ls_food_supply_otherspecify
# 172) changing type for field ls_food_supply_dk
# 173) changing type for field ls_food_supply_ref
# 174) changing type for field ls_proddif
# 175) changing type for field ls_proddif_diffeedpurchase
# 176) changing type for field ls_proddif_constaccesstopasture
# 177) changing type for field ls_proddif_constaccesstowater
# 178) changing type for field ls_proddif_difaccessvetserv
# 179) changing type for field ls_proddif_difaccessvetinp
# 180) changing type for field ls_proddif_diseases
# 181) changing type for field ls_proddif_theftorinsecurity
# 182) changing type for field ls_proddif_pooraccesstolmarket
# 183) changing type for field ls_proddif_noaccesstocredit
# 184) changing type for field ls_proddif_lackoflabour
# 185) changing type for field ls_proddif_other
# 186) changing type for field ls_proddif_otherspecify
# 187) changing type for field ls_proddif_dk
# 188) changing type for field ls_proddif_ref
# 189) changing type for field ls_salesmain
# 190) changing type for field ls_salesdif
# 191) changing type for field ls_salesdif_smallerprofits
# 192) changing type for field ls_salesdif_damageandlosses
# 193) changing type for field ls_salesdif_lowdemand
# 194) changing type for field ls_salesdif_lowprices
# 195) changing type for field ls_salesdif_slaughterhouse
# 196) changing type for field ls_salesdif_processing
# 197) changing type for field ls_salesdif_other
# 198) changing type for field ls_salesdif_otherspecify
# 199) changing type for field ls_salesdif_dk
# 200) changing type for field ls_salesdif_ref
# 201) changing type for field ls_salesprice
# 202) changing type for field ls_proc
# 203) changing type for field ls_proc_slaughter
# 204) changing type for field ls_proc_meatprocess
# 205) changing type for field ls_proc_dairyprocess
# 206) changing type for field ls_proc_leather
# 207) changing type for field ls_proc_other
# 208) changing type for field ls_proc_otherspecify
# 209) changing type for field ls_proc_dk
# 210) changing type for field ls_proc_ref
# 211) changing type for field ls_proc_fac_priv_cold_transp
# 212) changing type for field ls_proc_fac_coop_cold_transp
# 213) changing type for field ls_proc_fac_slaughterinncomm
# 214) changing type for field ls_proc_fac_slaughteroutofcomm
# 215) changing type for field ls_proc_fac_farm_dairy
# 216) changing type for field ls_proc_fac_coop_dairy
# 217) changing type for field ls_proc_fac_other
# 218) changing type for field ls_proc_fac_otherspecify
# 219) changing type for field ls_proc_fac_none
# 220) changing type for field ls_proc_fac_dk
# 221) changing type for field ls_proc_fac_ref
# 222) changing type for field ls_proc_fac_state
# 223) changing type for field fish_main_coastal
# 224) changing type for field fish_main_opensea
# 225) changing type for field fish_main_lakespondsrivers
# 226) changing type for field fish_main_aquaculture
# 227) changing type for field fish_main_dk
# 228) changing type for field fish_main_ref
# 229) changing type for field fish_change
# 230) changing type for field fish_proddif
# 231) changing type for field fish_proddif_find
# 232) changing type for field fish_proddif_covid
# 233) changing type for field fish_proddif_fuel
# 234) changing type for field fish_proddif_inputs
# 235) changing type for field fish_proddif_labour
# 236) changing type for field fish_proddif_other
# 237) changing type for field fish_proddif_otherspecify
# 238) changing type for field fish_proddif_dk
# 239) changing type for field fish_proddif_ref
# 240) changing type for field fish_inputdif_bait
# 241) changing type for field fish_inputdif_net
# 242) changing type for field fish_inputdif_gear
# 243) changing type for field fish_inputdif_ice
# 244) changing type for field fish_inputdif_fuel
# 245) changing type for field fish_inputdif_boatrepairs
# 246) changing type for field fish_inputdif_other
# 247) changing type for field fish_inputdif_otherspecify
# 248) changing type for field fish_inputdif_dk
# 249) changing type for field fish_inputdif_ref
# 250) changing type for field fish_salesmain
# 251) changing type for field fish_salesmain_otherspecify
# 252) changing type for field fish_salesdif
# 253) changing type for field fish_saledif_smallerprofits
# 254) changing type for field fish_saledif_damageandlosses
# 255) changing type for field fish_saledif_lowdemand
# 256) changing type for field fish_saledif_lowprices
# 257) changing type for field fish_saledif_processing
# 258) changing type for field fish_saledif_other
# 259) changing type for field fish_saledif_otherspecify
# 260) changing type for field fish_saledif_dk
# 261) changing type for field fish_saledif_ref
# 262) changing type for field fish_salesprice
# 263) changing type for field fies_worried
# 264) changing type for field fies_healthy
# 265) changing type for field fies_fewfoods
# 266) changing type for field fies_skipped
# 267) changing type for field fies_ateless
# 268) changing type for field fies_ranout
# 269) changing type for field fies_ranout_hhs
# 270) changing type for field fies_hungry
# 271) changing type for field fies_hungry_hhs
# 272) changing type for field fies_whlday
# 273) changing type for field fies_whlday_hhs
# 274) changing type for field fies_rawscore
# 275) changing type for field fies_moderate
# 276) changing type for field fies_severe
# 277) changing type for field fies_mod_and_sev
# 278) changing type for field fies_phase_1
# 279) changing type for field fies_phase_2
# 280) changing type for field fies_phase_3
# 281) changing type for field fies_phase_4
# 282) changing type for field fies_phase_5
# 283) changing type for field fcs
# 284) changing type for field fcs_cereal_days
# 285) changing type for field fcs_tubers_days
# 286) changing type for field fcs_staple_days
# 287) changing type for field fcs_pulses_days
# 288) changing type for field fcs_fruit_days
# 289) changing type for field fcs_meat_fish_days
# 290) changing type for field fcs_dairy_days
# 291) changing type for field fcs_sugar_days
# 292) changing type for field fcs_oil_days
# 293) changing type for field fcs_cereal_source
# 294) changing type for field fcs_tubers_source
# 295) changing type for field fcs_staple_source
# 296) changing type for field fcs_pulses_source
# 297) changing type for field fcs_fruit_source
# 298) changing type for field fcs_meat_fish_source
# 299) changing type for field fcs_dairy_source
# 300) changing type for field fcs_sugar_source
# 301) changing type for field fcs_oil_source
# 302) changing type for field fcg
# 303) changing type for field hhs
# 304) changing type for field hhg
# 305) changing type for field cs_stress_hh_assets
# 306) changing type for field cs_stress_spent_savings
# 307) changing type for field cs_stress_sold_more_animals
# 308) changing type for field cs_stress_eat_elsewhere
# 309) changing type for field cs_stress_borrowed_or_helped
# 310) changing type for field cs_stress_credit
# 311) changing type for field cs_stress_borrowed_money
# 312) changing type for field cs_stress_changed_school
# 313) changing type for field cs_crisis_sold_prod_assets
# 314) changing type for field cs_crisis_no_school
# 315) changing type for field cs_crisis_reduced_health_exp
# 316) changing type for field cs_crisis_harv_immature_crops
# 317) changing type for field cs_crisis_consumed_seed_stocks
# 318) changing type for field cs_crisis_decr_agric_input_exp
# 319) changing type for field cs_emergency_sold_house
# 320) changing type for field cs_emergency_begged
# 321) changing type for field cs_emergency_illegal
# 322) changing type for field cs_emergency_sold_last_female
# 323) changing type for field cs_emergency_hh_migration
# 324) changing type for field lcsi
# 325) changing type for field rcsi_less_preferred_foods
# 326) changing type for field rcsi_borrowed_food
# 327) changing type for field rcsi_limit_portions
# 328) changing type for field rcsi_restrict_adult_consumption
# 329) changing type for field rcsi_reduce_number_meals
# 330) changing type for field rcsi_score
# 331) changing type for field rcsi_class
# 332) changing type for field hdds_cereals
# 333) changing type for field hdds_rootstubers
# 334) changing type for field hdds_vegetables
# 335) changing type for field hdds_fruits
# 336) changing type for field hdds_meat
# 337) changing type for field hdds_eggs
# 338) changing type for field hdds_fish
# 339) changing type for field hdds_legumes
# 340) changing type for field hdds_milkdairy
# 341) changing type for field hdds_oils
# 342) changing type for field hdds_sugar
# 343) changing type for field hdds_condiments
# 344) changing type for field hdds_score
# 345) changing type for field hdds_class
# 346) changing type for field need
# 347) changing type for field need_seeds
# 348) changing type for field need_fertilizers
# 349) changing type for field need_pesticides
# 350) changing type for field need_tools
# 351) changing type for field need_accesstoirrigationwater
# 352) changing type for field need_accesstoland
# 353) changing type for field need_animalfeed
# 354) changing type for field need_veterinaryservices
# 355) changing type for field need_veterinaryinputs
# 356) changing type for field need_animalsalemingarantdprice
# 357) changing type for field need_restockinganimals
# 358) changing type for field need_supportforprocessprod
# 359) changing type for field need_supptransofanimalsorprod
# 360) changing type for field need_acstomechanisedequipprod
# 361) changing type for field need_marketingsupport
# 362) changing type for field need_cashassistance
# 363) changing type for field need_loans
# 364) changing type for field need_storageequipmentorfaci
# 365) changing type for field need_techsupporextensionserv
# 366) changing type for field need_landrehabilitation
# 367) changing type for field need_fishequiorothersuppforfish
# 368) changing type for field need_infoonsafetymeasures
# 369) changing type for field need_other
# 370) changing type for field need_otherspecify
# 371) changing type for field need_dk
# 372) changing type for field need_ref
# 373) changing type for field need_received_food
# 374) changing type for field need_received_cashvouchers
# 375) changing type for field need_received_seeds
# 376) changing type for field need_received_extensionservices
# 377) changing type for field need_received_livestockfeed
# 378) changing type for field need_received_other
# 379) changing type for field need_received_otherspecify
# 380) changing type for field need_received_noassistreceived
# 381) changing type for field need_received_dk
# 382) changing type for field need_received_ref
# 383) changing type for field callback
# 384) changing type for field language
# 385) changing type for field weight_base
# 386) changing type for field weight_quota
# 387) changing type for field weight_crop_prod
# 388) changing type for field weight_livestock_prod
# 389) changing type for field weight_wealth
# 390) changing type for field weight_gender
# 391) changing type for field weight_educ
# 392) changing type for field weight_final
# 393) changing type for field percentage
# 394) changing type for field qc_step0_date
# 395) changing type for field qc_step1_date
# 396) changing type for field qc_step1_username
# 397) changing type for field qc_step2_date
# 398) changing type for field qc_step2_username
# 399) changing type for field qc_enumerator
# 400) changing type for field qc_method

# %%
def create_and_apply_domain(master_table, domain_table, field_name, domain_already_exists):
    # Process: Create the coded value domain
    domName = '%s_dom' % domain_table
    if not domain_already_exists:
        if domain_table == 'crp_main':
            field_type = "LONG"
        else:
            field_type = "SHORT"
        try:
            arcpy.CreateDomain_management(output_gdb, domName, field_type= field_type)
        except Exception as e:
            print(e)
        # Store all the domain values in a dictionary with the domain code as the "key" 
        # and the domain description as the "value" (domDict[code])

        domDict = make_attribute_dict(domain_table, 'code', 'label')
        #print(domDict)

        #   dict example:  {"CI":"Cast iron", "DI": "Ductile iron", "PVC": "PVC", 
        #                "ACP": "Asbestos concrete", "COP": "Copper"}

        # Process: Add valid material types to the domain
        # use a for loop to cycle through all the domain codes in the dictionary
        for code in domDict:
            try:
                arcpy.AddCodedValueToDomain_management(output_gdb, domName, code, domDict[code])
            except:
                print("AddCodedValueToDomain_management failed")


    arcpy.AssignDomainToField_management(master_table, field_name, domName)

# %%
##THis section of the script searches for all domains tables in the GDB
##then, for each table  it creates a new domain,
###it stores all domain values in a dictionary, it add each code domain, and finally assign the domain to the right field (having same name)

# Set the current workspace
arcpy.env.workspace = output_gdb

# Get and print a list of tables
tables = arcpy.ListTables()
master_table = os.path.join(output_gdb,'hh_master_table')

print("---APPLYING DOMAINS FOR SINGLE CHOICE FIELDS---")
counter = 0
for table in tables:
    if 'master_table' not in table and table not in useless_fields and  'derived_fields' not in table:
        #print(table)
        if table == "yes_no":
            yes_no_table_for_later = table ##we dont have a yes_no field to which apply the domain
        else:
            counter += 1
            print ("%s) Creating and Applying (new) domain for field %s" % (counter, table))
            create_and_apply_domain(master_table, table, table, False) #domain_table has the same name of the field where it should be applied
            if table == 'crp_main':
                print ("%s) Creating and Applying (new) domain for field crp_main_cc" % (counter))
                create_and_apply_domain(master_table, table, 'crp_main_cc', False) #same domains should be applied to this field (derived, calulcated by Amandine)
# Out:
# ---APPLYING DOMAINS FOR SINGLE CHOICE FIELDS---
# 1) Creating and Applying (new) domain for field resp_gender
# 2) Creating and Applying (new) domain for field hh_agricactivity
# 3) Creating and Applying (new) domain for field hh_gender
# 4) Creating and Applying (new) domain for field hh_education
# 5) Creating and Applying (new) domain for field hh_wealth_water
# 6) Creating and Applying (new) domain for field hh_wealth_toilet
# 7) Creating and Applying (new) domain for field hh_wealth_light
# 8) Creating and Applying (new) domain for field hh_residencetype
# 9) Creating and Applying (new) domain for field hh_maritalstat
# 10) Creating and Applying (new) domain for field hh_age
# 11) Creating and Applying (new) domain for field income_main
# 12) Creating and Applying (new) domain for field income_main_comp
# 13) Creating and Applying (new) domain for field income_sec
# 14) Creating and Applying (new) domain for field income_sec_comp
# 15) Creating and Applying (new) domain for field income_third
# 16) Creating and Applying (new) domain for field income_third_comp
# 17) Creating and Applying (new) domain for field crp_main
# 17) Creating and Applying (new) domain for field crp_main_cc
# Failed to execute. Parameters are not valid.
# ERROR 000192: Invalid value for Domain Name
# Failed to execute (CreateDomain).
#
# 18) Creating and Applying (new) domain for field crp_landsize
# 19) Creating and Applying (new) domain for field crp_landright
# 20) Creating and Applying (new) domain for field crp_irrigation
# 21) Creating and Applying (new) domain for field crp_area_change
# 22) Creating and Applying (new) domain for field crp_harv_change
# 23) Creating and Applying (new) domain for field crp_proddif
# 24) Creating and Applying (new) domain for field crp_salesdif
# 25) Creating and Applying (new) domain for field crp_salesprice
# 26) Creating and Applying (new) domain for field crp_proc
# 27) Creating and Applying (new) domain for field crp_proc_state
# 28) Creating and Applying (new) domain for field ls_main
# 29) Creating and Applying (new) domain for field ls_proddif
# 30) Creating and Applying (new) domain for field ls_salesmain
# 31) Creating and Applying (new) domain for field ls_salesdif
# 32) Creating and Applying (new) domain for field ls_salesprice
# 33) Creating and Applying (new) domain for field ls_proc
# 34) Creating and Applying (new) domain for field ls_proc_fac_state
# 35) Creating and Applying (new) domain for field fish_change
# 36) Creating and Applying (new) domain for field fish_proddif
# 37) Creating and Applying (new) domain for field fish_salesmain
# 38) Creating and Applying (new) domain for field fish_salesdif
# 39) Creating and Applying (new) domain for field fish_salesprice
# 40) Creating and Applying (new) domain for field fies_worried
# 41) Creating and Applying (new) domain for field fies_healthy
# 42) Creating and Applying (new) domain for field fies_fewfoods
# 43) Creating and Applying (new) domain for field fies_skipped
# 44) Creating and Applying (new) domain for field fies_ateless
# 45) Creating and Applying (new) domain for field fies_ranout
# 46) Creating and Applying (new) domain for field fies_ranout_hhs
# 47) Creating and Applying (new) domain for field fies_hungry
# 48) Creating and Applying (new) domain for field fies_hungry_hhs
# 49) Creating and Applying (new) domain for field fies_whlday
# 50) Creating and Applying (new) domain for field fies_whlday_hhs
# 51) Creating and Applying (new) domain for field cs_stress_hh_assets
# 52) Creating and Applying (new) domain for field cs_stress_spent_savings
# 53) Creating and Applying (new) domain for field cs_stress_sold_more_animals
# 54) Creating and Applying (new) domain for field cs_stress_eat_elsewhere
# 55) Creating and Applying (new) domain for field cs_stress_borrowed_or_helped
# 56) Creating and Applying (new) domain for field cs_stress_credit
# 57) Creating and Applying (new) domain for field cs_stress_borrowed_money
# 58) Creating and Applying (new) domain for field cs_stress_changed_school
# 59) Creating and Applying (new) domain for field cs_crisis_sold_prod_assets
# 60) Creating and Applying (new) domain for field cs_crisis_no_school
# 61) Creating and Applying (new) domain for field cs_crisis_reduced_health_exp
# 62) Creating and Applying (new) domain for field cs_crisis_harv_immature_crops
# 63) Creating and Applying (new) domain for field cs_crisis_consumed_seed_stocks
# 64) Creating and Applying (new) domain for field cs_crisis_decr_agric_input_exp
# 65) Creating and Applying (new) domain for field cs_emergency_sold_house
# 66) Creating and Applying (new) domain for field cs_emergency_begged
# 67) Creating and Applying (new) domain for field cs_emergency_illegal
# 68) Creating and Applying (new) domain for field cs_emergency_sold_last_female
# 69) Creating and Applying (new) domain for field cs_emergency_hh_migration
# 70) Creating and Applying (new) domain for field need
# 71) Creating and Applying (new) domain for field callback
# 72) Creating and Applying (new) domain for field language

# %%
print("---APPLYING DOMAINS FOR MULTIPLE CHOICE DERIVED FIELDS---")
yes_no_domain_created = False
counter = 0
for derived_field in all_derived_fieldnames:
    if derived_field not in all_answers_with_other_option: #'other' fields, are strings without domains #changed!
        counter +=1
        if not yes_no_domain_created:
            print ("%s) Creating and applying new YES-NO domain (table %s) for derivate field %s" % (counter, yes_no_table_for_later,derived_field))
            create_and_apply_domain(master_table, yes_no_table_for_later, derived_field, False)
            yes_no_domain_created = True
        else:
            print ("%s) Applying existing YES-NO domain for derivate field %s" % (counter,derived_field))
            create_and_apply_domain(master_table, yes_no_table_for_later, derived_field, True)
# Out:
# ---APPLYING DOMAINS FOR MULTIPLE CHOICE DERIVED FIELDS---
# 1) Creating and applying new YES-NO domain (table yes_no) for derivate field covid_goodstransp
# 2) Applying existing YES-NO domain for derivate field covid_marketclosed
# 3) Applying existing YES-NO domain for derivate field covid_borderclosed
# 4) Applying existing YES-NO domain for derivate field covid_stayhome
# 5) Applying existing YES-NO domain for derivate field covid_gatherings
# 6) Applying existing YES-NO domain for derivate field covid_processclosed
# 7) Applying existing YES-NO domain for derivate field covid_none
# 8) Applying existing YES-NO domain for derivate field covid_dk
# 9) Applying existing YES-NO domain for derivate field covid_ref
# 10) Applying existing YES-NO domain for derivate field shock_noshock
# 11) Applying existing YES-NO domain for derivate field shock_sicknessordeathofhh
# 12) Applying existing YES-NO domain for derivate field shock_lostemplorwork
# 13) Applying existing YES-NO domain for derivate field shock_otherintrahhshock
# 14) Applying existing YES-NO domain for derivate field shock_higherfoodprices
# 15) Applying existing YES-NO domain for derivate field shock_higherfuelprices
# 16) Applying existing YES-NO domain for derivate field shock_cantworkordobusiness
# 17) Applying existing YES-NO domain for derivate field shock_othereconomicshock
# 18) Applying existing YES-NO domain for derivate field shock_pestoutbreak
# 19) Applying existing YES-NO domain for derivate field shock_plantdisease
# 20) Applying existing YES-NO domain for derivate field shock_animaldisease
# 21) Applying existing YES-NO domain for derivate field shock_napasture
# 22) Applying existing YES-NO domain for derivate field shock_othercropandlivests
# 23) Applying existing YES-NO domain for derivate field shock_coldtemporhail
# 24) Applying existing YES-NO domain for derivate field shock_flood
# 25) Applying existing YES-NO domain for derivate field shock_hurricane
# 26) Applying existing YES-NO domain for derivate field shock_drought
# 27) Applying existing YES-NO domain for derivate field shock_earthquake
# 28) Applying existing YES-NO domain for derivate field shock_landslides
# 29) Applying existing YES-NO domain for derivate field shock_firenatural
# 30) Applying existing YES-NO domain for derivate field shock_othernathazard
# 31) Applying existing YES-NO domain for derivate field shock_violenceinsecconf
# 32) Applying existing YES-NO domain for derivate field shock_theftofprodassets
# 33) Applying existing YES-NO domain for derivate field shock_fire
# 34) Applying existing YES-NO domain for derivate field shock_othermanmadehazard
# 35) Applying existing YES-NO domain for derivate field shock_dk
# 36) Applying existing YES-NO domain for derivate field shock_ref
# 37) Applying existing YES-NO domain for derivate field crp_seed_ownprod
# 38) Applying existing YES-NO domain for derivate field crp_seed_market
# 39) Applying existing YES-NO domain for derivate field crp_seed_company
# 40) Applying existing YES-NO domain for derivate field crp_seed_freedist
# 41) Applying existing YES-NO domain for derivate field crp_seed_bank
# 42) Applying existing YES-NO domain for derivate field crp_seed_gov
# 43) Applying existing YES-NO domain for derivate field crp_seed_dk
# 44) Applying existing YES-NO domain for derivate field crp_seed_ref
# 45) Applying existing YES-NO domain for derivate field crp_proddif_plantdisease
# 46) Applying existing YES-NO domain for derivate field crp_proddif_seedquality
# 47) Applying existing YES-NO domain for derivate field crp_proddif_lostordamaged
# 48) Applying existing YES-NO domain for derivate field crp_proddif_naplot
# 49) Applying existing YES-NO domain for derivate field crp_proddif_nafertilizer
# 50) Applying existing YES-NO domain for derivate field crp_proddif_naseeds
# 51) Applying existing YES-NO domain for derivate field crp_proddif_nainsecticides
# 52) Applying existing YES-NO domain for derivate field crp_proddif_nalabour
# 53) Applying existing YES-NO domain for derivate field crp_proddif_namachinery
# 54) Applying existing YES-NO domain for derivate field crp_proddif_nafuelorelect
# 55) Applying existing YES-NO domain for derivate field crp_proddif_soilerosion
# 56) Applying existing YES-NO domain for derivate field crp_proddif_irrigation
# 57) Applying existing YES-NO domain for derivate field crp_proddif_dk
# 58) Applying existing YES-NO domain for derivate field crp_proddif_ref
# 59) Applying existing YES-NO domain for derivate field crp_saledif_marketing_cost
# 60) Applying existing YES-NO domain for derivate field crp_saledif_damagelosses
# 61) Applying existing YES-NO domain for derivate field crp_saledif_lowdemand
# 62) Applying existing YES-NO domain for derivate field crp_saledif_lowprice
# 63) Applying existing YES-NO domain for derivate field crp_saledif_dif_processing
# 64) Applying existing YES-NO domain for derivate field crp_saledif_dk
# 65) Applying existing YES-NO domain for derivate field crp_saledif_ref
# 66) Applying existing YES-NO domain for derivate field crp_proc_mach_mill
# 67) Applying existing YES-NO domain for derivate field crp_proc_mach_thresher
# 68) Applying existing YES-NO domain for derivate field crp_proc_mach_dryingfacilit
# 69) Applying existing YES-NO domain for derivate field crp_proc_mach_none
# 70) Applying existing YES-NO domain for derivate field crp_proc_mach_dk
# 71) Applying existing YES-NO domain for derivate field crp_proc_mach_ref
# 72) Applying existing YES-NO domain for derivate field crp_proc_owner_yours
# 73) Applying existing YES-NO domain for derivate field crp_proc_owner_farmin
# 74) Applying existing YES-NO domain for derivate field crp_proc_owner_farmout
# 75) Applying existing YES-NO domain for derivate field crp_proc_owner_millin
# 76) Applying existing YES-NO domain for derivate field crp_proc_owner_millout
# 77) Applying existing YES-NO domain for derivate field crp_proc_owner_dk
# 78) Applying existing YES-NO domain for derivate field crp_proc_owner_ref
# 79) Applying existing YES-NO domain for derivate field ls_num_nochange
# 80) Applying existing YES-NO domain for derivate field ls_num_inc_didnotsellasmany
# 81) Applying existing YES-NO domain for derivate field ls_num_inc_moreborn
# 82) Applying existing YES-NO domain for derivate field ls_num_inc_purchbarterdmore
# 83) Applying existing YES-NO domain for derivate field ls_num_inc_receivedfree
# 84) Applying existing YES-NO domain for derivate field ls_num_dec_animalsdied
# 85) Applying existing YES-NO domain for derivate field ls_num_dec_soldmoregoodprice
# 86) Applying existing YES-NO domain for derivate field ls_num_dec_soldmoredistsale
# 87) Applying existing YES-NO domain for derivate field ls_num_dec_anmlescloststolen
# 88) Applying existing YES-NO domain for derivate field ls_num_dec_killedorgaveanml
# 89) Applying existing YES-NO domain for derivate field ls_num_inc_dec_dk
# 90) Applying existing YES-NO domain for derivate field ls_num_inc_dec_ref
# 91) Applying existing YES-NO domain for derivate field ls_food_supply_openpasture
# 92) Applying existing YES-NO domain for derivate field ls_food_supply_commonpasture
# 93) Applying existing YES-NO domain for derivate field ls_food_supply_fieldselfprodfod
# 94) Applying existing YES-NO domain for derivate field ls_food_supply_purchased
# 95) Applying existing YES-NO domain for derivate field ls_food_supply_dk
# 96) Applying existing YES-NO domain for derivate field ls_food_supply_ref
# 97) Applying existing YES-NO domain for derivate field ls_proddif_diffeedpurchase
# 98) Applying existing YES-NO domain for derivate field ls_proddif_constaccesstopasture
# 99) Applying existing YES-NO domain for derivate field ls_proddif_constaccesstowater
# 100) Applying existing YES-NO domain for derivate field ls_proddif_difaccessvetserv
# 101) Applying existing YES-NO domain for derivate field ls_proddif_difaccessvetinp
# 102) Applying existing YES-NO domain for derivate field ls_proddif_diseases
# 103) Applying existing YES-NO domain for derivate field ls_proddif_theftorinsecurity
# 104) Applying existing YES-NO domain for derivate field ls_proddif_pooraccesstolmarket
# 105) Applying existing YES-NO domain for derivate field ls_proddif_noaccesstocredit
# 106) Applying existing YES-NO domain for derivate field ls_proddif_lackoflabour
# 107) Applying existing YES-NO domain for derivate field ls_proddif_dk
# 108) Applying existing YES-NO domain for derivate field ls_proddif_ref
# 109) Applying existing YES-NO domain for derivate field ls_salesdif_smallerprofits
# 110) Applying existing YES-NO domain for derivate field ls_salesdif_damageandlosses
# 111) Applying existing YES-NO domain for derivate field ls_salesdif_lowdemand
# 112) Applying existing YES-NO domain for derivate field ls_salesdif_lowprices
# 113) Applying existing YES-NO domain for derivate field ls_salesdif_slaughterhouse
# 114) Applying existing YES-NO domain for derivate field ls_salesdif_processing
# 115) Applying existing YES-NO domain for derivate field ls_salesdif_dk
# 116) Applying existing YES-NO domain for derivate field ls_salesdif_ref
# 117) Applying existing YES-NO domain for derivate field ls_proc_slaughter
# 118) Applying existing YES-NO domain for derivate field ls_proc_meatprocess
# 119) Applying existing YES-NO domain for derivate field ls_proc_dairyprocess
# 120) Applying existing YES-NO domain for derivate field ls_proc_leather
# 121) Applying existing YES-NO domain for derivate field ls_proc_dk
# 122) Applying existing YES-NO domain for derivate field ls_proc_ref
# 123) Applying existing YES-NO domain for derivate field ls_proc_fac_priv_cold_transp
# 124) Applying existing YES-NO domain for derivate field ls_proc_fac_coop_cold_transp
# 125) Applying existing YES-NO domain for derivate field ls_proc_fac_slaughterinncomm
# 126) Applying existing YES-NO domain for derivate field ls_proc_fac_slaughteroutofcomm
# 127) Applying existing YES-NO domain for derivate field ls_proc_fac_farm_dairy
# 128) Applying existing YES-NO domain for derivate field ls_proc_fac_coop_dairy
# 129) Applying existing YES-NO domain for derivate field ls_proc_fac_none
# 130) Applying existing YES-NO domain for derivate field ls_proc_fac_dk
# 131) Applying existing YES-NO domain for derivate field ls_proc_fac_ref
# 132) Applying existing YES-NO domain for derivate field fish_main_coastal
# 133) Applying existing YES-NO domain for derivate field fish_main_opensea
# 134) Applying existing YES-NO domain for derivate field fish_main_lakespondsrivers
# 135) Applying existing YES-NO domain for derivate field fish_main_aquaculture
# 136) Applying existing YES-NO domain for derivate field fish_main_dk
# 137) Applying existing YES-NO domain for derivate field fish_main_ref
# 138) Applying existing YES-NO domain for derivate field fish_proddif_find
# 139) Applying existing YES-NO domain for derivate field fish_proddif_covid
# 140) Applying existing YES-NO domain for derivate field fish_proddif_fuel
# 141) Applying existing YES-NO domain for derivate field fish_proddif_inputs
# 142) Applying existing YES-NO domain for derivate field fish_proddif_labour
# 143) Applying existing YES-NO domain for derivate field fish_proddif_dk
# 144) Applying existing YES-NO domain for derivate field fish_proddif_ref
# 145) Applying existing YES-NO domain for derivate field fish_inputdif_bait
# 146) Applying existing YES-NO domain for derivate field fish_inputdif_net
# 147) Applying existing YES-NO domain for derivate field fish_inputdif_gear
# 148) Applying existing YES-NO domain for derivate field fish_inputdif_ice
# 149) Applying existing YES-NO domain for derivate field fish_inputdif_fuel
# 150) Applying existing YES-NO domain for derivate field fish_inputdif_boatrepairs
# 151) Applying existing YES-NO domain for derivate field fish_inputdif_dk
# 152) Applying existing YES-NO domain for derivate field fish_inputdif_ref
# 153) Applying existing YES-NO domain for derivate field fish_saledif_smallerprofits
# 154) Applying existing YES-NO domain for derivate field fish_saledif_damageandlosses
# 155) Applying existing YES-NO domain for derivate field fish_saledif_lowdemand
# 156) Applying existing YES-NO domain for derivate field fish_saledif_lowprices
# 157) Applying existing YES-NO domain for derivate field fish_saledif_processing
# 158) Applying existing YES-NO domain for derivate field fish_saledif_dk
# 159) Applying existing YES-NO domain for derivate field fish_saledif_ref
# 160) Applying existing YES-NO domain for derivate field hdds_cereals
# 161) Applying existing YES-NO domain for derivate field hdds_rootstubers
# 162) Applying existing YES-NO domain for derivate field hdds_vegetables
# 163) Applying existing YES-NO domain for derivate field hdds_fruits
# 164) Applying existing YES-NO domain for derivate field hdds_meat
# 165) Applying existing YES-NO domain for derivate field hdds_eggs
# 166) Applying existing YES-NO domain for derivate field hdds_fish
# 167) Applying existing YES-NO domain for derivate field hdds_legumes
# 168) Applying existing YES-NO domain for derivate field hdds_milkdairy
# 169) Applying existing YES-NO domain for derivate field hdds_oils
# 170) Applying existing YES-NO domain for derivate field hdds_sugar
# 171) Applying existing YES-NO domain for derivate field hdds_condiments
# 172) Applying existing YES-NO domain for derivate field need_seeds
# 173) Applying existing YES-NO domain for derivate field need_fertilizers
# 174) Applying existing YES-NO domain for derivate field need_pesticides
# 175) Applying existing YES-NO domain for derivate field need_tools
# 176) Applying existing YES-NO domain for derivate field need_accesstoirrigationwater
# 177) Applying existing YES-NO domain for derivate field need_accesstoland
# 178) Applying existing YES-NO domain for derivate field need_animalfeed
# 179) Applying existing YES-NO domain for derivate field need_veterinaryservices
# 180) Applying existing YES-NO domain for derivate field need_veterinaryinputs
# 181) Applying existing YES-NO domain for derivate field need_animalsalemingarantdprice
# 182) Applying existing YES-NO domain for derivate field need_restockinganimals
# 183) Applying existing YES-NO domain for derivate field need_supportforprocessprod
# 184) Applying existing YES-NO domain for derivate field need_supptransofanimalsorprod
# 185) Applying existing YES-NO domain for derivate field need_acstomechanisedequipprod
# 186) Applying existing YES-NO domain for derivate field need_marketingsupport
# 187) Applying existing YES-NO domain for derivate field need_cashassistance
# 188) Applying existing YES-NO domain for derivate field need_loans
# 189) Applying existing YES-NO domain for derivate field need_storageequipmentorfaci
# 190) Applying existing YES-NO domain for derivate field need_techsupporextensionserv
# 191) Applying existing YES-NO domain for derivate field need_landrehabilitation
# 192) Applying existing YES-NO domain for derivate field need_fishequiorothersuppforfish
# 193) Applying existing YES-NO domain for derivate field need_infoonsafetymeasures
# 194) Applying existing YES-NO domain for derivate field need_dk
# 195) Applying existing YES-NO domain for derivate field need_ref
# 196) Applying existing YES-NO domain for derivate field need_received_food
# 197) Applying existing YES-NO domain for derivate field need_received_cashvouchers
# 198) Applying existing YES-NO domain for derivate field need_received_seeds
# 199) Applying existing YES-NO domain for derivate field need_received_extensionservices
# 200) Applying existing YES-NO domain for derivate field need_received_livestockfeed
# 201) Applying existing YES-NO domain for derivate field need_received_noassistreceived
# 202) Applying existing YES-NO domain for derivate field need_received_dk
# 203) Applying existing YES-NO domain for derivate field need_received_ref

# %%
counter = 0        
for other_field in other_fields_multiple_choice_yes_no_domain:
    counter +=1
    print ("%s) Applying existing YES-NO domain for ''other'' field %s" % (counter,other_field))
    create_and_apply_domain(master_table, yes_no_table_for_later, other_field, True)
# Out:
# 1) Applying existing YES-NO domain for ''other'' field covid_other
# 2) Applying existing YES-NO domain for ''other'' field crp_seed_other
# 3) Applying existing YES-NO domain for ''other'' field crp_proddif_other
# 4) Applying existing YES-NO domain for ''other'' field crp_saledif_other
# 5) Applying existing YES-NO domain for ''other'' field crp_proc_mach_other
# 6) Applying existing YES-NO domain for ''other'' field crp_proc_owner_other
# 7) Applying existing YES-NO domain for ''other'' field ls_num_inc_dec_other
# 8) Applying existing YES-NO domain for ''other'' field ls_food_supply_other
# 9) Applying existing YES-NO domain for ''other'' field ls_proddif_other
# 10) Applying existing YES-NO domain for ''other'' field ls_salesdif_other
# 11) Applying existing YES-NO domain for ''other'' field ls_proc_other
# 12) Applying existing YES-NO domain for ''other'' field ls_proc_fac_other
# 13) Applying existing YES-NO domain for ''other'' field fish_proddif_other
# 14) Applying existing YES-NO domain for ''other'' field fish_inputdif_other
# 15) Applying existing YES-NO domain for ''other'' field fish_saledif_other
# 16) Applying existing YES-NO domain for ''other'' field need_other
# 17) Applying existing YES-NO domain for ''other'' field need_received_other

# %%
##APPLYING DOMAINS FOR INDICATORS (variables added during the analysis phase and not present in the questionnaire)

#print(indicators_fields) #at the end, this list is used only for copypasting and create the following dictionary


indicators_domains_dict = {'rcsi_less_preferred_foods':[0,1,2,3,4,5,6,7],'rcsi_borrowed_food':[0,1,2,3,4,5,6,7],
                           'rcsi_limit_portions':[0,1,2,3,4,5,6,7],'rcsi_restrict_adult_consumption':[0,1,2,3,4,5,6,7],
                           'rcsi_reduce_number_meals':[0,1,2,3,4,5,6,7],'rcsi_score':[0,56],'rcsi_class':[0,1,2,3],
                           'fies_rawscore':[0,1,2,3,4,5,6,7,8],'lcsi':[0,1,2,3],'hdds_score':[0,12],
                           'hdds_class':[1,2,3],'hhs':[0,6],'hhg':[0,5],'fcs':[0,112],'fcg':[1,2,3],
                          'fcs_cereal_days':[0,7],'fcs_tubers_days':[0,7],'fcs_staple_days':[0,7],'fcs_pulses_days':[0,7],
                           'fcs_fruit_days':[0,7],'fcs_meat_fish_days':[0,7],'fcs_dairy_days':[0,7],'fcs_sugar_days':[0,7],'fcs_oil_days':[0,7],
                          'fcs_cereal_source':[0,10],'fcs_tubers_source':[0,10],'fcs_staple_source':[0,10],'fcs_pulses_source':[0,10],
                           'fcs_fruit_source':[0,10],'fcs_meat_fish_source':[0,10],'fcs_dairy_source':[0,10],'fcs_sugar_source':[0,10],
                           'fcs_oil_source':[0,10]}


for field, rangedomain in indicators_domains_dict.items():
    try:
        domName = field + "_dom"
        # Process: Create the range domain
        print("CreateDomain for derived field %s" % field)
#         try:
        arcpy.CreateDomain_management(output_gdb, domName, field_type = "SHORT", domain_type = "RANGE")
#         except: 
#             print ("Domain %s already exists" % domName)
        
        # Process: Set the minimum and maximum values for the range domain
        #print("SetValueForRangeDomain from %s to %s" % (rangedomain[0], rangedomain[-1]))
        arcpy.SetValueForRangeDomain_management(output_gdb, domName, rangedomain[0], rangedomain[-1])

        # Process: Constrain the fitting rotation angle
        #print("AssignDomainToField")
        arcpy.AssignDomainToField_management(master_table, field, domName)
    except Exception as e: 
        print(e)
        print("Domain creation failed for derived field %s" % field)
# Out:
# CreateDomain for derived field rcsi_less_preferred_foods
# CreateDomain for derived field rcsi_borrowed_food
# CreateDomain for derived field rcsi_limit_portions
# CreateDomain for derived field rcsi_restrict_adult_consumption
# CreateDomain for derived field rcsi_reduce_number_meals
# CreateDomain for derived field rcsi_score
# CreateDomain for derived field rcsi_class
# CreateDomain for derived field fies_rawscore
# CreateDomain for derived field lcsi
# CreateDomain for derived field hdds_score
# CreateDomain for derived field hdds_class
# CreateDomain for derived field hhs
# CreateDomain for derived field hhg
# CreateDomain for derived field fcs
# CreateDomain for derived field fcg
# CreateDomain for derived field fcs_cereal_days
# CreateDomain for derived field fcs_tubers_days
# CreateDomain for derived field fcs_staple_days
# CreateDomain for derived field fcs_pulses_days
# CreateDomain for derived field fcs_fruit_days
# CreateDomain for derived field fcs_meat_fish_days
# CreateDomain for derived field fcs_dairy_days
# CreateDomain for derived field fcs_sugar_days
# CreateDomain for derived field fcs_oil_days
# CreateDomain for derived field fcs_cereal_source
# CreateDomain for derived field fcs_tubers_source
# CreateDomain for derived field fcs_staple_source
# CreateDomain for derived field fcs_pulses_source
# CreateDomain for derived field fcs_fruit_source
# CreateDomain for derived field fcs_meat_fish_source
# CreateDomain for derived field fcs_dairy_source
# CreateDomain for derived field fcs_sugar_source
# CreateDomain for derived field fcs_oil_source

# %%
print("Adding Global ID")
arcpy.AddGlobalIDs_management(master_table)
# Out:
# Adding Global ID
# <Result 'C:\\temp\\data_processing_exports\\fGDB_with_coded_values_20210802172812.gdb\\hh_master_table'>

# %%
arcpy.TableToTable_conversion(master_table, temp_path, "hh_master_table_%s.csv" % now)
# Out:
# <Result 'C:\\temp\\data_processing_exports\\hh_master_table_20210802172812.csv'>

# %%
print("Execution time: ", datetime.now() - startTime)
# Out:
# Execution time:  0:26:59.485545
