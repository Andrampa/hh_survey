# %%
import pandas as pd
import xlrd
import arcpy
from pandas import ExcelWriter
from datetime import datetime
import os

# %%
now = datetime.now().strftime('%Y%m%d%H%M%S')
temp_path = r'C:\temp\data_processing_exports'
questionnaire_file = r'C:\git\hh_survey\R3 questionnaire_GeoPoll_final.xlsx' #the questionnaire file that we use for creating the table
coded_values_file = os.path.join(temp_path, "coded_values_%s.xlsx" % now) #intermediary output file with all categories and codes extracted from the questionnaire
writer = pd.ExcelWriter(coded_values_file, engine='xlsxwriter')
field_names_list = []
max_counter = 3000 #for testing purposes, we may need to limit the execution only to some items

# %%
def importallsheets(in_excel, out_gdb):
    ###this function import all sheets of an xlsx file into separate tables inside a GDB (with same name)
    print("max_counter: %s" % max_counter)
    counter = 0
    workbook = xlrd.open_workbook(in_excel)
    sheets = [sheet.name for sheet in workbook.sheets()]

    print('{} sheets found: {}'.format(len(sheets), ','.join(sheets)))
    for sheet in sheets:
        counter +=1
        if counter <= max_counter:
            # The out_table is based on the input excel file name
            # a underscore (_) separator followed by the sheet name
            out_table = os.path.join(
                out_gdb,
                arcpy.ValidateTableName(
                    "{0}".format(sheet),
                    out_gdb))

            print('Converting {} to {}'.format(sheet, out_table))

            # Perform the conversion
            arcpy.ExcelToTable_conversion(in_excel, out_table, sheet)
            

def make_attribute_dict(fc, code_field, value_field):
    #this function creates a dictionary based on a GDB table
    attdict = {}
    with arcpy.da.SearchCursor(fc, [code_field, value_field]) as cursor:
        for row in cursor:
            attdict[row[0]] = row[1]
    return attdict

def fix_category_formatting(category):
    #this function improves and standardizes the formatting of the categories' descriptions
     return category.replace("[","(").replace("]",")").replace("(specify)","").replace("/ ",", ").capitalize().replace("adps","ADPs").replace("idp","IDP").replace("covid","COVID")

# %%
##this section of the script reads the survey excel file and creates an excel file with multiple sheets:
### each sheet contains the coded value and description for a "Single choice" or "Open Ended-Select All That Apply" question.
###moreover, it creates and populates several lists that will be used later for defining each field of the final table names, types and domains

print("Opening questionnaire DF")
quest_df = pd.read_excel(open(questionnaire_file, 'rb'), sheet_name='Questionnaire HH',skiprows=2)
#create a list of all possible numbering
numbering = ["%s)" % n for n in range(1,200)] ## 1), 2), ... 200)
# initialize list of lists that will store the results
dict_derived_fieldnames = {} #this dict will group all derived fields in case of "Select All That Apply" type of questions
field_names_list = [] ##this list will contain all fields of the final table
text_type_fields = [] ##this list will contain all fields of the final table with TEXT type
range_type_fields = [] ##this list will contain all fields of the final table storing RANGE data  (will be LONG type)
##iterate the following for each row (so each question of the questionnaire)
for index, row in quest_df.iterrows():
    try:
        first_derived_fieldname = "" #the name of the first derived field will be the main of the domain table
        all_derived_fieldnames = []
        codes_and_labels = []
        categories = str(row['English']).replace("\t","")
        question_name = row['Suggested Qname']  #Q Name
        question_type = row['Q Type']
        programming_instructions = row['Programming Instructions'] #this field contains coded values for crop_main
        print("\n\n----%s----" % question_name)
        #only for questions with pre-defined categories need domains
        if question_type in ("StartRecording","Single Choice","Open Ended-Single Choice", "Open Ended - Single Choice", "Open Ended-Select All That Apply",
                             "Select All That Apply","Open Ended - Select All That Apply "):
            if question_name == 'crp_main': #for this question only, coded values should be taken from field programming_instructions
                programming_lines = programming_instructions.splitlines()
                for programming_line in programming_lines:
                    if ")" in programming_line:
                        #print(programming_line)
                        index, category = programming_line.split(")")
                        category = fix_category_formatting(category)
                        codes_and_labels.append([index, category])
            else:
                #find all numbering present in the category string
                numbering_in_text = [n for n in numbering if n in categories]
                #print(numbering_in_text)
                ##the following loop creates a list "codes_and_labels" with all available codes&labels for each question
                for index in range(0,len(numbering_in_text)):
                    start = categories.find(numbering_in_text[index]) + len(numbering_in_text[index])
                    try:
                        end = categories.find(numbering_in_text[index + 1])
                        substring = categories[start:end].strip()
                    except:
                        # it fails during the last loop -> the last option is usually at the end of the string
                        substring = categories[start:].strip()
                    #print(substring)
                    category = fix_category_formatting(substring)
                    codes_and_labels.append([index +1, category])
                
            if question_type not in ["Open Ended-Select All That Apply","Select All That Apply","Open Ended - Select All That Apply "]:
                #so questions with NO derived fields
                field_names_list.append(question_name)
                codes_and_labels_df = pd.DataFrame(codes_and_labels, columns=['code', 'label'])
                codes_and_labels_df.to_excel(writer, sheet_name=question_name)
            else:
                #so questions with derived fields
                numbering_in_qname = [n for n in numbering if n in question_name]
                for index in range(0, len(numbering_in_qname)):
                    start = question_name.find(numbering_in_qname[index]) + len(numbering_in_qname[index])
                    try:
                        end = question_name.find(numbering_in_qname[index + 1])
                        derived_field_name = question_name[start:end].strip()
                    except:
                        # it fails during the last loop -> the last option is usually at the end of the string
                        derived_field_name = question_name[start:].strip()
                    if index == 0:
                        first_derived_fieldname = derived_field_name
                        codes_and_labels_df = pd.DataFrame(codes_and_labels, columns=['code', 'label'])
                        codes_and_labels_df.to_excel(writer, sheet_name=derived_field_name)
                    all_derived_fieldnames.append(derived_field_name)
                    field_names_list.append(derived_field_name)
                dict_derived_fieldnames[first_derived_fieldname] = all_derived_fieldnames
        elif question_type == "Range":
            #these questions will be associated to LONG type fields
            field_names_list.append(question_name)
            range_type_fields.append(question_name)
        elif question_type == "Open Ended":
            #these questions will be associated to TEXT type fields
            if not pd.isnull(question_name): #NaN rows we want to skip (i.e. OptIn question without a name in the survey)
                field_names_list.append(question_name)
                text_type_fields.append(question_name)
        else:
            print("QUESTION SKIPPED ---------", question_name, question_type)
    except:
        print("failed for some reasons")


print("Saving codes and labels %s" % coded_values_file)
# Close the Pandas Excel writer and output the Excel file.
writer.save()
# Out:
# Opening questionnaire DF
#
#
# ----nan----
# QUESTION SKIPPED --------- nan nan
#
#
# ----nan----
#
#
# ----calldispo----
#
#
# ----calldispo_answeringmachine----
# QUESTION SKIPPED --------- calldispo_answeringmachine nan
#
#
# ----calldispo_noanswer----
# QUESTION SKIPPED --------- calldispo_noanswer nan
#
#
# ----calldispo_underreview----
# QUESTION SKIPPED --------- calldispo_underreview nan
#
#
# ----calldispo_disconnected----
# QUESTION SKIPPED --------- calldispo_disconnected nan
#
#
# ----resp_language----
#
#
# ----introduction----
#
#
# ----resp_agree----
#
#
# ----resp_refusalwhy----
#
#
# ----resp_whencallback----
#
#
# ----callbackmessage_en----
#
#
# ----nan----
# QUESTION SKIPPED --------- nan nan
#
#
# ----NA ----
# QUESTION SKIPPED --------- NA  nan
#
#
# ----nan----
# QUESTION SKIPPED --------- nan nan
#
#
# ----resp_age----
#
#
# ----resp_gender----
#
#
# ----hh_admin1----
#
#
# ----hh_admin2_1----
#
#
# ----hh_admin2_2----
#
#
# ----quotareached----
#
#
# ----hh_agricactivity----
#
#
# ----nan----
# QUESTION SKIPPED --------- nan nan
#
#
# ----hh_gender----
#
#
# ----hh_education----
#
#
# ----hh_wealth----
#
#
# ----hh_residencetype----
#
#
# ----hh_size----
#
#
# ----hh_maritalstat----
#
#
# ----nan----
# QUESTION SKIPPED --------- nan nan
#
#
# ----income_main----
#
#
# ----income_main_amount----
#
#
# ----income_main_amount_conf----
#
#
# ----income_main_comp----
#
#
# ----income_sec----
#
#
# ----income_sec_amount----
#
#
# ----income_sec_amount_conf----
#
#
# ----income_sec_comp----
#
#
# ----income_third----
#
#
# ----income_third_amount----
#
#
# ----income_third_amount_conf----
#
#
# ----income_third_comp----
#
#
# ----covid_policy
#
# 1) covid_goodstransp
# 2) covid_marketclosed
# 3) covid_borderclosed
# 4) covid_stayhome
# 5) covid_gatherings
# 6) covid_processclosed
# 7) covid_other
# 8) covid_none
# 9) covid_dk
# 10) covid_ref----
#
#
# ----shock_
#
# 1) shock_noshock
# 2) shock_sicknessordeathofhh
# 3) shock_lostemplorwork
# 4) shock_otherintrahhshock
# 5) shock_higherfoodprices
# 6) shock_higherfuelprices
# 7) shock_cantworkordobusiness
# 8) shock_othereconomicshock
# 9) shock_pestoutbreak
# 10) shock_plantdisease
# 11) shock_animaldisease
# 12) shock_napasture
# 13) shock_othercropandlivests
# 14) shock_coldtemporhail
# 15) shock_flood
# 16) shock_hurricane
# 17) shock_drought
# 18) shock_earthquake
# 19) shock_landslides
# 20) shock_firenatural
# 21) shock_othernathazard
# 22) shock_violenceinsecconf
# 23) shock_theftofprodassets
# 24) shock_fire
# 25) shock_othermanmadehazard
# 26) shock_dk
# 27) shock_ref----
#
#
# ----shock_otherspecified----
#
#
# ----hh_explanation----
#
#
# ----nan----
# QUESTION SKIPPED --------- nan nan
#
#
# ----crp_main----
#
#
# ----crp_landsize----
#
#
# ----crp_landright----
#
#
# ----crp_irrigation----
#
#
# ----crp_seed_supply
#
# 1) crp_seed_ownprod
# 2) crp_seed_market
# 3) crp_seed_company
# 4) crp_seed_freedist
# 5) crp_seed_bank
# 6) crp_seed_gov
# 7) crp_seed_other
# 8) crp_seed_dk
# 9) crp_seed_ref----
#
#
# ----crp_area_change----
#
#
# ----crp_harv_change----
#
#
# ----crp_proddif----
#
#
# ----crp_proddif_
#
# 1) crp_proddif_plantdisease
# 2) crp_proddif_seedquality
# 3) crp_proddif_lostordamaged
# 4) crp_proddif_naplot
# 5) crp_proddif_nafertilizer
# 6) crp_proddif_naseeds
# 7) crp_proddif_nainsecticides
# 8) crp_proddif_nalabour
# 9) crp_proddif_namachinery
# 10) crp_proddif_nafuelorelect
# 11) crp_proddif_soilerosion
# 12) crp_proddif_irrigation
# 13) crp_proddif_other
# 14) crp_proddif_dk
# 15) crp_proddif_ref----
#
#
# ----nan----
# QUESTION SKIPPED --------- nan nan
#
#
# ----crp_salesdif----
#
#
# ----crp_salesdif_
#
# 1) crp_saledif_marketing_cost
# 2) crp_saledif_damagelosses
# 3) crp_saledif_lowdemand
# 4) crp_saledif_lowprice
# 5) crp_saledif_dif_processing
# 6) crp_saledif_other
# 7) crp_saledif_dk
# 8) crp_saledif_ref----
#
#
# ----crp_salesprice----
#
#
# ----crp_proc----
#
#
# ----crp_proc_mach_
#
# 1) crp_proc_mach_mill
# 2) crp_proc_mach_thresher
# 3) crp_proc_mach_dryingfacilit
# 4)crp_proc_mach_none
# 5) crp_proc_mach_other
# 6) crp_proc_mach_dk
# 7) crp_proc_mach_ref----
#
#
# ----crp_proc_owner_
#
# 1) crp_proc_owner_yours
# 2) crp_proc_owner_farmin
# 3) crp_proc_owner_farmout
# 4) crp_proc_owner_millin
# 5) crp_proc_owner_millout
# 6) crp_proc_owner_other
# 7) crp_proc_owner_dk
# 8) crp_proc_owner_ref----
#
#
# ----crp_proc_state----
#
#
# ----nan----
# QUESTION SKIPPED --------- nan nan
#
#
# ----ls_main----
#
#
# ----ls_num_lastyr----
#
#
# ----ls_num_now----
#
#
# ----ls_num_
#
# 1)ls_num_nochange
# 2) ls_num_inc_didnotsellasmany
# 3) ls_num_inc_moreborn
# 4) ls_num_inc_purchbarterdmore
# 5) ls_num_inc_receivedfree
# 6)ls_num_dec_animalsdied
# 7)ls_num_dec_soldmoregoodprice
# 8)ls_num_dec_soldmoredistsale
# 9)ls_num_dec_anmlescloststolen
# 10)ls_num_dec_killedorgaveanml
# 11)ls_num_inc_dec_other
# 12)ls_num_inc_dec_dk
# 13)ls_num_inc_dec_ref----
#
#
# ----ls_food_supply
#
# 1) ls_food_supply_openpasture
# 2) ls_food_supply_commngpastureland
# 3) ls_food_supply_fieldselfprodfod
# 4) ls_food_supply_purchasefeedorfodderonmarkets
# 5) ls_food_supply_other
# 6) ls_food_supply_dk
# 7) ls_food_supply_ref----
#
#
# ----ls_birthrate----
# QUESTION SKIPPED --------- ls_birthrate nan
#
#
# ----ls_proddif----
#
#
# ----ls_proddif_
#
# 1) ls_proddif_diffeedpurchase
# 2) ls_proddif_constaccesstopasture
# 3) ls_proddif_constaccesstowater
# 4) ls_proddif_difaccessvetserv
# 5) ls_proddif_difaccessvetinp
# 6) ls_proddif_diseases
# 7) ls_proddif_theftorinsecurity
# 8) ls_proddif_pooraccesstolmarket
# 9) ls_proddif_noaccesstocredit
# 10) ls_proddif_lackoflabour
# 11) ls_proddif_other
# 12) ls_proddif_dk
# 13) ls_proddif_ref----
#
#
# ----nan----
# QUESTION SKIPPED --------- nan nan
#
#
# ----ls_salesmain----
#
#
# ----ls_salesdif----
#
#
# ----ls_salesdif_
#
# 1) ls_salesdif_smallerprofits
# 2) ls_salesdif_damageandlosses
# 3) ls_salesdif_lowdemand
# 4) ls_salesdif_lowprices
# 5)  ls_salesdif_slaughterhouse
# 6) ls_salesdif_processing
# 7) ls_salesdif_other
# 8) ls_salesdif_dk
# 9) ls_salesdif_ref----
#
#
# ----ls_salesprice----
#
#
# ----ls_proc----
#
#
# ----ls_proc_
# 1) ls_proc_slaughter
# 2)ls_proc_meatprocess
# 3) ls_proc_dairyprocess
# 4) ls_proc_leather
# 5) ls_proc_other
# 6) ls_proc_dk
# 7) ls_proc_ref----
#
#
# ----ls_proc_fac_
# 1) ls_proc_fac_priv_cold_transp
# 2) ls_proc_fac_coop_cold_transp
# 3) ls_proc_fac_slaughterinncomm
# 4) ls_proc_fac_slaughteroutofcomm
# 5) ls_proc_fac_farm_dairy
# 6) ls_proc_fac_coop_dairy
# 7) ls_proc_fac_other
# 8)ls_proc_fac_none
# 9) ls_proc_fac_dk
# 10) ls_proc_fac_ref----
#
#
# ----ls_proc_fac_state----
#
#
# ----nan----
# QUESTION SKIPPED --------- nan nan
#
#
# ----fish_main_
#
# 1) fish_main_coastal
# 2) fish_main_opensea
# 3) fish_main_lakespondsrivers
# 4) fish_main_aquaculture
# 5) fish_main_dk
# 6) fish_main_ref----
#
#
# ----fish_change----
#
#
# ----fish_proddif----
#
#
# ----fish_proddif_
#
# 1) fish_proddif_find
# 2) fish_proddif_covid
# 3) fish_proddif_fuel
# 4) fish_proddif_inputs
# 5) fish_proddif_labour
# 6) fish_proddif_other
# 7) fish_proddif_dk
# 8) fish_proddif_ref----
#
#
# ----fish_inputdif_
#
# 1) fish_inputdif_bait
# 2)fish_inputdif_net
# 3) fish_inputdif_gear
# 4) fish_inputdif_ice
# 5) fish_inputdif_fuel
# 6) fish_inputdif_boatrepairs
# 7) fish_inputdif_other
# 8)fish_inputdif_dk
# 9) fish_inputdif_ref----
#
#
# ----nan----
# QUESTION SKIPPED --------- nan nan
#
#
# ----fish_salesmain----
#
#
# ----fish_salesdif_1----
#
#
# ----fish_salesdif_
#
# 1) fish_saledif_smallerprofits
# 2) fish_saledif_damageandlosses
# 3) fish_saledif_lowdemand
# 4) fish_saledif_lowprices
# 5) fish_saledif_processing
# 6) fish_saledif_other
# 7) fish_saledif_dk
# 8) fish_saledif_ref
# ----
#
#
# ----fish_salesprice----
#
#
# ----nan----
# QUESTION SKIPPED --------- nan nan
#
#
# ----fies----
#
#
# ----fies_worried----
#
#
# ----fies_healthy----
#
#
# ----fies_fewfoods----
#
#
# ----fies_skipped----
#
#
# ----fies_ateless----
#
#
# ----fies_ranout----
#
#
# ----fies_ranout_hhs----
#
#
# ----fies_hungry----
#
#
# ----fies_hungry_hhs----
#
#
# ----fies_whlday----
#
#
# ----fies_whlday_hhs----
#
#
# ----copingstrategies----
#
#
# ----cs_spentsavings----
#
#
# ----cs_borrowmoney----
#
#
# ----cs_purchasedfoodcredit----
#
#
# ----cs_soldhhassetsgoods----
#
#
# ----cs_soldprodassets----
#
#
# ----cs_eatplantingseeds----
#
#
# ----cs_withdrewchild----
#
#
# ----cs_soldlandhouse----
#
#
# ----cs_begging----
#
#
# ----cs_soldfemanimals----
#
#
# ----hdds
#
# 1) hdds_cereals
# 2) hdds_condiments
# 3) hdds_eggs
# 4) hdds_fish
# 5) hdds_fruits
# 6) hdds_legumes
# 7) hdds_meat
# 8) hdds_milkdairy
# 9) hdds_oils
# 10) hdds_rootstubers
# 11) hdds_sugar
# 12) hdds_vegetables----
#
#
# ----hdds_confirmation----
#
#
# ----nan----
# QUESTION SKIPPED --------- nan nan
#
#
# ----need----
#
#
# ----need_
#
# 1) need_seeds
# 2) need_fertilizers
# 3) need_pesticides
# 4) need_tools
# 5) need_accesstoirrigationwater
# 6) need_accesstoland
# 7) need_animalfeed
# 8) need_veterinaryservices
# 9) need_veterinaryinputs
# 10) need_animalsalemingarantdprice
# 11) need_restockinganimals
# 12) need_supportforprocessprod
# 13) need_supptransofanimalsorprod
# 14) need_acstomechanisedequipprod
# 15) need_marketingsupport
# 16) need_cashassistance
# 17) need_loans
# 18) need_storageequipmentorfaci
# 19) need_techsupporextensionserv
# 20) need_landrehabilitation
# 21) need_fishequiorothersuppforfish
# 22) need_infoonsafetymeasures
# 23) need_other
# 24) need_dk
# 25) need_ref----
#
#
# ----need_received_
#
# 1) need_received_food
# 2) need_received_cashvouchers
# 3) need_received_seeds
# 4) need_received_extensionservices
# 5) need_received_livestockfeed
# 6) need_received_other
# 7) need_received_noassistreceived
# 8) need_received_dk
# 9) need_received_ref----
#
#
# ----nan----
# QUESTION SKIPPED --------- nan nan
#
#
# ----callback----
#
#
# ----language2----
#
#
# ----closeout----
# QUESTION SKIPPED --------- closeout nan
# Saving codes and labels C:\temp\data_processing_exports\coded_values_20210504151635.xlsx

# %%
###this section creates a new GDB
gdb_name = "fGDB_with_coded_values_%s.gdb" % now
output_gdb = os.path.join(temp_path, gdb_name)
arcpy.CreateFileGDB_management(temp_path,gdb_name)
# Out:
# <Result 'C:\\temp\\data_processing_exports\\fGDB_with_coded_values_20210504151635.gdb'>

# %%
##here we and import each table with coded values and description into the GDB
###it can take up to 5 seconds per table - and we normally process hundreds of table.
####for this reason, for testing purposes edit variable max_counter in the first cell of this notebook


importallsheets(coded_values_file, output_gdb)
# Out:
# max_counter: 3000
# 95 sheets found: calldispo,resp_language,introduction,resp_agree,resp_refusalwhy,resp_gender,hh_admin1,hh_admin2_1,hh_admin2_2,quotareached,hh_agricactivity,hh_gender,hh_education,hh_wealth,hh_residencetype,hh_maritalstat,income_main,income_main_amount_conf,income_main_comp,income_sec,income_sec_amount_conf,income_sec_comp,income_third,income_third_amount_conf,income_third_comp,covid_goodstransp,shock_noshock,crp_main,crp_landsize,crp_landright,crp_irrigation,crp_seed_ownprod,crp_area_change,crp_harv_change,crp_proddif,crp_proddif_plantdisease,crp_salesdif,crp_saledif_marketing_cost,crp_salesprice,crp_proc,crp_proc_mach_mill,crp_proc_owner_yours,crp_proc_state,ls_main,ls_num_nochange,ls_food_supply_openpasture,ls_proddif,ls_proddif_diffeedpurchase,ls_salesmain,ls_salesdif,ls_salesdif_smallerprofits,ls_salesprice,ls_proc,ls_proc_slaughter,ls_proc_fac_priv_cold_transp,ls_proc_fac_state,fish_main_coastal,fish_change,fish_proddif,fish_proddif_find,fish_inputdif_bait,fish_salesmain,fish_salesdif_1,fish_saledif_smallerprofits,fish_salesprice,fies,fies_worried,fies_healthy,fies_fewfoods,fies_skipped,fies_ateless,fies_ranout,fies_ranout_hhs,fies_hungry,fies_hungry_hhs,fies_whlday,fies_whlday_hhs,copingstrategies,cs_spentsavings,cs_borrowmoney,cs_purchasedfoodcredit,cs_soldhhassetsgoods,cs_soldprodassets,cs_eatplantingseeds,cs_withdrewchild,cs_soldlandhouse,cs_begging,cs_soldfemanimals,hdds_cereals,hdds_confirmation,need,need_seeds,need_received_food,callback,language2
# Converting calldispo to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\calldispo
# Converting resp_language to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\resp_language
# Converting introduction to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\introduction
# Converting resp_agree to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\resp_agree
# Converting resp_refusalwhy to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\resp_refusalwhy
# Converting resp_gender to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\resp_gender
# Converting hh_admin1 to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\hh_admin1
# Converting hh_admin2_1 to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\hh_admin2_1
# Converting hh_admin2_2 to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\hh_admin2_2
# Converting quotareached to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\quotareached
# Converting hh_agricactivity to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\hh_agricactivity
# Converting hh_gender to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\hh_gender
# Converting hh_education to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\hh_education
# Converting hh_wealth to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\hh_wealth
# Converting hh_residencetype to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\hh_residencetype
# Converting hh_maritalstat to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\hh_maritalstat
# Converting income_main to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\income_main
# Converting income_main_amount_conf to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\income_main_amount_conf
# Converting income_main_comp to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\income_main_comp
# Converting income_sec to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\income_sec
# Converting income_sec_amount_conf to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\income_sec_amount_conf
# Converting income_sec_comp to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\income_sec_comp
# Converting income_third to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\income_third
# Converting income_third_amount_conf to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\income_third_amount_conf
# Converting income_third_comp to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\income_third_comp
# Converting covid_goodstransp to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\covid_goodstransp
# Converting shock_noshock to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\shock_noshock
# Converting crp_main to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\crp_main
# Converting crp_landsize to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\crp_landsize
# Converting crp_landright to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\crp_landright
# Converting crp_irrigation to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\crp_irrigation
# Converting crp_seed_ownprod to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\crp_seed_ownprod
# Converting crp_area_change to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\crp_area_change
# Converting crp_harv_change to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\crp_harv_change
# Converting crp_proddif to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\crp_proddif
# Converting crp_proddif_plantdisease to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\crp_proddif_plantdisease
# Converting crp_salesdif to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\crp_salesdif
# Converting crp_saledif_marketing_cost to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\crp_saledif_marketing_cost
# Converting crp_salesprice to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\crp_salesprice
# Converting crp_proc to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\crp_proc
# Converting crp_proc_mach_mill to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\crp_proc_mach_mill
# Converting crp_proc_owner_yours to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\crp_proc_owner_yours
# Converting crp_proc_state to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\crp_proc_state
# Converting ls_main to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\ls_main
# Converting ls_num_nochange to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\ls_num_nochange
# Converting ls_food_supply_openpasture to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\ls_food_supply_openpasture
# Converting ls_proddif to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\ls_proddif
# Converting ls_proddif_diffeedpurchase to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\ls_proddif_diffeedpurchase
# Converting ls_salesmain to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\ls_salesmain
# Converting ls_salesdif to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\ls_salesdif
# Converting ls_salesdif_smallerprofits to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\ls_salesdif_smallerprofits
# Converting ls_salesprice to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\ls_salesprice
# Converting ls_proc to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\ls_proc
# Converting ls_proc_slaughter to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\ls_proc_slaughter
# Converting ls_proc_fac_priv_cold_transp to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\ls_proc_fac_priv_cold_transp
# Converting ls_proc_fac_state to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\ls_proc_fac_state
# Converting fish_main_coastal to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\fish_main_coastal
# Converting fish_change to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\fish_change
# Converting fish_proddif to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\fish_proddif
# Converting fish_proddif_find to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\fish_proddif_find
# Converting fish_inputdif_bait to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\fish_inputdif_bait
# Converting fish_salesmain to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\fish_salesmain
# Converting fish_salesdif_1 to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\fish_salesdif_1
# Converting fish_saledif_smallerprofits to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\fish_saledif_smallerprofits
# Converting fish_salesprice to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\fish_salesprice
# Converting fies to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\fies
# Converting fies_worried to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\fies_worried
# Converting fies_healthy to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\fies_healthy
# Converting fies_fewfoods to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\fies_fewfoods
# Converting fies_skipped to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\fies_skipped
# Converting fies_ateless to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\fies_ateless
# Converting fies_ranout to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\fies_ranout
# Converting fies_ranout_hhs to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\fies_ranout_hhs
# Converting fies_hungry to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\fies_hungry
# Converting fies_hungry_hhs to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\fies_hungry_hhs
# Converting fies_whlday to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\fies_whlday
# Converting fies_whlday_hhs to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\fies_whlday_hhs
# Converting copingstrategies to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\copingstrategies
# Converting cs_spentsavings to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\cs_spentsavings
# Converting cs_borrowmoney to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\cs_borrowmoney
# Converting cs_purchasedfoodcredit to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\cs_purchasedfoodcredit
# Converting cs_soldhhassetsgoods to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\cs_soldhhassetsgoods
# Converting cs_soldprodassets to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\cs_soldprodassets
# Converting cs_eatplantingseeds to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\cs_eatplantingseeds
# Converting cs_withdrewchild to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\cs_withdrewchild
# Converting cs_soldlandhouse to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\cs_soldlandhouse
# Converting cs_begging to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\cs_begging
# Converting cs_soldfemanimals to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\cs_soldfemanimals
# Converting hdds_cereals to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\hdds_cereals
# Converting hdds_confirmation to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\hdds_confirmation
# Converting need to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\need
# Converting need_seeds to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\need_seeds
# Converting need_received_food to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\need_received_food
# Converting callback to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\callback
# Converting language2 to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\language2

# %%
###it reads the survey file and creates an excel file with all field names of the outputs table.
###then it imports the empty output table template to the GDB, and calls it survey_data. this table will be the future master table
###coded values will be enforced there.

#insert opening fields that come from Geopoll and are not captured by the questionnaire file
opening_fields = [["survey_id",'TEXT'],["operator_id",'TEXT'],["adm0_name",'TEXT'],["adm0_ISO3",'TEXT'],["adm1_pcode",'TEXT'], ["adm1_name",'TEXT'],["adm2_pcode",'TEXT'],["adm2_name",'TEXT'],
["survey_created_date",'TEXT'],["opt_in_date",'TEXT'],["total_case_duration",'TEXT']]

#manage opening fields type
opening_fields_names_text = [i[0] for i in opening_fields if i[1] == 'TEXT']
opening_fields_names_short = [i[0] for i in opening_fields if i[1] == 'SHORT']
opening_fields_names_range = [i[0] for i in opening_fields if i[1] == 'RANGE']
opening_fields_names_date = [i[0] for i in opening_fields if i[1] == 'DATE']

text_type_fields += opening_fields_names_text
range_type_fields += opening_fields_names_range

opening_field_names = [i[0] for i in opening_fields]
field_names_list = opening_field_names + field_names_list

#some fields in the questionnaire should be removed from the master table
useless_fields = ['callbackmessage_en', 'hh_admin1', 'calldispo', 'hh_admin2_1', 'hh_admin2_2', 'quotareached', 'resp_refusalwhy', 'resp_whencallback', 'fies','copingstrategies',
                 "introduction",'hdds_confirmation','income_main_amount_conf','income_sec_amount_conf','income_third_amount_conf']


s_useless_fields = set(useless_fields)  

field_names_list = [x for x in field_names_list if x not in s_useless_fields]


survey_empty_table_df = pd.DataFrame(columns=[field_names_list])
survey_empty_table_xlsx = os.path.join(temp_path, "survey_empty_table_%s.xlsx" % now)
writer = pd.ExcelWriter(survey_empty_table_xlsx, engine='xlsxwriter')
survey_empty_table_df.to_excel(writer, sheet_name="survey_data")
writer.save()

# %%
###this section imports the excel file just created into the GDB

importallsheets(survey_empty_table_xlsx, output_gdb)
# Out:
# max_counter: 3000
# 1 sheets found: survey_data
# Converting survey_data to C:\temp\data_processing_exports\fGDB_with_coded_values_20210504151635.gdb\survey_data

# %%
##there is always an unwanted field to remove
try:
    arcpy.DeleteField_management(os.path.join(output_gdb, "survey_data"),"COL_A")
except:
    print ("field COL_A does not exist")

# %%
### This section alters each fields type in the survey master table
###domain related fiels shuld be integer, in order to enforce coded values, except crop_main

##string fields: open ended questions + crop_main
##long fields: range and numbers related questions (age, currency, hh size...)
##short fields: coded values questions

GDB_survey_table = os.path.join(output_gdb,"survey_data")
field_names = [f.name for f in arcpy.ListFields(GDB_survey_table)]
for field in field_names:
    if field in field_names_list:
        print("changing type for field %s" % field)
        try:
            if field == 'crp_main' or field in text_type_fields: #crp_main is associated to text codes since they have possible dots (.) for subcategories
                arcpy.management.AlterField(GDB_survey_table, field, field_type = "TEXT")
            elif field in range_type_fields: #i.e. currencies
                arcpy.management.AlterField(GDB_survey_table, field, field_type = "LONG")
            else: #all other fields are short integer (simple  code values)
                arcpy.management.AlterField(GDB_survey_table, field, field_type = "SHORT")
        except:
            pass
# Out:
# changing type for field survey_id
# changing type for field operator_id
# changing type for field adm0_name
# changing type for field adm0_ISO3
# changing type for field adm1_pcode
# changing type for field adm1_name
# changing type for field adm2_pcode
# changing type for field adm2_name
# changing type for field survey_created_date
# changing type for field opt_in_date
# changing type for field total_case_duration
# changing type for field resp_language
# changing type for field resp_agree
# changing type for field resp_age
# changing type for field resp_gender
# changing type for field hh_agricactivity
# changing type for field hh_gender
# changing type for field hh_education
# changing type for field hh_wealth
# changing type for field hh_residencetype
# changing type for field hh_size
# changing type for field hh_maritalstat
# changing type for field income_main
# changing type for field income_main_amount
# changing type for field income_main_comp
# changing type for field income_sec
# changing type for field income_sec_amount
# changing type for field income_sec_comp
# changing type for field income_third
# changing type for field income_third_amount
# changing type for field income_third_comp
# changing type for field covid_goodstransp
# changing type for field covid_marketclosed
# changing type for field covid_borderclosed
# changing type for field covid_stayhome
# changing type for field covid_gatherings
# changing type for field covid_processclosed
# changing type for field covid_other
# changing type for field covid_none
# changing type for field covid_dk
# changing type for field covid_ref
# changing type for field shock_noshock
# changing type for field shock_sicknessordeathofhh
# changing type for field shock_lostemplorwork
# changing type for field shock_otherintrahhshock
# changing type for field shock_higherfoodprices
# changing type for field shock_higherfuelprices
# changing type for field shock_cantworkordobusiness
# changing type for field shock_othereconomicshock
# changing type for field shock_pestoutbreak
# changing type for field shock_plantdisease
# changing type for field shock_animaldisease
# changing type for field shock_napasture
# changing type for field shock_othercropandlivests
# changing type for field shock_coldtemporhail
# changing type for field shock_flood
# changing type for field shock_hurricane
# changing type for field shock_drought
# changing type for field shock_earthquake
# changing type for field shock_landslides
# changing type for field shock_firenatural
# changing type for field shock_othernathazard
# changing type for field shock_violenceinsecconf
# changing type for field shock_theftofprodassets
# changing type for field shock_fire
# changing type for field shock_othermanmadehazard
# changing type for field shock_dk
# changing type for field shock_ref
# changing type for field shock_otherspecified
# changing type for field hh_explanation
# changing type for field crp_main
# changing type for field crp_landsize
# changing type for field crp_landright
# changing type for field crp_irrigation
# changing type for field crp_seed_ownprod
# changing type for field crp_seed_market
# changing type for field crp_seed_company
# changing type for field crp_seed_freedist
# changing type for field crp_seed_bank
# changing type for field crp_seed_gov
# changing type for field crp_seed_other
# changing type for field crp_seed_dk
# changing type for field crp_seed_ref
# changing type for field crp_area_change
# changing type for field crp_harv_change
# changing type for field crp_proddif
# changing type for field crp_proddif_plantdisease
# changing type for field crp_proddif_seedquality
# changing type for field crp_proddif_lostordamaged
# changing type for field crp_proddif_naplot
# changing type for field crp_proddif_nafertilizer
# changing type for field crp_proddif_naseeds
# changing type for field crp_proddif_nainsecticides
# changing type for field crp_proddif_nalabour
# changing type for field crp_proddif_namachinery
# changing type for field crp_proddif_nafuelorelect
# changing type for field crp_proddif_soilerosion
# changing type for field crp_proddif_irrigation
# changing type for field crp_proddif_other
# changing type for field crp_proddif_dk
# changing type for field crp_proddif_ref
# changing type for field crp_salesdif
# changing type for field crp_saledif_marketing_cost
# changing type for field crp_saledif_damagelosses
# changing type for field crp_saledif_lowdemand
# changing type for field crp_saledif_lowprice
# changing type for field crp_saledif_dif_processing
# changing type for field crp_saledif_other
# changing type for field crp_saledif_dk
# changing type for field crp_saledif_ref
# changing type for field crp_salesprice
# changing type for field crp_proc
# changing type for field crp_proc_mach_mill
# changing type for field crp_proc_mach_thresher
# changing type for field crp_proc_mach_dryingfacilit
# changing type for field crp_proc_mach_none
# changing type for field crp_proc_mach_other
# changing type for field crp_proc_mach_dk
# changing type for field crp_proc_mach_ref
# changing type for field crp_proc_owner_yours
# changing type for field crp_proc_owner_farmin
# changing type for field crp_proc_owner_farmout
# changing type for field crp_proc_owner_millin
# changing type for field crp_proc_owner_millout
# changing type for field crp_proc_owner_other
# changing type for field crp_proc_owner_dk
# changing type for field crp_proc_owner_ref
# changing type for field crp_proc_state
# changing type for field ls_main
# changing type for field ls_num_lastyr
# changing type for field ls_num_now
# changing type for field ls_num_nochange
# changing type for field ls_num_inc_didnotsellasmany
# changing type for field ls_num_inc_moreborn
# changing type for field ls_num_inc_purchbarterdmore
# changing type for field ls_num_inc_receivedfree
# changing type for field ls_num_dec_animalsdied
# changing type for field ls_num_dec_soldmoregoodprice
# changing type for field ls_num_dec_soldmoredistsale
# changing type for field ls_num_dec_anmlescloststolen
# changing type for field ls_num_dec_killedorgaveanml
# changing type for field ls_num_inc_dec_other
# changing type for field ls_num_inc_dec_dk
# changing type for field ls_num_inc_dec_ref
# changing type for field ls_food_supply_openpasture
# changing type for field ls_food_supply_commngpastureland
# changing type for field ls_food_supply_fieldselfprodfod
# changing type for field ls_food_supply_purchasefeedorfodderonmarkets
# changing type for field ls_food_supply_other
# changing type for field ls_food_supply_dk
# changing type for field ls_food_supply_ref
# changing type for field ls_proddif
# changing type for field ls_proddif_diffeedpurchase
# changing type for field ls_proddif_constaccesstopasture
# changing type for field ls_proddif_constaccesstowater
# changing type for field ls_proddif_difaccessvetserv
# changing type for field ls_proddif_difaccessvetinp
# changing type for field ls_proddif_diseases
# changing type for field ls_proddif_theftorinsecurity
# changing type for field ls_proddif_pooraccesstolmarket
# changing type for field ls_proddif_noaccesstocredit
# changing type for field ls_proddif_lackoflabour
# changing type for field ls_proddif_other
# changing type for field ls_proddif_dk
# changing type for field ls_proddif_ref
# changing type for field ls_salesmain
# changing type for field ls_salesdif
# changing type for field ls_salesdif_smallerprofits
# changing type for field ls_salesdif_damageandlosses
# changing type for field ls_salesdif_lowdemand
# changing type for field ls_salesdif_lowprices
# changing type for field ls_salesdif_slaughterhouse
# changing type for field ls_salesdif_processing
# changing type for field ls_salesdif_other
# changing type for field ls_salesdif_dk
# changing type for field ls_salesdif_ref
# changing type for field ls_salesprice
# changing type for field ls_proc
# changing type for field ls_proc_slaughter
# changing type for field ls_proc_meatprocess
# changing type for field ls_proc_dairyprocess
# changing type for field ls_proc_leather
# changing type for field ls_proc_other
# changing type for field ls_proc_dk
# changing type for field ls_proc_ref
# changing type for field ls_proc_fac_priv_cold_transp
# changing type for field ls_proc_fac_coop_cold_transp
# changing type for field ls_proc_fac_slaughterinncomm
# changing type for field ls_proc_fac_slaughteroutofcomm
# changing type for field ls_proc_fac_farm_dairy
# changing type for field ls_proc_fac_coop_dairy
# changing type for field ls_proc_fac_other
# changing type for field ls_proc_fac_none
# changing type for field ls_proc_fac_dk
# changing type for field ls_proc_fac_ref
# changing type for field ls_proc_fac_state
# changing type for field fish_main_coastal
# changing type for field fish_main_opensea
# changing type for field fish_main_lakespondsrivers
# changing type for field fish_main_aquaculture
# changing type for field fish_main_dk
# changing type for field fish_main_ref
# changing type for field fish_change
# changing type for field fish_proddif
# changing type for field fish_proddif_find
# changing type for field fish_proddif_covid
# changing type for field fish_proddif_fuel
# changing type for field fish_proddif_inputs
# changing type for field fish_proddif_labour
# changing type for field fish_proddif_other
# changing type for field fish_proddif_dk
# changing type for field fish_proddif_ref
# changing type for field fish_inputdif_bait
# changing type for field fish_inputdif_net
# changing type for field fish_inputdif_gear
# changing type for field fish_inputdif_ice
# changing type for field fish_inputdif_fuel
# changing type for field fish_inputdif_boatrepairs
# changing type for field fish_inputdif_other
# changing type for field fish_inputdif_dk
# changing type for field fish_inputdif_ref
# changing type for field fish_salesmain
# changing type for field fish_salesdif_1
# changing type for field fish_saledif_smallerprofits
# changing type for field fish_saledif_damageandlosses
# changing type for field fish_saledif_lowdemand
# changing type for field fish_saledif_lowprices
# changing type for field fish_saledif_processing
# changing type for field fish_saledif_other
# changing type for field fish_saledif_dk
# changing type for field fish_saledif_ref
# changing type for field fish_salesprice
# changing type for field fies_worried
# changing type for field fies_healthy
# changing type for field fies_fewfoods
# changing type for field fies_skipped
# changing type for field fies_ateless
# changing type for field fies_ranout
# changing type for field fies_ranout_hhs
# changing type for field fies_hungry
# changing type for field fies_hungry_hhs
# changing type for field fies_whlday
# changing type for field fies_whlday_hhs
# changing type for field cs_spentsavings
# changing type for field cs_borrowmoney
# changing type for field cs_purchasedfoodcredit
# changing type for field cs_soldhhassetsgoods
# changing type for field cs_soldprodassets
# changing type for field cs_eatplantingseeds
# changing type for field cs_withdrewchild
# changing type for field cs_soldlandhouse
# changing type for field cs_begging
# changing type for field cs_soldfemanimals
# changing type for field hdds_cereals
# changing type for field hdds_condiments
# changing type for field hdds_eggs
# changing type for field hdds_fish
# changing type for field hdds_fruits
# changing type for field hdds_legumes
# changing type for field hdds_meat
# changing type for field hdds_milkdairy
# changing type for field hdds_oils
# changing type for field hdds_rootstubers
# changing type for field hdds_sugar
# changing type for field hdds_vegetables
# changing type for field need
# changing type for field need_seeds
# changing type for field need_fertilizers
# changing type for field need_pesticides
# changing type for field need_tools
# changing type for field need_accesstoirrigationwater
# changing type for field need_accesstoland
# changing type for field need_animalfeed
# changing type for field need_veterinaryservices
# changing type for field need_veterinaryinputs
# changing type for field need_animalsalemingarantdprice
# changing type for field need_restockinganimals
# changing type for field need_supportforprocessprod
# changing type for field need_supptransofanimalsorprod
# changing type for field need_acstomechanisedequipprod
# changing type for field need_marketingsupport
# changing type for field need_cashassistance
# changing type for field need_loans
# changing type for field need_storageequipmentorfaci
# changing type for field need_techsupporextensionserv
# changing type for field need_landrehabilitation
# changing type for field need_fishequiorothersuppforfish
# changing type for field need_infoonsafetymeasures
# changing type for field need_other
# changing type for field need_dk
# changing type for field need_ref
# changing type for field need_received_food
# changing type for field need_received_cashvouchers
# changing type for field need_received_seeds
# changing type for field need_received_extensionservices
# changing type for field need_received_livestockfeed
# changing type for field need_received_other
# changing type for field need_received_noassistreceived
# changing type for field need_received_dk
# changing type for field need_received_ref
# changing type for field callback
# changing type for field language2

# %%
def create_and_apply_domain(master_table, domain_table, field_name, domain_already_exists):
    # Process: Create the coded value domain
    domName = '%s_dom' % domain_table
    if not domain_already_exists:
        if domain_table == 'crp_main':
            field_type = "TEXT"
        else:
            field_type = "SHORT"
        try:
            arcpy.CreateDomain_management(output_gdb, domName, field_type= field_type)
        except:
            print('domain exists')
        # Store all the domain values in a dictionary with the domain code as the "key" 
        # and the domain description as the "value" (domDict[code])

        domDict = make_attribute_dict(domain_table, 'code', 'label')
        print(domDict)

        #   dict example:  {"CI":"Cast iron", "DI": "Ductile iron", "PVC": "PVC", 
        #                "ACP": "Asbestos concrete", "COP": "Copper"}

        # Process: Add valid material types to the domain
        # use a for loop to cycle through all the domain codes in the dictionary
        for code in domDict:
            try:
                arcpy.AddCodedValueToDomain_management(output_gdb, domName, code, domDict[code])
            except:
                print("AddCodedValueToDomain_management failed")

        # Process: Constrain the material value of distribution mains

    arcpy.AssignDomainToField_management(master_table, field_name, domName)

# %%
##THis section of the script searches for all domains tables in the GDB
##then, for each table  it creates a new domain,
###it stores all domain values in a dictionary, it add each code domain, and finally assign the domain to the right field (having same name)

# Set the current workspace
arcpy.env.workspace = output_gdb

# Get and print a list of tables
tables = arcpy.ListTables()
master_table = os.path.join(output_gdb,'survey_data')
for table in tables:
    if 'survey_data' not in table and table not in useless_fields:
        #print(table)
        print ("Creating and Applying (new) domain for %s" % table)
        create_and_apply_domain(master_table, table, table, False) #domain_table has the same name of the field where it should be applied
        if table in dict_derived_fieldnames:
            derived_fields_list = dict_derived_fieldnames[table]
            for derived_field in derived_fields_list:
                print ("Creating and Applying (existing) domain for derivate field %s" % derived_field)
                create_and_apply_domain(master_table, table, derived_field, True)
# Out:
# Creating and Applying (new) domain for resp_language
# {1: 'English', 2: 'Other options (add as many as necessary)'}
# Creating and Applying (new) domain for resp_agree
# {1: 'Yes', 2: 'Not now but another time in the week', 3: 'No'}
# Creating and Applying (new) domain for resp_gender
# {1: 'Male', 2: 'Female', 3: "Don't know", 4: 'Refused'}
# Creating and Applying (new) domain for hh_agricactivity
# {1: 'Yes - crop production', 2: 'Yes - livestock production', 3: 'Yes - both crop and livestock production', 4: 'No', 5: "Don't know", 6: 'Refused'}
# Creating and Applying (new) domain for hh_gender
# {1: 'Male', 2: 'Female', 3: "Don't know", 4: 'Refused'}
# Creating and Applying (new) domain for hh_education
# {1: 'None or did not complete primary school', 2: 'Completed primary school', 3: 'Completed secondary school', 4: 'Completed higher education (university , college) degree', 5: 'Islamic education', 6: "Don't know", 7: 'Refused'}
# Creating and Applying (new) domain for hh_wealth
# {}
# Creating and Applying (new) domain for hh_residencetype
# {1: 'Permanent resident - you have been living in your village , town for longer than two years and this is what you consider your habitual residence', 2: 'Recent migrant not forcefully displaced - you have been living in your current place of residence for less than two years and you moved there voluntarily for work , family or other reasons that are not related to conflict or natural disaster', 3: 'Returnee - you have only come back to this residence in the last two years after having been forced to move to another location having fled conflict or natural disaster (if return was over 2 years ago the respondent is considered a permanent resident)', 4: 'Internally displaced person (IDP) - you were forced to flee your village or town because of conflict or natural disaster and you are now an internally displaced person in your current place of residence', 5: 'Refugee - you were forced to flee your country because of conflict or natural disaster and you are now a refugee in your current place of residence', 6: "Don't know", 7: 'Refused'}
# Creating and Applying (new) domain for hh_maritalstat
# {1: 'Single , never married', 2: 'Married', 3: 'Separated', 4: 'Divorced', 5: 'Widowed', 6: 'Don’t know', 7: 'Refused'}
# Creating and Applying (new) domain for income_main
# {1: 'Farmer , production and sale of cereal crops', 2: 'Farmer , production and sale of vegetable or fruit', 3: 'Farmer , production and sale of cashcrops', 4: 'Farmer , production and sale of livestock and livestock products', 5: 'Farmer , production and sale of fish', 6: 'Farmer , collection and sale of forestry or bush products', 7: 'Informal agricultural trade excluding producers', 8: 'Formal agricultural trade excluding producers', 9: 'Daily wage on farms and other casual employment in agric sector', 10: 'Stable employment in agricultural sector', 11: 'Non-agricultural self-employed or liberal profession, doctor, architect, lawyer, including restaurant', 12: 'Off-farm daily wages and other non-agric casual employment', 13: 'Stable employment  in non- agric sector', 14: 'Public employment', 15: 'Income not derived from work , charity', 16: 'Income not derived from work , welfare transfer, pension, humanitarian aid', 17: 'Income not derived from work , remittances', 18: 'Income not derived from work , income from other rents', 19: 'No income source in the last 3 months and used exclusively savings', 20: 'No income source in the last 3 months and used exclusively debt', 21: 'Refused'}
# Creating and Applying (new) domain for income_main_comp
# {1: 'A lot more (increased by more than 50%)', 2: 'More', 3: 'Same', 4: 'Less', 5: 'A lot less (less than half as much)', 6: "Don't know", 7: 'Refused'}
# Creating and Applying (new) domain for income_sec
# {1: 'Farmer , production and sale of cereal crops', 2: 'Farmer , production and sale of vegetable or fruit', 3: 'Farmer , production and sale of cashcrops', 4: 'Farmer , production and sale of livestock and livestock products', 5: 'Farmer , production and sale of fish', 6: 'Farmer , collection and sale of forestry or bush products', 7: 'Informal agricultural trade excluding producers', 8: 'Formal agricultural trade excluding producers', 9: 'Daily wage on farms and other casual employment in agric sector', 10: 'Stable employment in agricultural sector', 11: 'Non-agricultural self-employed or liberal profession, doctor, architect, lawyer, including restaurant', 12: 'Off-farm daily wages and other non-agric casual employment', 13: 'Stable employment  in non- agric sector', 14: 'Public employment', 15: 'Income not derived from work , charity', 16: 'Income not derived from work , welfare transfer, pension, humanitarian aid', 17: 'Income not derived from work , remittances', 18: 'Income not derived from work , income from other rents', 19: 'No second most important source of income', 20: "Don't know", 21: 'Refused'}
# Creating and Applying (new) domain for income_sec_comp
# {1: 'A lot more (increased by more than 50%)', 2: 'More', 3: 'Same', 4: 'Less', 5: 'A lot less (less than half as much)', 6: "Don't know", 7: 'Refused'}
# Creating and Applying (new) domain for income_third
# {1: 'Farmer , production and sale of cereal crops', 2: 'Farmer , production and sale of vegetable or fruit', 3: 'Farmer , production and sale of cashcrops', 4: 'Farmer , production and sale of livestock and livestock products', 5: 'Farmer , production and sale of fish', 6: 'Farmer , collection and sale of forestry or bush products', 7: 'Informal agricultural trade excluding producers', 8: 'Formal agricultural trade excluding producers', 9: 'Daily wage on farms and other casual employment in agric sector', 10: 'Stable employment in agricultural sector', 11: 'Non-agricultural self-employed or liberal profession, doctor, architect, lawyer, including restaurant', 12: 'Off-farm daily wages and other non-agric casual employment', 13: 'Stable employment in non-agric sector', 14: 'Public employment', 15: 'Income not derived from work , charity', 16: 'Income not derived from work , welfare transfer, pension, humanitarian aid', 17: 'Income not derived from work , remittances', 18: 'Income not derived from work , income from other rents', 19: 'No third most important source of income', 20: "Don't know", 21: 'Refused'}
# Creating and Applying (new) domain for income_third_comp
# {1: 'A lot more (increased by more than 50%)', 2: 'More', 3: 'Same', 4: 'Less', 5: 'A lot less (less than half as much)', 6: "Don't know", 7: 'Refused'}
# Creating and Applying (new) domain for covid_goodstransp
# {1: 'Movement restrictions for goods impeding or delaying ability to transport goods to markets', 2: 'Closure of food markets', 3: 'Closure of international borders (affecting the purchase of imported inputs or the sale of goods for export or transhumance)', 4: 'Stay at home order', 5: 'Ban on gatherings', 6: 'Closure of food processors (slaughterhouse , dairy cooperatives , etc) or restaurants', 7: 'Other ', 8: 'Not affected by restrictions', 9: "Don't know", 10: 'Refused'}
# Creating and Applying (existing) domain for derivate field covid_goodstransp
# Creating and Applying (existing) domain for derivate field covid_marketclosed
# Creating and Applying (existing) domain for derivate field covid_borderclosed
# Creating and Applying (existing) domain for derivate field covid_stayhome
# Creating and Applying (existing) domain for derivate field covid_gatherings
# Creating and Applying (existing) domain for derivate field covid_processclosed
# Creating and Applying (existing) domain for derivate field covid_other
# Creating and Applying (existing) domain for derivate field covid_none
# Creating and Applying (existing) domain for derivate field covid_dk
# Creating and Applying (existing) domain for derivate field covid_ref
# Creating and Applying (new) domain for shock_noshock
# {1: 'No shock', 2: 'Sickness or death of household member(s) (sickness of breadwinner , unusually high medical expenditure , funeral expenses , death of breadwinner)', 3: 'Lost employment or working opportunities', 4: 'Other intra household shock', 5: 'Much higher than usual food prices', 6: 'Much higher than usual fuel prices', 7: 'External event impeding the continuation of work or business affecting all - laws closing markets , businesses , road infrastructure to markets destroyed, etc.', 8: 'Other economic shock', 9: 'Pest outbreak', 10: 'Plant disease', 11: 'Animal disease affecting many animals', 12: 'Lack of physical access to pasture (because of conflict , infrastructure damage , COVID-19 restrictions)', 13: 'Other crop and livestock shock', 14: 'Cold temperatures or hail', 15: 'Flood', 16: 'Hurricane , cyclone', 17: 'Drought', 18: 'Earthquake', 19: 'Landslides', 20: 'Fire from natural disaster', 21: 'Other natural hazard', 22: 'Violence and insecurity , conflict', 23: 'Theft of production assets (land , livestock , tools , etc)', 24: 'Fire from man-made disaster', 25: 'Other man-made hazard', 26: "Don't know", 27: 'Refused'}
# Creating and Applying (existing) domain for derivate field shock_noshock
# Creating and Applying (existing) domain for derivate field shock_sicknessordeathofhh
# Creating and Applying (existing) domain for derivate field shock_lostemplorwork
# Creating and Applying (existing) domain for derivate field shock_otherintrahhshock
# Creating and Applying (existing) domain for derivate field shock_higherfoodprices
# Creating and Applying (existing) domain for derivate field shock_higherfuelprices
# Creating and Applying (existing) domain for derivate field shock_cantworkordobusiness
# Creating and Applying (existing) domain for derivate field shock_othereconomicshock
# Creating and Applying (existing) domain for derivate field shock_pestoutbreak
# Creating and Applying (existing) domain for derivate field shock_plantdisease
# Creating and Applying (existing) domain for derivate field shock_animaldisease
# Creating and Applying (existing) domain for derivate field shock_napasture
# Creating and Applying (existing) domain for derivate field shock_othercropandlivests
# Creating and Applying (existing) domain for derivate field shock_coldtemporhail
# Creating and Applying (existing) domain for derivate field shock_flood
# Creating and Applying (existing) domain for derivate field shock_hurricane
# Creating and Applying (existing) domain for derivate field shock_drought
# Creating and Applying (existing) domain for derivate field shock_earthquake
# Creating and Applying (existing) domain for derivate field shock_landslides
# Creating and Applying (existing) domain for derivate field shock_firenatural
# Creating and Applying (existing) domain for derivate field shock_othernathazard
# Creating and Applying (existing) domain for derivate field shock_violenceinsecconf
# Creating and Applying (existing) domain for derivate field shock_theftofprodassets
# Creating and Applying (existing) domain for derivate field shock_fire
# Creating and Applying (existing) domain for derivate field shock_othermanmadehazard
# Creating and Applying (existing) domain for derivate field shock_dk
# Creating and Applying (existing) domain for derivate field shock_ref
# Creating and Applying (new) domain for crp_main
# {'1.1': 'Rice', '1.2': 'Wheat', '1.3': 'Millet', '1.4': 'Sorgum', '1.5': 'Maize', '1.99': 'Other cereals', '2.1': 'Cassava', '2.2': 'Potatoe', '2.3': 'Sweet potatoes', '2.5': 'Carrots', '2.99': 'Other tubers', '3.1': 'Beans', '3.2': 'Lentils', '3.3': 'Peas', '3.4': 'Soybeans', '3.99': 'Other pulses', '4.1': 'Cabbage', '4.2': 'Lettuce', '4.3': 'Spinach', '4.4': 'Moringa', '4.99': 'Other leafy veg', '5.1': 'Tomatoes', '5.2': 'Cucumber', '5.4': 'Eggplant/aubergine', '5.5': 'Zucchini', '5.6': 'Okra', '5.7': 'Pepper', '5.8': 'Onions', '5.99': 'Other non leafy vegs', '6.5': 'Sweet bananas', '6.6': 'Plantains', '6.7': 'Papaya', '6.8': 'Mango', '7': 'Pineapple', '7.1': 'Other fruit', '8.2': 'Groundnut/peanut', '8.3': 'Cashew nut', '8.99': 'Other nuts', '9.1': 'Cocoa', '9.2': 'Coffee', '9.99': 'Other food cash crop', '42': 'No crop production', '43': "Don't know ", '44': 'Refused'}
# Creating and Applying (new) domain for crp_landsize
# {1: 'Less than 1 ha', 2: '1 to 5 ha', 3: '5 to 10 ha', 4: 'More than 10 ha', 5: 'Don’t know', 6: 'Refused'}
# Creating and Applying (new) domain for crp_landright
# {1: 'Inherited', 2: 'Right given by community leader', 3: 'Cleared from bush or forest', 4: 'Purchased', 5: 'Received from state', 6: 'Sharecrop', 7: 'Rental', 8: 'Other ', 9: "Don't know", 10: 'Refused'}
# Creating and Applying (new) domain for crp_irrigation
# {1: 'Rainfed', 2: 'Canal', 3: 'Pump or mechanized', 4: 'Manually from water surface , well or other water source.', 5: 'Flood irrigation', 6: 'Other ', 7: "Don't know", 8: 'Refused'}
# Creating and Applying (new) domain for crp_seed_ownprod
# {1: 'Own production', 2: 'Purchased at market or agro-input shop', 3: 'Purchased directly from seed company', 4: 'Free distribution', 5: 'Community seed banks , farmer networks , etc.', 6: 'Government suppliers (ADPs)', 7: 'Other ', 8: "Don't know", 9: 'Refused'}
# Creating and Applying (existing) domain for derivate field crp_seed_ownprod
# Creating and Applying (existing) domain for derivate field crp_seed_market
# Creating and Applying (existing) domain for derivate field crp_seed_company
# Creating and Applying (existing) domain for derivate field crp_seed_freedist
# Creating and Applying (existing) domain for derivate field crp_seed_bank
# Creating and Applying (existing) domain for derivate field crp_seed_gov
# Creating and Applying (existing) domain for derivate field crp_seed_other
# Creating and Applying (existing) domain for derivate field crp_seed_dk
# Creating and Applying (existing) domain for derivate field crp_seed_ref
# Creating and Applying (new) domain for crp_area_change
# {1: 'A lot more (increased by more than 50%)', 2: 'More', 3: 'Same', 4: 'Less', 5: 'A lot less (less than half as much)', 6: "Don't know", 7: 'Refused'}
# Creating and Applying (new) domain for crp_harv_change
# {1: 'A lot more (increased by more than 50%)', 2: 'More', 3: 'Same', 4: 'Less', 5: 'A lot less (less than half as much)', 6: "Don't know", 7: 'Refused'}
# Creating and Applying (new) domain for crp_proddif
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# Creating and Applying (new) domain for crp_proddif_plantdisease
# {1: 'Plant disease', 2: 'Low quality of seeds', 3: 'Crop lost or damaged during growing season (locust, armyworm, or disasters other than plant disease)', 4: 'Could not access plot', 5: 'Could not  access fertilizer (not available on markets or prices too high)', 6: 'Could not access enough seeds (not available on markets or prices too high)', 7: 'Could not access insecticides', 8: 'Could not access extra labour or manpower', 9: 'Could not access machinery', 10: 'Could not access  fuel or electricity to power agricultural equipment', 11: 'Soil erosion', 12: 'Not enough irrigation water', 13: 'Other ', 14: "Don't know", 15: 'Refused'}
# Creating and Applying (existing) domain for derivate field crp_proddif_plantdisease
# Creating and Applying (existing) domain for derivate field crp_proddif_seedquality
# Creating and Applying (existing) domain for derivate field crp_proddif_lostordamaged
# Creating and Applying (existing) domain for derivate field crp_proddif_naplot
# Creating and Applying (existing) domain for derivate field crp_proddif_nafertilizer
# Creating and Applying (existing) domain for derivate field crp_proddif_naseeds
# Creating and Applying (existing) domain for derivate field crp_proddif_nainsecticides
# Creating and Applying (existing) domain for derivate field crp_proddif_nalabour
# Creating and Applying (existing) domain for derivate field crp_proddif_namachinery
# Creating and Applying (existing) domain for derivate field crp_proddif_nafuelorelect
# Creating and Applying (existing) domain for derivate field crp_proddif_soilerosion
# Creating and Applying (existing) domain for derivate field crp_proddif_irrigation
# Creating and Applying (existing) domain for derivate field crp_proddif_other
# Creating and Applying (existing) domain for derivate field crp_proddif_dk
# Creating and Applying (existing) domain for derivate field crp_proddif_ref
# Creating and Applying (new) domain for crp_salesdif
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# Creating and Applying (new) domain for crp_saledif_marketing_cost
# {1: 'Higher marketing costs (such as transportation)', 2: 'Damage and losses due to delay or inability to physically access markets', 3: 'Usual traders or local customers are not buying as much as usual', 4: 'Prices are too low', 5: 'Difficulty processing product (lack of processing inputs, equipment, etc)', 6: 'Other ', 7: "Don't know", 8: 'Refused'}
# Creating and Applying (existing) domain for derivate field crp_saledif_marketing_cost
# Creating and Applying (existing) domain for derivate field crp_saledif_damagelosses
# Creating and Applying (existing) domain for derivate field crp_saledif_lowdemand
# Creating and Applying (existing) domain for derivate field crp_saledif_lowprice
# Creating and Applying (existing) domain for derivate field crp_saledif_dif_processing
# Creating and Applying (existing) domain for derivate field crp_saledif_other
# Creating and Applying (existing) domain for derivate field crp_saledif_dk
# Creating and Applying (existing) domain for derivate field crp_saledif_ref
# Creating and Applying (new) domain for crp_salesprice
# {1: 'A lot more (increased by more than 50%)', 2: 'More', 3: 'Same', 4: 'Less', 5: 'A lot less (less than half as much)', 6: "Don't know", 7: 'Refused'}
# Creating and Applying (new) domain for crp_proc
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# Creating and Applying (new) domain for crp_proc_mach_mill
# {1: 'Mill', 2: 'Thresher', 3: 'Drying facilities', 4: 'None', 5: 'Other ', 6: "Don't know", 7: 'Refused'}
# Creating and Applying (existing) domain for derivate field crp_proc_mach_mill
# Creating and Applying (existing) domain for derivate field crp_proc_mach_thresher
# Creating and Applying (existing) domain for derivate field crp_proc_mach_dryingfacilit
# Creating and Applying (existing) domain for derivate field crp_proc_mach_none
# Creating and Applying (existing) domain for derivate field crp_proc_mach_other
# Creating and Applying (existing) domain for derivate field crp_proc_mach_dk
# Creating and Applying (existing) domain for derivate field crp_proc_mach_ref
# Creating and Applying (new) domain for crp_proc_owner_yours
# {1: 'Yourself', 2: 'Farm cooperative within community', 3: 'Farm cooperative outside of community', 4: 'Private shop or mill within community', 5: 'Private mill outside community', 6: 'Other ', 7: "Don't know", 8: 'Refused'}
# Creating and Applying (existing) domain for derivate field crp_proc_owner_yours
# Creating and Applying (existing) domain for derivate field crp_proc_owner_farmin
# Creating and Applying (existing) domain for derivate field crp_proc_owner_farmout
# Creating and Applying (existing) domain for derivate field crp_proc_owner_millin
# Creating and Applying (existing) domain for derivate field crp_proc_owner_millout
# Creating and Applying (existing) domain for derivate field crp_proc_owner_other
# Creating and Applying (existing) domain for derivate field crp_proc_owner_dk
# Creating and Applying (existing) domain for derivate field crp_proc_owner_ref
# Creating and Applying (new) domain for crp_proc_state
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# Creating and Applying (new) domain for ls_main
# {1: 'Cattle (cow , beef , veal , yak , buffalo)', 2: 'Goats', 3: 'Sheeps', 4: 'Swine', 5: 'Equine (donkey , horse , etc)', 6: 'Small domesticated mammals (rabbits , minks , guinea pigs , etc)', 7: 'Poultry (chicken , guineafowl , duck , etc)', 8: 'Camelids', 9: 'Other ', 10: "Don't know", 11: 'Refused'}
# Creating and Applying (new) domain for ls_num_nochange
# {1: 'No change in livestock number', 2: 'Did not sell as many', 3: 'Many more born', 4: 'Purchased or bartered more animals this year', 5: 'Received animals for free (restocking, gift)', 6: 'Animals died of poor health, malnutrition or injury', 7: 'Sold more than usual because of good prices', 8: 'Sold more than usual because of distress sales (unable to feed animal, need money urgently for household basic needs even if sales were unsustainable)', 9: 'Animal escaped or was lost or stolen', 10: 'Killed or gave away more animals than usual for household consumption or celebrations (marriage, funerals, etc)', 11: 'Other ', 12: 'Don’t know', 13: 'Refused'}
# Creating and Applying (existing) domain for derivate field ls_num_nochange
# Creating and Applying (existing) domain for derivate field ls_num_inc_didnotsellasmany
# Creating and Applying (existing) domain for derivate field ls_num_inc_moreborn
# Creating and Applying (existing) domain for derivate field ls_num_inc_purchbarterdmore
# Creating and Applying (existing) domain for derivate field ls_num_inc_receivedfree
# Creating and Applying (existing) domain for derivate field ls_num_dec_animalsdied
# Creating and Applying (existing) domain for derivate field ls_num_dec_soldmoregoodprice
# Creating and Applying (existing) domain for derivate field ls_num_dec_soldmoredistsale
# Creating and Applying (existing) domain for derivate field ls_num_dec_anmlescloststolen
# Creating and Applying (existing) domain for derivate field ls_num_dec_killedorgaveanml
# Creating and Applying (existing) domain for derivate field ls_num_inc_dec_other
# Creating and Applying (existing) domain for derivate field ls_num_inc_dec_dk
# Creating and Applying (existing) domain for derivate field ls_num_inc_dec_ref
# Creating and Applying (new) domain for ls_food_supply_openpasture
# {1: 'Open pasture', 2: 'Community-managed pasture land', 3: 'Owned or rented field or self-produced fodder', 4: 'Purchase feed or fodder on markets', 5: 'Other ', 6: "Don't know", 7: 'Refused'}
# Creating and Applying (existing) domain for derivate field ls_food_supply_openpasture
# Creating and Applying (existing) domain for derivate field ls_food_supply_commngpastureland
# Creating and Applying (existing) domain for derivate field ls_food_supply_fieldselfprodfod
# Creating and Applying (existing) domain for derivate field ls_food_supply_purchasefeedorfodderonmarkets
# Creating and Applying (existing) domain for derivate field ls_food_supply_other
# Creating and Applying (existing) domain for derivate field ls_food_supply_dk
# Creating and Applying (existing) domain for derivate field ls_food_supply_ref
# Creating and Applying (new) domain for ls_proddif
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# Creating and Applying (new) domain for ls_proddif_diffeedpurchase
# {1: 'Difficulty to purchase feed (prices or access to market)', 2: 'Constrained access to pasture', 3: 'Constrained access to water', 4: 'Difficulty to access veterinary services', 5: 'Difficulty to access veterinary inputs (medicine for animals, tools for animal health, etc)', 6: 'Livestock diseases', 7: 'Livestock theft or insecurity', 8: 'Poor access to livestock market to buy young animals', 9: 'No access to  credit', 10: 'Labour too expensive or income insufficient to hire labour or labourers are unavailable', 11: 'Other ', 12: "Don't know", 13: 'Refused'}
# Creating and Applying (existing) domain for derivate field ls_proddif_diffeedpurchase
# Creating and Applying (existing) domain for derivate field ls_proddif_constaccesstopasture
# Creating and Applying (existing) domain for derivate field ls_proddif_constaccesstowater
# Creating and Applying (existing) domain for derivate field ls_proddif_difaccessvetserv
# Creating and Applying (existing) domain for derivate field ls_proddif_difaccessvetinp
# Creating and Applying (existing) domain for derivate field ls_proddif_diseases
# Creating and Applying (existing) domain for derivate field ls_proddif_theftorinsecurity
# Creating and Applying (existing) domain for derivate field ls_proddif_pooraccesstolmarket
# Creating and Applying (existing) domain for derivate field ls_proddif_noaccesstocredit
# Creating and Applying (existing) domain for derivate field ls_proddif_lackoflabour
# Creating and Applying (existing) domain for derivate field ls_proddif_other
# Creating and Applying (existing) domain for derivate field ls_proddif_dk
# Creating and Applying (existing) domain for derivate field ls_proddif_ref
# Creating and Applying (new) domain for ls_salesmain
# {1: 'Cattle (cow , beef , veal , yak , buffalo)', 2: 'Goats', 3: 'Sheeps', 4: 'Swine', 5: 'Equine (donkey , horse , etc.)', 6: 'Small domesticated mammals (rabbits , minks , guinea pigs , etc)', 7: 'Poultry (chicken , guineafowl , duck , etc.)', 8: 'Camelids', 9: 'Eggs', 10: 'Milk or dairy products', 11: 'Skin or leather', 12: "Don't know", 13: 'Refused'}
# Creating and Applying (new) domain for ls_salesdif
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# Creating and Applying (new) domain for ls_salesdif_smallerprofits
# {1: 'Higher marketing costs (such as transportation)', 2: 'Damage and losses due to delay or inability to physically access markets (including limited storage capacity)', 3: 'Usual traders or local customers are not buying as much as usual', 4: 'Prices are too low', 5: 'Closure of slaughterhouses or difficulties accessing slaughterhouses', 6: 'Difficulties to process product other than closure of slaughterhouse (lack of access to processing inputs, equipment, etc)', 7: 'Other ', 8: "Don't know", 9: 'Refused'}
# Creating and Applying (existing) domain for derivate field ls_salesdif_smallerprofits
# Creating and Applying (existing) domain for derivate field ls_salesdif_damageandlosses
# Creating and Applying (existing) domain for derivate field ls_salesdif_lowdemand
# Creating and Applying (existing) domain for derivate field ls_salesdif_lowprices
# Creating and Applying (existing) domain for derivate field ls_salesdif_slaughterhouse
# Creating and Applying (existing) domain for derivate field ls_salesdif_processing
# Creating and Applying (existing) domain for derivate field ls_salesdif_other
# Creating and Applying (existing) domain for derivate field ls_salesdif_dk
# Creating and Applying (existing) domain for derivate field ls_salesdif_ref
# Creating and Applying (new) domain for ls_salesprice
# {1: 'A lot more (increased by more than 50%)', 2: 'More', 3: 'Same', 4: 'Less', 5: 'A lot less (less than half as much)', 6: "Don't know", 7: 'Refused'}
# Creating and Applying (new) domain for ls_proc
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# Creating and Applying (new) domain for ls_proc_slaughter
# {1: 'Slaughter', 2: 'Meat processing after slaughtering (drying, roasting, smoking, fresh meat)', 3: 'Dairy processing', 4: 'Leather', 5: 'Other ', 6: "Don't know", 7: 'Refused'}
# Creating and Applying (existing) domain for derivate field ls_proc_slaughter
# Creating and Applying (existing) domain for derivate field ls_proc_meatprocess
# Creating and Applying (existing) domain for derivate field ls_proc_dairyprocess
# Creating and Applying (existing) domain for derivate field ls_proc_leather
# Creating and Applying (existing) domain for derivate field ls_proc_other
# Creating and Applying (existing) domain for derivate field ls_proc_dk
# Creating and Applying (existing) domain for derivate field ls_proc_ref
# Creating and Applying (new) domain for ls_proc_fac_priv_cold_transp
# {1: 'Purchase private cold transportation services', 2: 'Cold transport from farm cooperative', 3: 'Slaughterhouse within community', 4: 'Slaughterhouse outside of community', 5: 'Dairy processing at farm', 6: 'Dairy processing in cooperative', 7: 'None', 8: 'Other ', 9: "Don't know", 10: 'Refused'}
# Creating and Applying (existing) domain for derivate field ls_proc_fac_priv_cold_transp
# Creating and Applying (existing) domain for derivate field ls_proc_fac_coop_cold_transp
# Creating and Applying (existing) domain for derivate field ls_proc_fac_slaughterinncomm
# Creating and Applying (existing) domain for derivate field ls_proc_fac_slaughteroutofcomm
# Creating and Applying (existing) domain for derivate field ls_proc_fac_farm_dairy
# Creating and Applying (existing) domain for derivate field ls_proc_fac_coop_dairy
# Creating and Applying (existing) domain for derivate field ls_proc_fac_other
# Creating and Applying (existing) domain for derivate field ls_proc_fac_none
# Creating and Applying (existing) domain for derivate field ls_proc_fac_dk
# Creating and Applying (existing) domain for derivate field ls_proc_fac_ref
# Creating and Applying (new) domain for ls_proc_fac_state
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# Creating and Applying (new) domain for fish_main_coastal
# {1: 'Coastal fishing', 2: 'Open sea fishing', 3: 'Fishing in lakes, ponds and rivers', 4: 'Aquaculture', 5: "Don't know", 6: 'Refused'}
# Creating and Applying (existing) domain for derivate field fish_main_coastal
# Creating and Applying (existing) domain for derivate field fish_main_opensea
# Creating and Applying (existing) domain for derivate field fish_main_lakespondsrivers
# Creating and Applying (existing) domain for derivate field fish_main_aquaculture
# Creating and Applying (existing) domain for derivate field fish_main_dk
# Creating and Applying (existing) domain for derivate field fish_main_ref
# Creating and Applying (new) domain for fish_change
# {1: 'A lot more (increased by more than 50%)', 2: 'More', 3: 'Same', 4: 'Less', 5: 'A lot less (less than half as much)', 6: "Don't know", 7: 'Refused'}
# Creating and Applying (new) domain for fish_proddif
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# Creating and Applying (new) domain for fish_proddif_find
# {1: 'Fish is more difficult to find than in previous years  in the same season', 2: 'Concerns and restrictions related to COVID-19 pandemic', 3: 'Difficulty accessing fuel (prices higher or not available)', 4: 'Difficulty accessing fishing material and-or other inputs (prices higher or not available)', 5: 'Labour too expensive or income insufficient to hire labour', 6: 'Other ', 7: "Don't know", 8: 'Refused'}
# Creating and Applying (existing) domain for derivate field fish_proddif_find
# Creating and Applying (existing) domain for derivate field fish_proddif_covid
# Creating and Applying (existing) domain for derivate field fish_proddif_fuel
# Creating and Applying (existing) domain for derivate field fish_proddif_inputs
# Creating and Applying (existing) domain for derivate field fish_proddif_labour
# Creating and Applying (existing) domain for derivate field fish_proddif_other
# Creating and Applying (existing) domain for derivate field fish_proddif_dk
# Creating and Applying (existing) domain for derivate field fish_proddif_ref
# Creating and Applying (new) domain for fish_inputdif_bait
# {1: 'Bait', 2: 'Net', 3: 'Gear', 4: 'Ice', 5: 'Fuel', 6: 'Boat repairs', 7: 'Other ', 8: "Don't know", 9: 'Refused'}
# Creating and Applying (existing) domain for derivate field fish_inputdif_bait
# Creating and Applying (existing) domain for derivate field fish_inputdif_net
# Creating and Applying (existing) domain for derivate field fish_inputdif_gear
# Creating and Applying (existing) domain for derivate field fish_inputdif_ice
# Creating and Applying (existing) domain for derivate field fish_inputdif_fuel
# Creating and Applying (existing) domain for derivate field fish_inputdif_boatrepairs
# Creating and Applying (existing) domain for derivate field fish_inputdif_other
# Creating and Applying (existing) domain for derivate field fish_inputdif_dk
# Creating and Applying (existing) domain for derivate field fish_inputdif_ref
# Creating and Applying (new) domain for fish_salesmain
# {1: 'Fresh fish (any kind)', 2: 'Dry fish (any kind)', 3: 'Smoked fish', 4: 'Seafood (any kind)', 5: 'Other ', 6: "Don't know", 7: 'Refused'}
# Creating and Applying (new) domain for fish_salesdif_1
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# Creating and Applying (new) domain for fish_saledif_smallerprofits
# {1: 'Higher marketing costs (such as transportation costs. fuel costs, etc)', 2: 'Damage and losses due to delay or inability to physically access markets (including limited storage capacity and closure of markets)', 3: 'Usual traders or local customers are not buying as much as usual', 4: 'Prices are too low', 5: 'Difficulties to process product (lack of access to processing inputs. equipment, etc)', 6: 'Other ', 7: "Don't know", 8: 'Refused'}
# Creating and Applying (existing) domain for derivate field fish_saledif_smallerprofits
# Creating and Applying (existing) domain for derivate field fish_saledif_damageandlosses
# Creating and Applying (existing) domain for derivate field fish_saledif_lowdemand
# Creating and Applying (existing) domain for derivate field fish_saledif_lowprices
# Creating and Applying (existing) domain for derivate field fish_saledif_processing
# Creating and Applying (existing) domain for derivate field fish_saledif_other
# Creating and Applying (existing) domain for derivate field fish_saledif_dk
# Creating and Applying (existing) domain for derivate field fish_saledif_ref
# Creating and Applying (new) domain for fish_salesprice
# {1: 'A lot more (increased by more than 50%)', 2: 'More', 3: 'Same', 4: 'Less', 5: 'A lot less (less than half as much)', 6: "Don't know", 7: 'Refused'}
# Creating and Applying (new) domain for fies_worried
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# Creating and Applying (new) domain for fies_healthy
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# Creating and Applying (new) domain for fies_fewfoods
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# Creating and Applying (new) domain for fies_skipped
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# Creating and Applying (new) domain for fies_ateless
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# Creating and Applying (new) domain for fies_ranout
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# Creating and Applying (new) domain for fies_ranout_hhs
# {1: 'Rarely (once or twice)', 2: 'Sometimes (in some weeks but not every week)', 3: 'Often (every week)', 4: "Don't know", 5: 'Refused'}
# Creating and Applying (new) domain for fies_hungry
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# Creating and Applying (new) domain for fies_hungry_hhs
# {1: 'Rarely (once or twice)', 2: 'Sometimes (in some weeks but not every week)', 3: 'Often (every week)', 4: "Don't know", 5: 'Refused'}
# Creating and Applying (new) domain for fies_whlday
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# Creating and Applying (new) domain for fies_whlday_hhs
# {1: 'Rarely (once or twice)', 2: 'Sometimes (in some weeks but not every week)', 3: 'Often (every week)', 4: "Don't know", 5: 'Refused'}
# Creating and Applying (new) domain for cs_spentsavings
# {1: 'Yes', 2: 'No - because it wasn’t necessary', 3: 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it', 4: 'Not applicable', 5: "Don't know", 6: 'Refused'}
# Creating and Applying (new) domain for cs_borrowmoney
# {1: 'Yes', 2: 'No - because it wasn’t necessary', 3: 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it', 4: 'Not applicable', 5: "Don't know", 6: 'Refused'}
# Creating and Applying (new) domain for cs_purchasedfoodcredit
# {1: 'Yes', 2: 'No - because it wasn’t necessary', 3: 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it', 4: 'Not applicable', 5: "Don't know", 6: 'Refused'}
# Creating and Applying (new) domain for cs_soldhhassetsgoods
# {1: 'Yes', 2: 'No - because it wasn’t necessary', 3: 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it', 4: 'Not applicable', 5: "Don't know", 6: 'Refused'}
# Creating and Applying (new) domain for cs_soldprodassets
# {1: 'Yes', 2: 'No - because it wasn’t necessary', 3: 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it', 4: 'Not applicable', 5: "Don't know", 6: 'Refused'}
# Creating and Applying (new) domain for cs_eatplantingseeds
# {1: 'Yes', 2: 'No - because it wasn’t necessary', 3: 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it', 4: 'Not applicable', 5: "Don't know", 6: 'Refused'}
# Creating and Applying (new) domain for cs_withdrewchild
# {1: 'Yes', 2: 'No - because it wasn’t necessary', 3: 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it', 4: 'Not applicable', 5: "Don't know", 6: 'Refused'}
# Creating and Applying (new) domain for cs_soldlandhouse
# {1: 'Yes', 2: 'No - because it wasn’t necessary', 3: 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it', 4: 'Not applicable', 5: "Don't know", 6: 'Refused'}
# Creating and Applying (new) domain for cs_begging
# {1: 'Yes', 2: 'No - because it wasn’t necessary', 3: 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it', 4: 'Not applicable', 5: "Don't know", 6: 'Refused'}
# Creating and Applying (new) domain for cs_soldfemanimals
# {1: 'Yes', 2: 'No - because it wasn’t necessary', 3: 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it', 4: 'Not applicable', 5: "Don't know", 6: 'Refused'}
# Creating and Applying (new) domain for hdds_cereals
# {1: 'Cereals (sorghum, millet, corn, wheat, rice, spaghetti, bread or insert any other locally available grain)', 2: 'Roots and tubers (white sweet potato, potato, yam, cassava or other tubers)', 3: 'Vegetables (all)', 4: 'Fruits (all)', 5: 'Meat, poultry and offal (beef, pork, lamb, goat, rabbit, wild game, chicken, duck, liver, kidney, heart, or other organ meats)', 6: 'Eggs', 7: 'Fish or shellfish (fresh or dried fish, shellfish)', 8: 'Legumes and nuts (beans, peas, peanut, lentils, almond, and/or other nuts)', 9: 'Milk and other dairy products (fresh milk, sour, yogurt, cheese, other dairy products)', 10: 'Oils and fat (cooking, butter, margarine, fat, oil, other oil)', 11: 'Sugar or sugary products (honey, jam, donuts, candy, chocolate, biscuits, pastries, cakes and other sweet products)', 12: 'Condiments (cocoa, salt, garlic, spices, yeast, baking powder, tomato or tomato sauce, meat or fish as a condiment), coffee, tea'}
# Creating and Applying (existing) domain for derivate field hdds_cereals
# Creating and Applying (existing) domain for derivate field hdds_condiments
# Creating and Applying (existing) domain for derivate field hdds_eggs
# Creating and Applying (existing) domain for derivate field hdds_fish
# Creating and Applying (existing) domain for derivate field hdds_fruits
# Creating and Applying (existing) domain for derivate field hdds_legumes
# Creating and Applying (existing) domain for derivate field hdds_meat
# Creating and Applying (existing) domain for derivate field hdds_milkdairy
# Creating and Applying (existing) domain for derivate field hdds_oils
# Creating and Applying (existing) domain for derivate field hdds_rootstubers
# Creating and Applying (existing) domain for derivate field hdds_sugar
# Creating and Applying (existing) domain for derivate field hdds_vegetables
# Creating and Applying (new) domain for need
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# Creating and Applying (new) domain for need_seeds
# {1: 'Seeds', 2: 'Fertilizers', 3: 'Pesticides', 4: 'Tools', 5: 'Access to irrigation water', 6: 'Access to land', 7: 'Animal feed', 8: 'Veterinary services', 9: 'Veterinary inputs', 10: 'Sales of animals with minimum garanteed price', 11: 'Restocking animals', 12: 'Support for processing product', 13: 'Support for transportation of animals or animal product (e.g. cold chains for milk)', 14: 'Access to tractors', 15: 'Marketing support', 16: 'Cash assistance', 17: 'Loans', 18: 'Storage equipment or facility (bags , containers , etc.)', 19: 'Technical support or extension services', 20: 'Land rehabilitation (in case of a disaster)', 21: 'Fisheries equipment or other support for fisheries', 22: 'Information on safety measures to carry out agricultural work in the context of the COVID-19 epidemic', 23: 'Other ', 24: "Don't know", 25: 'Refused'}
# Creating and Applying (existing) domain for derivate field need_seeds
# Creating and Applying (existing) domain for derivate field need_fertilizers
# Creating and Applying (existing) domain for derivate field need_pesticides
# Creating and Applying (existing) domain for derivate field need_tools
# Creating and Applying (existing) domain for derivate field need_accesstoirrigationwater
# Creating and Applying (existing) domain for derivate field need_accesstoland
# Creating and Applying (existing) domain for derivate field need_animalfeed
# Creating and Applying (existing) domain for derivate field need_veterinaryservices
# Creating and Applying (existing) domain for derivate field need_veterinaryinputs
# Creating and Applying (existing) domain for derivate field need_animalsalemingarantdprice
# Creating and Applying (existing) domain for derivate field need_restockinganimals
# Creating and Applying (existing) domain for derivate field need_supportforprocessprod
# Creating and Applying (existing) domain for derivate field need_supptransofanimalsorprod
# Creating and Applying (existing) domain for derivate field need_acstomechanisedequipprod
# Creating and Applying (existing) domain for derivate field need_marketingsupport
# Creating and Applying (existing) domain for derivate field need_cashassistance
# Creating and Applying (existing) domain for derivate field need_loans
# Creating and Applying (existing) domain for derivate field need_storageequipmentorfaci
# Creating and Applying (existing) domain for derivate field need_techsupporextensionserv
# Creating and Applying (existing) domain for derivate field need_landrehabilitation
# Creating and Applying (existing) domain for derivate field need_fishequiorothersuppforfish
# Creating and Applying (existing) domain for derivate field need_infoonsafetymeasures
# Creating and Applying (existing) domain for derivate field need_other
# Creating and Applying (existing) domain for derivate field need_dk
# Creating and Applying (existing) domain for derivate field need_ref
# Creating and Applying (new) domain for need_received_food
# {1: 'Food', 2: 'Cash vouchers', 3: 'Seeds', 4: 'Extension services', 5: 'Livestock feed', 6: 'Other ', 7: 'No assistance received', 8: "Don't know", 9: 'Refused'}
# Creating and Applying (existing) domain for derivate field need_received_food
# Creating and Applying (existing) domain for derivate field need_received_cashvouchers
# Creating and Applying (existing) domain for derivate field need_received_seeds
# Creating and Applying (existing) domain for derivate field need_received_extensionservices
# Creating and Applying (existing) domain for derivate field need_received_livestockfeed
# Creating and Applying (existing) domain for derivate field need_received_other
# Creating and Applying (existing) domain for derivate field need_received_noassistreceived
# Creating and Applying (existing) domain for derivate field need_received_dk
# Creating and Applying (existing) domain for derivate field need_received_ref
# Creating and Applying (new) domain for callback
# {1: 'Yes', 2: 'No'}
# Creating and Applying (new) domain for language2
# {1: 'English', 2: 'Other languages (consistent with resp_language)'}
