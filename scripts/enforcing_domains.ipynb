# %%
import pandas as pd
import xlrd
import arcpy
from pandas import ExcelWriter
from datetime import datetime
import os

# %%
startTime = datetime.now()
now = datetime.now().strftime('%Y%m%d%H%M%S')
temp_path = r'C:\temp\data_processing_exports'
#questionnaire_file = r'C:\git\hh_survey\household_questionnaire_geopoll_202105.xlsx' #the questionnaire file that we use for creating the table
questionnaire_file = r'C:\git\hh_survey\household_questionnaire_geopoll_EN_template_20210604_ISO3.xlsx'
coded_values_file = os.path.join(temp_path, "coded_values_%s.xlsx" % now) #intermediary output file with all categories and codes extracted from the questionnaire
writer = pd.ExcelWriter(coded_values_file, engine='xlsxwriter')
field_names_list = []
max_counter = 3000 #for testing purposes, we may need to limit the execution only to some items

# %%
def importallsheets(in_excel, out_gdb):
    ###this function import all sheets of an xlsx file into separate tables inside a GDB (with same name)
    print("max_counter: %s" % max_counter)
    counter = 0
    workbook = xlrd.open_workbook(in_excel)
    sheets = [sheet.name for sheet in workbook.sheets()]

    print('{} sheets found: {}'.format(len(sheets), ','.join(sheets)))
    for sheet in sheets:
        counter +=1
        if counter <= max_counter:
            # The out_table is based on the input excel file name
            # a underscore (_) separator followed by the sheet name
            out_table = os.path.join(
                out_gdb,
                arcpy.ValidateTableName(
                    "{0}".format(sheet),
                    out_gdb))

            print('Converting {} to {}'.format(sheet, out_table))

            # Perform the conversion
            arcpy.ExcelToTable_conversion(in_excel, out_table, sheet)
            

def make_attribute_dict(fc, code_field, value_field):
    #this function creates a dictionary based on a GDB table
    attdict = {}
    with arcpy.da.SearchCursor(fc, [code_field, value_field]) as cursor:
        for row in cursor:
            attdict[row[0]] = row[1]
    return attdict

def fix_category_formatting(category):
    #this function improves and standardizes the formatting of the categories' descriptions
     return category.replace("[","(").replace("]",")").replace("(specify)","").replace("/ ",", ").capitalize().replace("adps","ADPs").replace("idp","IDP").replace("covid","COVID").replace(" , ",", ").replace("staplec","staple") 

def insert_element_in_list_after_element(old_list, new_item,after_item): 
    new_list = []
    for each in old_list:
        if each == after_item:
            new_list.append(new_item)
        new_list.append(each)
    return new_list

# %%
##this section of the script reads the survey excel file and creates an excel file with multiple sheets:
### each sheet contains the coded value and description for a "Single choice" or "Open Ended-Select All That Apply" question.
###moreover, it creates and populates several lists that will be used later for defining each field of the final table names, types and domains

print("Opening questionnaire DF")
quest_df = pd.read_excel(open(questionnaire_file, 'rb'), sheet_name='survey',skiprows=2)
#create a list of all possible numbering
numbering = ["%s)" % n for n in range(1,200)] ## 1), 2), ... 200)
# initialize list of lists that will store the results
dict_derived_fieldnames = {} #this dict will group all derived fields in case of "Select All That Apply" type of questions
field_names_list = [] ##this list will contain all fields of the final table
text_type_fields = [] ##this list will contain all fields of the final table with TEXT type
range_type_fields = [] ##this list will contain all fields of the final table storing RANGE data  (will be LONG type)
double_type_fields = [] ##this list will contain all fields of the final table storing DOUBLE data  
##iterate the following for each row (so each question of the questionnaire)
all_derived_fieldnames = []
all_answers_with_other_option = [] ##this list will contain all "Other: specify" fields in Select all that apply type of questions
single_choice_questions_with_other_categories = [] ##this list will contain all "Other: specify" fields in single choice type of questions
quest_df = quest_df[quest_df['Suggested Qname'].notna()]
for index, row in quest_df.iterrows():
    try:
        first_derived_fieldname = "" #the name of the first derived field will be the main of the domain table
        derived_fieldnames = []
        codes_and_labels = []
        categories = str(row['English']).replace("\t","")
        question_name = row['Suggested Qname'].strip()  #Q Name
        question_type = row['Q Type']
        programming_instructions = row['Programming Instructions'] #this field contains coded values for crop_main
        print("\n\n----%s----" % question_name)
        #only for questions with pre-defined categories need domains
        if question_type in ("StartRecording","Single Choice","Open Ended-Single Choice", "Open Ended - Single Choice", "Open Ended-Select All That Apply",
                             "Select All That Apply","Open Ended - Select All That Apply "):
            if question_name == 'crp_main': #for this question only, coded values should be taken from field programming_instructions
                programming_lines = programming_instructions.splitlines()
                for programming_line in programming_lines:
                    if ")" in programming_line:
                        #print(programming_line)
                        index, category = programming_line.split(")")
                        category = fix_category_formatting(category)
                        codes_and_labels.append([index, category])
            else:
                #find all numbering present in the category string
                numbering_in_text = [n for n in numbering if n in categories]
                #print(numbering_in_text)
                ##the following loop creates a list "codes_and_labels" with all available codes&labels for each question
                for index in range(0,len(numbering_in_text)):
                    start = categories.find(numbering_in_text[index]) + len(numbering_in_text[index])
                    try:
                        end = categories.find(numbering_in_text[index + 1])
                        substring = categories[start:end].strip()
                    except:
                        # it fails during the last loop -> the last option is usually at the end of the string
                        substring = categories[start:].strip()
                    #print(substring)
                    category = fix_category_formatting(substring)
                    codes_and_labels.append([index +1, category])
                
            if question_type not in ["Open Ended-Select All That Apply","Select All That Apply","Open Ended - Select All That Apply "]:
                #so questions with NO derived fields
                field_names_list.append(question_name.strip())
                codes_and_labels_df = pd.DataFrame(codes_and_labels, columns=['code', 'label'])
                codes_and_labels_df.to_excel(writer, sheet_name=question_name)
                ##check if one of the option is other -> the question need 1 derived field for keeping the specified text
                if any(s[1].lower().strip() == "other" for s in codes_and_labels):
                    other_categories = [s[1] for s in codes_and_labels if s[1].lower().strip() == "other" ]
                    single_choice_derived_other_field = "%s_other" % question_name.strip()
                    single_choice_questions_with_other_categories.append(single_choice_derived_other_field)
                    field_names_list.append(single_choice_derived_other_field)
                    
            else:
                #so questions with derived fields
                numbering_in_qname = [n for n in numbering if n in question_name]
                for index in range(0, len(numbering_in_qname)):
                    start = question_name.find(numbering_in_qname[index]) + len(numbering_in_qname[index])
                    try:
                        end = question_name.find(numbering_in_qname[index + 1])
                        derived_field_name = question_name[start:end].strip()
                    except:
                        # it fails during the last loop -> the last option is usually at the end of the string
                        derived_field_name = question_name[start:].strip()
                    all_derived_fieldnames.append(derived_field_name)
                    derived_fieldnames.append(derived_field_name)
                    field_names_list.append(derived_field_name)
                    if derived_field_name[-6:] == "_other": ##this field will need to be STRING - with no domain (since it's a 'other specify')
                        all_answers_with_other_option.append(derived_field_name)
                    if index == 0:
                        first_derived_fieldname = derived_field_name
                        codes_and_labels_df = pd.DataFrame(codes_and_labels, columns=['code', 'label'])
                        #codes_and_labels_df.to_excel(writer, sheet_name=derived_field_name) #we don't need domain table for derived fields, since they will use YES NOT domain table
                dict_derived_fieldnames[first_derived_fieldname] = all_derived_fieldnames
        elif question_type == "Range":
            #these questions will be associated to LONG type fields
            field_names_list.append(question_name.strip())
            range_type_fields.append(question_name)
        elif question_type == "Open Ended":
            #these questions will be associated to TEXT type fields
            if not pd.isnull(question_name): #NaN rows we want to skip (i.e. OptIn question without a name in the survey)
                field_names_list.append(question_name)
                text_type_fields.append(question_name)
        else:
            print("QUESTION SKIPPED ---------", question_name, question_type)
    except:
        print("failed for some reasons")

#adding Yes No table (for derived fields domain)
d = {1:"Yes",0:"No"}
yesno_df = pd.DataFrame(d.items(), columns=['code', 'label'])
yesno_df.to_excel(writer, sheet_name='yes_no')
print("Saving codes and labels %s" % coded_values_file)

#print(all_answers_with_other_option)

#creating additional sheet with all derived fields, that will be used for a script that ensures that also these values are within the domains in the output table, in a later stage
list_of_yes_no_fields = []
for derived_field in all_derived_fieldnames:
    if derived_field not in all_answers_with_other_option:
        list_of_yes_no_fields.append(derived_field)
        
derived_fields_df = pd.DataFrame(list_of_yes_no_fields) 
#print(derived_fields_df.head())
derived_fields_df.to_excel(writer, sheet_name='derived_fields') 

# Close the Pandas Excel writer and output the Excel file.
writer.save()
# Out:
# Opening questionnaire DF
#
#
# ----calldispo----
#
#
# ----calldispo_answeringmachine----
# QUESTION SKIPPED --------- calldispo_answeringmachine nan
#
#
# ----calldispo_noanswer----
# QUESTION SKIPPED --------- calldispo_noanswer nan
#
#
# ----calldispo_underreview----
# QUESTION SKIPPED --------- calldispo_underreview nan
#
#
# ----calldispo_disconnected----
# QUESTION SKIPPED --------- calldispo_disconnected nan
#
#
# ----resp_language----
#
#
# ----introduction----
#
#
# ----resp_agree----
#
#
# ----resp_refusalwhy----
#
#
# ----resp_whencallback----
#
#
# ----callbackmessage_en----
#
#
# ----NA----
# QUESTION SKIPPED --------- NA nan
#
#
# ----resp_age----
#
#
# ----resp_gender----
#
#
# ----hh_admin1----
#
#
# ----hh_admin2_1----
#
#
# ----hh_admin2_2----
#
#
# ----quotareached----
#
#
# ----hh_agricactivity----
#
#
# ----hh_gender----
#
#
# ----hh_education----
#
#
# ----hh_wealth_water
#
# 1)hh_wealth_water_pvttap
# 2)hh_wealth_water_publictap
# 3)hh_wealth_water_protectwell
# 4)hh_wealth_water_bottle
# 5)hh_wealth_water_othersafe
# 6)hh_wealth_water_river
# 7)hh_wealth_water_unprotectwell
# 8)hh_wealth_water_spring
# 9)hh_wealth_water_canalsurface
# 10)hh_wealth_water_otherunsafe
# 11)hh_wealth_water_dk
# 12)hh_wealth_water_ref----
#
#
# ----hh_wealth_toilet----
#
#
# ----hh_wealth_light----
#
#
# ----hh_residencetype----
#
#
# ----hh_size----
#
#
# ----hh_maritalstat----
#
#
# ----hh_age----
#
#
# ----income_main----
#
#
# ----income_main_amount----
#
#
# ----income_main_amount_conf----
#
#
# ----income_main_comp----
#
#
# ----income_sec----
#
#
# ----income_sec_amount----
#
#
# ----income_sec_amount_conf----
#
#
# ----income_sec_comp----
#
#
# ----income_third----
#
#
# ----income_third_amount----
#
#
# ----income_third_amount_conf----
#
#
# ----income_third_comp----
#
#
# ----covid_policy
#
# 1) covid_goodstransp
# 2) covid_marketclosed
# 3) covid_borderclosed
# 4) covid_stayhome
# 5) covid_gatherings
# 6) covid_processclosed
# 7) covid_other
# 8) covid_none
# 9) covid_dk
# 10) covid_ref----
#
#
# ----shock_
#
# 1) shock_noshock
# 2) shock_sicknessordeathofhh
# 3) shock_lostemplorwork
# 4) shock_otherintrahhshock
# 5) shock_higherfoodprices
# 6) shock_higherfuelprices
# 7) shock_cantworkordobusiness
# 8) shock_othereconomicshock
# 9) shock_pestoutbreak
# 10) shock_plantdisease
# 11) shock_animaldisease
# 12) shock_napasture
# 13) shock_othercropandlivests
# 14) shock_coldtemporhail
# 15) shock_flood
# 16) shock_hurricane
# 17) shock_drought
# 18) shock_earthquake
# 19) shock_landslides
# 20) shock_firenatural
# 21) shock_othernathazard
# 22) shock_violenceinsecconf
# 23) shock_theftofprodassets
# 24) shock_fire
# 25) shock_othermanmadehazard
# 26) shock_dk
# 27) shock_ref----
#
#
# ----shock_otherspecified----
#
#
# ----hh_explanation----
#
#
# ----crp_main----
#
#
# ----crp_landsize----
#
#
# ----crp_landright----
#
#
# ----crp_irrigation----
#
#
# ----crp_seed_supply
#
# 1) crp_seed_ownprod
# 2) crp_seed_market
# 3) crp_seed_company
# 4) crp_seed_freedist
# 5) crp_seed_bank
# 6) crp_seed_gov
# 7) crp_seed_other
# 8) crp_seed_dk
# 9) crp_seed_ref----
#
#
# ----crp_area_change----
#
#
# ----crp_harv_change----
#
#
# ----crp_proddif----
#
#
# ----crp_proddif_
#
# 1) crp_proddif_plantdisease
# 2) crp_proddif_seedquality
# 3) crp_proddif_lostordamaged
# 4) crp_proddif_naplot
# 5) crp_proddif_nafertilizer
# 6) crp_proddif_naseeds
# 7) crp_proddif_nainsecticides
# 8) crp_proddif_nalabour
# 9) crp_proddif_namachinery
# 10) crp_proddif_nafuelorelect
# 11) crp_proddif_soilerosion
# 12) crp_proddif_irrigation
# 13) crp_proddif_other
# 14) crp_proddif_dk
# 15) crp_proddif_ref----
#
#
# ----crp_salesdif----
#
#
# ----crp_saledif_
#
# 1) crp_saledif_marketing_cost
# 2) crp_saledif_damagelosses
# 3) crp_saledif_lowdemand
# 4) crp_saledif_lowprice
# 5) crp_saledif_dif_processing
# 6) crp_saledif_other
# 7) crp_saledif_dk
# 8) crp_saledif_ref----
#
#
# ----crp_salesprice----
#
#
# ----crp_proc----
#
#
# ----crp_proc_mach_
#
# 1) crp_proc_mach_mill
# 2) crp_proc_mach_thresher
# 3) crp_proc_mach_dryingfacilit
# 4)crp_proc_mach_none
# 5) crp_proc_mach_other
# 6) crp_proc_mach_dk
# 7) crp_proc_mach_ref----
#
#
# ----crp_proc_owner_
#
# 1) crp_proc_owner_yours
# 2) crp_proc_owner_farmin
# 3) crp_proc_owner_farmout
# 4) crp_proc_owner_millin
# 5) crp_proc_owner_millout
# 6) crp_proc_owner_other
# 7) crp_proc_owner_dk
# 8) crp_proc_owner_ref----
#
#
# ----crp_proc_state----
#
#
# ----ls_main----
#
#
# ----ls_num_lastyr----
#
#
# ----ls_num_now----
#
#
# ----ls_num_
#
# 1)ls_num_nochange
# 2) ls_num_inc_didnotsellasmany
# 3) ls_num_inc_moreborn
# 4) ls_num_inc_purchbarterdmore
# 5) ls_num_inc_receivedfree
# 6)ls_num_dec_animalsdied
# 7)ls_num_dec_soldmoregoodprice
# 8)ls_num_dec_soldmoredistsale
# 9)ls_num_dec_anmlescloststolen
# 10)ls_num_dec_killedorgaveanml
# 11)ls_num_inc_dec_other
# 12)ls_num_inc_dec_dk
# 13)ls_num_inc_dec_ref----
#
#
# ----ls_food_supply
#
# 1) ls_food_supply_openpasture
# 2) ls_food_supply_commngpastureland
# 3) ls_food_supply_fieldselfprodfod
# 4) ls_food_supply_purchasefeedorfodderonmarkets
# 5) ls_food_supply_other
# 6) ls_food_supply_dk
# 7) ls_food_supply_ref----
#
#
# ----ls_proddif----
#
#
# ----ls_proddif_
#
# 1) ls_proddif_diffeedpurchase
# 2) ls_proddif_constaccesstopasture
# 3) ls_proddif_constaccesstowater
# 4) ls_proddif_difaccessvetserv
# 5) ls_proddif_difaccessvetinp
# 6) ls_proddif_diseases
# 7) ls_proddif_theftorinsecurity
# 8) ls_proddif_pooraccesstolmarket
# 9) ls_proddif_noaccesstocredit
# 10) ls_proddif_lackoflabour
# 11) ls_proddif_other
# 12) ls_proddif_dk
# 13) ls_proddif_ref----
#
#
# ----ls_salesmain----
#
#
# ----ls_salesdif----
#
#
# ----ls_salesdif_
#
# 1) ls_salesdif_smallerprofits
# 2) ls_salesdif_damageandlosses
# 3) ls_salesdif_lowdemand
# 4) ls_salesdif_lowprices
# 5)  ls_salesdif_slaughterhouse
# 6) ls_salesdif_processing
# 7) ls_salesdif_other
# 8) ls_salesdif_dk
# 9) ls_salesdif_ref----
#
#
# ----ls_salesprice----
#
#
# ----ls_proc----
#
#
# ----ls_proc_
# 1) ls_proc_slaughter
# 2)ls_proc_meatprocess
# 3) ls_proc_dairyprocess
# 4) ls_proc_leather
# 5) ls_proc_other
# 6) ls_proc_dk
# 7) ls_proc_ref----
#
#
# ----ls_proc_fac_
# 1) ls_proc_fac_priv_cold_transp
# 2) ls_proc_fac_coop_cold_transp
# 3) ls_proc_fac_slaughterinncomm
# 4) ls_proc_fac_slaughteroutofcomm
# 5) ls_proc_fac_farm_dairy
# 6) ls_proc_fac_coop_dairy
# 7) ls_proc_fac_other
# 8)ls_proc_fac_none
# 9) ls_proc_fac_dk
# 10) ls_proc_fac_ref----
#
#
# ----ls_proc_fac_state----
#
#
# ----fish_main_
#
# 1) fish_main_coastal
# 2) fish_main_opensea
# 3) fish_main_lakespondsrivers
# 4) fish_main_aquaculture
# 5) fish_main_dk
# 6) fish_main_ref----
#
#
# ----fish_change----
#
#
# ----fish_proddif----
#
#
# ----fish_proddif_
#
# 1) fish_proddif_find
# 2) fish_proddif_covid
# 3) fish_proddif_fuel
# 4) fish_proddif_inputs
# 5) fish_proddif_labour
# 6) fish_proddif_other
# 7) fish_proddif_dk
# 8) fish_proddif_ref----
#
#
# ----fish_inputdif_
#
# 1) fish_inputdif_bait
# 2)fish_inputdif_net
# 3) fish_inputdif_gear
# 4) fish_inputdif_ice
# 5) fish_inputdif_fuel
# 6) fish_inputdif_boatrepairs
# 7) fish_inputdif_other
# 8)fish_inputdif_dk
# 9) fish_inputdif_ref----
#
#
# ----fish_salesmain----
#
#
# ----fish_salesdif_1----
#
#
# ----fish_saledif_
#
# 1) fish_saledif_smallerprofits
# 2) fish_saledif_damageandlosses
# 3) fish_saledif_lowdemand
# 4) fish_saledif_lowprices
# 5) fish_saledif_processing
# 6) fish_saledif_other
# 7) fish_saledif_dk
# 8) fish_saledif_ref----
#
#
# ----fish_salesprice----
#
#
# ----fies----
#
#
# ----fies_worried----
#
#
# ----fies_healthy----
#
#
# ----fies_fewfoods----
#
#
# ----fies_skipped----
#
#
# ----fies_ateless----
#
#
# ----fies_ranout----
#
#
# ----fies_ranout_hhs----
#
#
# ----fies_hungry----
#
#
# ----fies_hungry_hhs----
#
#
# ----fies_whlday----
#
#
# ----fies_whlday_hhs----
#
#
# ----copingstrategies----
#
#
# ----cs_stress_hh_assets----
#
#
# ----cs_stress_spent_savings----
#
#
# ----cs_stress_sold_more_animals----
#
#
# ----cs_stress_eat_elsewhere----
#
#
# ----cs_stress_borrowed_or_helped----
#
#
# ----cs_stress_credit----
#
#
# ----cs_stress_borrowed_money----
#
#
# ----cs_stress_changed_school----
#
#
# ----cs_crisis_sold_productive_asset----
#
#
# ----cs_crisis_no_school----
#
#
# ----cs_crisis_reduced_health_exp----
#
#
# ----cs_crisis_harv_immature_crops----
#
#
# ----cs_crisis_consumed_seed_stocks----
#
#
# ----cs_crisis_decr_agric_input_exp----
#
#
# ----cs_emergency_sold_house----
#
#
# ----cs_emergency_begged----
#
#
# ----cs_emergency_illegal----
#
#
# ----cs_emergency_sold_last_female----
#
#
# ----cs_emergency_hh_migration----
#
#
# ----hdds
#
# 1) hdds_cereals
# 2) hdds_rootstubers
# 3) hdds_vegetables
# 4) hdds_fruits
# 5) hdds_meat
# 6) hdds_eggs
# 7) hdds_fish
# 8) hdds_legumes
# 9) hdds_milkdairy
# 10) hdds_oils
# 11)hdds_sugar
# 12) hdds_condiments----
#
#
# ----hdds_confirmation----
#
#
# ----need----
#
#
# ----need_
#
# 1) need_seeds
# 2) need_fertilizers
# 3) need_pesticides
# 4) need_tools
# 5) need_accesstoirrigationwater
# 6) need_accesstoland
# 7) need_animalfeed
# 8) need_veterinaryservices
# 9) need_veterinaryinputs
# 10) need_animalsalemingarantdprice
# 11) need_restockinganimals
# 12) need_supportforprocessprod
# 13) need_supptransofanimalsorprod
# 14) need_acstomechanisedequipprod
# 15) need_marketingsupport
# 16) need_cashassistance
# 17) need_loans
# 18) need_storageequipmentorfaci
# 19) need_techsupporextensionserv
# 20) need_landrehabilitation
# 21) need_fishequiorothersuppforfish
# 22) need_infoonsafetymeasures
# 23) need_other
# 24) need_dk
# 25) need_ref----
#
#
# ----need_received_
#
# 1) need_received_food
# 2) need_received_cashvouchers
# 3) need_received_seeds
# 4) need_received_extensionservices
# 5) need_received_livestockfeed
# 6) need_received_other
# 7) need_received_noassistreceived
# 8) need_received_dk
# 9) need_received_ref----
#
#
# ----callback----
#
#
# ----language2----
#
#
# ----closeout----
# QUESTION SKIPPED --------- closeout nan
# Saving codes and labels C:\temp\data_processing_exports\coded_values_20210609181129.xlsx

# %%
###this section creates a new GDB
gdb_name = "fGDB_with_coded_values_%s.gdb" % now
output_gdb = os.path.join(temp_path, gdb_name)
arcpy.CreateFileGDB_management(temp_path,gdb_name)
# Out:
# <Result 'C:\\temp\\data_processing_exports\\fGDB_with_coded_values_20210609181129.gdb'>

# %%
##here we and import each table with coded values and description into the GDB
###it can take up to 5 seconds per table - and we normally process hundreds of table.
####for this reason, for testing purposes edit variable max_counter in the first cell of this notebook


importallsheets(coded_values_file, output_gdb)
# Out:
# max_counter: 3000
# 88 sheets found: calldispo,resp_language,introduction,resp_agree,resp_refusalwhy,resp_gender,hh_admin1,hh_admin2_1,hh_admin2_2,quotareached,hh_agricactivity,hh_gender,hh_education,hh_wealth_toilet,hh_wealth_light,hh_residencetype,hh_maritalstat,hh_age,income_main,income_main_amount_conf,income_main_comp,income_sec,income_sec_amount_conf,income_sec_comp,income_third,income_third_amount_conf,income_third_comp,crp_main,crp_landsize,crp_landright,crp_irrigation,crp_area_change,crp_harv_change,crp_proddif,crp_salesdif,crp_salesprice,crp_proc,crp_proc_state,ls_main,ls_proddif,ls_salesmain,ls_salesdif,ls_salesprice,ls_proc,ls_proc_fac_state,fish_change,fish_proddif,fish_salesmain,fish_salesdif_1,fish_salesprice,fies,fies_worried,fies_healthy,fies_fewfoods,fies_skipped,fies_ateless,fies_ranout,fies_ranout_hhs,fies_hungry,fies_hungry_hhs,fies_whlday,fies_whlday_hhs,copingstrategies,cs_stress_hh_assets,cs_stress_spent_savings,cs_stress_sold_more_animals,cs_stress_eat_elsewhere,cs_stress_borrowed_or_helped,cs_stress_credit,cs_stress_borrowed_money,cs_stress_changed_school,cs_crisis_sold_productive_asset,cs_crisis_no_school,cs_crisis_reduced_health_exp,cs_crisis_harv_immature_crops,cs_crisis_consumed_seed_stocks,cs_crisis_decr_agric_input_exp,cs_emergency_sold_house,cs_emergency_begged,cs_emergency_illegal,cs_emergency_sold_last_female,cs_emergency_hh_migration,hdds_confirmation,need,callback,language2,yes_no,derived_fields
# Converting calldispo to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\calldispo
# Converting resp_language to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\resp_language
# Converting introduction to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\introduction
# Converting resp_agree to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\resp_agree
# Converting resp_refusalwhy to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\resp_refusalwhy
# Converting resp_gender to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\resp_gender
# Converting hh_admin1 to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\hh_admin1
# Converting hh_admin2_1 to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\hh_admin2_1
# Converting hh_admin2_2 to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\hh_admin2_2
# Converting quotareached to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\quotareached
# Converting hh_agricactivity to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\hh_agricactivity
# Converting hh_gender to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\hh_gender
# Converting hh_education to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\hh_education
# Converting hh_wealth_toilet to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\hh_wealth_toilet
# Converting hh_wealth_light to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\hh_wealth_light
# Converting hh_residencetype to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\hh_residencetype
# Converting hh_maritalstat to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\hh_maritalstat
# Converting hh_age to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\hh_age
# Converting income_main to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\income_main
# Converting income_main_amount_conf to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\income_main_amount_conf
# Converting income_main_comp to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\income_main_comp
# Converting income_sec to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\income_sec
# Converting income_sec_amount_conf to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\income_sec_amount_conf
# Converting income_sec_comp to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\income_sec_comp
# Converting income_third to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\income_third
# Converting income_third_amount_conf to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\income_third_amount_conf
# Converting income_third_comp to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\income_third_comp
# Converting crp_main to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\crp_main
# Converting crp_landsize to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\crp_landsize
# Converting crp_landright to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\crp_landright
# Converting crp_irrigation to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\crp_irrigation
# Converting crp_area_change to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\crp_area_change
# Converting crp_harv_change to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\crp_harv_change
# Converting crp_proddif to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\crp_proddif
# Converting crp_salesdif to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\crp_salesdif
# Converting crp_salesprice to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\crp_salesprice
# Converting crp_proc to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\crp_proc
# Converting crp_proc_state to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\crp_proc_state
# Converting ls_main to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\ls_main
# Converting ls_proddif to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\ls_proddif
# Converting ls_salesmain to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\ls_salesmain
# Converting ls_salesdif to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\ls_salesdif
# Converting ls_salesprice to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\ls_salesprice
# Converting ls_proc to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\ls_proc
# Converting ls_proc_fac_state to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\ls_proc_fac_state
# Converting fish_change to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\fish_change
# Converting fish_proddif to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\fish_proddif
# Converting fish_salesmain to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\fish_salesmain
# Converting fish_salesdif_1 to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\fish_salesdif_1
# Converting fish_salesprice to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\fish_salesprice
# Converting fies to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\fies
# Converting fies_worried to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\fies_worried
# Converting fies_healthy to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\fies_healthy
# Converting fies_fewfoods to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\fies_fewfoods
# Converting fies_skipped to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\fies_skipped
# Converting fies_ateless to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\fies_ateless
# Converting fies_ranout to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\fies_ranout
# Converting fies_ranout_hhs to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\fies_ranout_hhs
# Converting fies_hungry to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\fies_hungry
# Converting fies_hungry_hhs to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\fies_hungry_hhs
# Converting fies_whlday to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\fies_whlday
# Converting fies_whlday_hhs to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\fies_whlday_hhs
# Converting copingstrategies to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\copingstrategies
# Converting cs_stress_hh_assets to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\cs_stress_hh_assets
# Converting cs_stress_spent_savings to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\cs_stress_spent_savings
# Converting cs_stress_sold_more_animals to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\cs_stress_sold_more_animals
# Converting cs_stress_eat_elsewhere to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\cs_stress_eat_elsewhere
# Converting cs_stress_borrowed_or_helped to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\cs_stress_borrowed_or_helped
# Converting cs_stress_credit to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\cs_stress_credit
# Converting cs_stress_borrowed_money to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\cs_stress_borrowed_money
# Converting cs_stress_changed_school to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\cs_stress_changed_school
# Converting cs_crisis_sold_productive_asset to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\cs_crisis_sold_productive_asset
# Converting cs_crisis_no_school to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\cs_crisis_no_school
# Converting cs_crisis_reduced_health_exp to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\cs_crisis_reduced_health_exp
# Converting cs_crisis_harv_immature_crops to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\cs_crisis_harv_immature_crops
# Converting cs_crisis_consumed_seed_stocks to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\cs_crisis_consumed_seed_stocks
# Converting cs_crisis_decr_agric_input_exp to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\cs_crisis_decr_agric_input_exp
# Converting cs_emergency_sold_house to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\cs_emergency_sold_house
# Converting cs_emergency_begged to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\cs_emergency_begged
# Converting cs_emergency_illegal to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\cs_emergency_illegal
# Converting cs_emergency_sold_last_female to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\cs_emergency_sold_last_female
# Converting cs_emergency_hh_migration to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\cs_emergency_hh_migration
# Converting hdds_confirmation to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\hdds_confirmation
# Converting need to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\need
# Converting callback to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\callback
# Converting language2 to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\language2
# Converting yes_no to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\yes_no
# Converting derived_fields to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\derived_fields

# %%
###it reads the survey file and creates an excel file with all field names of the outputs table.
###then it imports the empty output table template to the GDB, and calls it master_table. this table will be the future master table
###coded values will be enforced there.
#print(field_names_list)
#insert opening fields that come from Geopoll and are not captured by the questionnaire file
opening_fields = [["survey_id",'TEXT'],["operator_id",'TEXT'],["adm0_name",'TEXT'],["adm0_ISO3",'TEXT'],["adm1_pcode",'TEXT'], ["adm1_name",'TEXT'],["adm2_pcode",'TEXT'],["adm2_name",'TEXT'],
["survey_created_date",'TEXT'],["opt_in_date",'TEXT'],["total_case_duration",'TEXT'],["weight",'DOUBLE']]


#manage opening fields type
opening_fields_names_text = [i[0] for i in opening_fields if i[1] == 'TEXT']
opening_fields_names_short = [i[0] for i in opening_fields if i[1] == 'SHORT']
opening_fields_names_range = [i[0] for i in opening_fields if i[1] == 'RANGE']
opening_fields_names_date = [i[0] for i in opening_fields if i[1] == 'DATE']
opening_fields_names_double = [i[0] for i in opening_fields if i[1] == 'DOUBLE']

text_type_fields += opening_fields_names_text + single_choice_questions_with_other_categories
text_type_fields += all_answers_with_other_option
range_type_fields += opening_fields_names_range
double_type_fields += opening_fields_names_double

opening_field_names = [i[0] for i in opening_fields]
field_names_list = opening_field_names + field_names_list

#some fields in the questionnaire should be removed from the master table
useless_fields = ['callbackmessage_en', 'hh_admin1', 'calldispo', 'hh_admin2_1', 'hh_admin2_2', 'quotareached', 'resp_refusalwhy', 'resp_whencallback', 'fies','copingstrategies',
                 "introduction",'hdds_confirmation','income_main_amount_conf','income_sec_amount_conf','income_third_amount_conf']


s_useless_fields = set(useless_fields)  

field_names_list = [x for x in field_names_list if x not in s_useless_fields]

#adding hh_size_range
text_type_fields.append("hh_size_range")
#field_names_list = insert_element_in_list_after_element(field_names_list, "hh_size_range", "hh_size")

survey_empty_table_df = pd.DataFrame(columns=[field_names_list])
survey_empty_table_xlsx = os.path.join(temp_path, "survey_empty_table_%s.xlsx" % now)
writer = pd.ExcelWriter(survey_empty_table_xlsx, engine='xlsxwriter')
survey_empty_table_df.to_excel(writer, sheet_name="master_table")
writer.save()
#print(field_names_list)

# %%
###this section imports the excel file just created into the GDB

importallsheets(survey_empty_table_xlsx, output_gdb)
# Out:
# max_counter: 3000
# 1 sheets found: master_table
# Converting master_table to C:\temp\data_processing_exports\fGDB_with_coded_values_20210609181129.gdb\master_table

# %%
##there is always an unwanted field to remove
try:
    arcpy.DeleteField_management(os.path.join(output_gdb, "master_table"),"COL_A")
except:
    print ("field COL_A does not exist")

# %%
### This section alters each fields type in the survey master table
###domain related fiels shuld be integer, in order to enforce coded values, except crop_main

##string fields: open ended questions + crop_main
##long fields: range and numbers related questions (age, currency, hh size...)
##short fields: coded values questions

GDB_survey_table = os.path.join(output_gdb,"master_table")
field_names = [f.name for f in arcpy.ListFields(GDB_survey_table)]
counter = 0
for field in field_names:
    if field in field_names_list:
        counter +=1
        print("%s) changing type for field %s" % (counter,field))
        try:
            if field == 'crp_main' or field in text_type_fields: #crp_main is associated to text codes since they have possible dots (.) for subcategories
                arcpy.management.AlterField(GDB_survey_table, field, field_type = "TEXT")
            elif field in range_type_fields: #i.e. currencies
                arcpy.management.AlterField(GDB_survey_table, field, field_type = "LONG")
            elif field in double_type_fields: #i.e. weight
                arcpy.management.AlterField(GDB_survey_table, field, field_type = "DOUBLE")
            else: #all other fields are short integer (simple  code values)
                arcpy.management.AlterField(GDB_survey_table, field, field_type = "SHORT")
        except:
            pass
# Out:
# 1) changing type for field survey_id
# 2) changing type for field operator_id
# 3) changing type for field adm0_name
# 4) changing type for field adm0_ISO3
# 5) changing type for field adm1_pcode
# 6) changing type for field adm1_name
# 7) changing type for field adm2_pcode
# 8) changing type for field adm2_name
# 9) changing type for field survey_created_date
# 10) changing type for field opt_in_date
# 11) changing type for field total_case_duration
# 12) changing type for field weight
# 13) changing type for field percent
# 14) changing type for field resp_language
# 15) changing type for field resp_agree
# 16) changing type for field resp_refusalwhy_other
# 17) changing type for field resp_age
# 18) changing type for field resp_gender
# 19) changing type for field hh_agricactivity
# 20) changing type for field hh_gender
# 21) changing type for field hh_education
# 22) changing type for field hh_wealth_water_pvttap
# 23) changing type for field hh_wealth_water_publictap
# 24) changing type for field hh_wealth_water_protectwell
# 25) changing type for field hh_wealth_water_bottle
# 26) changing type for field hh_wealth_water_othersafe
# 27) changing type for field hh_wealth_water_river
# 28) changing type for field hh_wealth_water_unprotectwell
# 29) changing type for field hh_wealth_water_spring
# 30) changing type for field hh_wealth_water_canalsurface
# 31) changing type for field hh_wealth_water_otherunsafe
# 32) changing type for field hh_wealth_water_dk
# 33) changing type for field hh_wealth_water_ref
# 34) changing type for field hh_wealth_toilet
# 35) changing type for field hh_wealth_light
# 36) changing type for field hh_residencetype
# 37) changing type for field hh_size_range
# 38) changing type for field hh_size
# 39) changing type for field hh_maritalstat
# 40) changing type for field hh_age
# 41) changing type for field income_main
# 42) changing type for field income_main_amount
# 43) changing type for field income_main_comp
# 44) changing type for field income_sec
# 45) changing type for field income_sec_amount
# 46) changing type for field income_sec_comp
# 47) changing type for field income_third
# 48) changing type for field income_third_amount
# 49) changing type for field income_third_comp
# 50) changing type for field covid_goodstransp
# 51) changing type for field covid_marketclosed
# 52) changing type for field covid_borderclosed
# 53) changing type for field covid_stayhome
# 54) changing type for field covid_gatherings
# 55) changing type for field covid_processclosed
# 56) changing type for field covid_other
# 57) changing type for field covid_none
# 58) changing type for field covid_dk
# 59) changing type for field covid_ref
# 60) changing type for field shock_noshock
# 61) changing type for field shock_sicknessordeathofhh
# 62) changing type for field shock_lostemplorwork
# 63) changing type for field shock_otherintrahhshock
# 64) changing type for field shock_higherfoodprices
# 65) changing type for field shock_higherfuelprices
# 66) changing type for field shock_cantworkordobusiness
# 67) changing type for field shock_othereconomicshock
# 68) changing type for field shock_pestoutbreak
# 69) changing type for field shock_plantdisease
# 70) changing type for field shock_animaldisease
# 71) changing type for field shock_napasture
# 72) changing type for field shock_othercropandlivests
# 73) changing type for field shock_coldtemporhail
# 74) changing type for field shock_flood
# 75) changing type for field shock_hurricane
# 76) changing type for field shock_drought
# 77) changing type for field shock_earthquake
# 78) changing type for field shock_landslides
# 79) changing type for field shock_firenatural
# 80) changing type for field shock_othernathazard
# 81) changing type for field shock_violenceinsecconf
# 82) changing type for field shock_theftofprodassets
# 83) changing type for field shock_fire
# 84) changing type for field shock_othermanmadehazard
# 85) changing type for field shock_dk
# 86) changing type for field shock_ref
# 87) changing type for field shock_otherspecified
# 88) changing type for field hh_explanation
# 89) changing type for field crp_main
# 90) changing type for field crp_landsize
# 91) changing type for field crp_landright
# 92) changing type for field crp_landright_other
# 93) changing type for field crp_irrigation
# 94) changing type for field crp_irrigation_other
# 95) changing type for field crp_seed_ownprod
# 96) changing type for field crp_seed_market
# 97) changing type for field crp_seed_company
# 98) changing type for field crp_seed_freedist
# 99) changing type for field crp_seed_bank
# 100) changing type for field crp_seed_gov
# 101) changing type for field crp_seed_other
# 102) changing type for field crp_seed_dk
# 103) changing type for field crp_seed_ref
# 104) changing type for field crp_area_change
# 105) changing type for field crp_harv_change
# 106) changing type for field crp_proddif
# 107) changing type for field crp_proddif_plantdisease
# 108) changing type for field crp_proddif_seedquality
# 109) changing type for field crp_proddif_lostordamaged
# 110) changing type for field crp_proddif_naplot
# 111) changing type for field crp_proddif_nafertilizer
# 112) changing type for field crp_proddif_naseeds
# 113) changing type for field crp_proddif_nainsecticides
# 114) changing type for field crp_proddif_nalabour
# 115) changing type for field crp_proddif_namachinery
# 116) changing type for field crp_proddif_nafuelorelect
# 117) changing type for field crp_proddif_soilerosion
# 118) changing type for field crp_proddif_irrigation
# 119) changing type for field crp_proddif_other
# 120) changing type for field crp_proddif_dk
# 121) changing type for field crp_proddif_ref
# 122) changing type for field crp_salesdif
# 123) changing type for field crp_saledif_marketing_cost
# 124) changing type for field crp_saledif_damagelosses
# 125) changing type for field crp_saledif_lowdemand
# 126) changing type for field crp_saledif_lowprice
# 127) changing type for field crp_saledif_dif_processing
# 128) changing type for field crp_saledif_other
# 129) changing type for field crp_saledif_dk
# 130) changing type for field crp_saledif_ref
# 131) changing type for field crp_salesprice
# 132) changing type for field crp_proc
# 133) changing type for field crp_proc_mach_mill
# 134) changing type for field crp_proc_mach_thresher
# 135) changing type for field crp_proc_mach_dryingfacilit
# 136) changing type for field crp_proc_mach_none
# 137) changing type for field crp_proc_mach_other
# 138) changing type for field crp_proc_mach_dk
# 139) changing type for field crp_proc_mach_ref
# 140) changing type for field crp_proc_owner_yours
# 141) changing type for field crp_proc_owner_farmin
# 142) changing type for field crp_proc_owner_farmout
# 143) changing type for field crp_proc_owner_millin
# 144) changing type for field crp_proc_owner_millout
# 145) changing type for field crp_proc_owner_other
# 146) changing type for field crp_proc_owner_dk
# 147) changing type for field crp_proc_owner_ref
# 148) changing type for field crp_proc_state
# 149) changing type for field ls_main
# 150) changing type for field ls_main_other
# 151) changing type for field ls_num_lastyr
# 152) changing type for field ls_num_now
# 153) changing type for field ls_num_nochange
# 154) changing type for field ls_num_inc_didnotsellasmany
# 155) changing type for field ls_num_inc_moreborn
# 156) changing type for field ls_num_inc_purchbarterdmore
# 157) changing type for field ls_num_inc_receivedfree
# 158) changing type for field ls_num_dec_animalsdied
# 159) changing type for field ls_num_dec_soldmoregoodprice
# 160) changing type for field ls_num_dec_soldmoredistsale
# 161) changing type for field ls_num_dec_anmlescloststolen
# 162) changing type for field ls_num_dec_killedorgaveanml
# 163) changing type for field ls_num_inc_dec_other
# 164) changing type for field ls_num_inc_dec_dk
# 165) changing type for field ls_num_inc_dec_ref
# 166) changing type for field ls_food_supply_openpasture
# 167) changing type for field ls_food_supply_commngpastureland
# 168) changing type for field ls_food_supply_fieldselfprodfod
# 169) changing type for field ls_food_supply_purchasefeedorfodderonmarkets
# 170) changing type for field ls_food_supply_other
# 171) changing type for field ls_food_supply_dk
# 172) changing type for field ls_food_supply_ref
# 173) changing type for field ls_proddif
# 174) changing type for field ls_proddif_diffeedpurchase
# 175) changing type for field ls_proddif_constaccesstopasture
# 176) changing type for field ls_proddif_constaccesstowater
# 177) changing type for field ls_proddif_difaccessvetserv
# 178) changing type for field ls_proddif_difaccessvetinp
# 179) changing type for field ls_proddif_diseases
# 180) changing type for field ls_proddif_theftorinsecurity
# 181) changing type for field ls_proddif_pooraccesstolmarket
# 182) changing type for field ls_proddif_noaccesstocredit
# 183) changing type for field ls_proddif_lackoflabour
# 184) changing type for field ls_proddif_other
# 185) changing type for field ls_proddif_dk
# 186) changing type for field ls_proddif_ref
# 187) changing type for field ls_salesmain
# 188) changing type for field ls_salesdif
# 189) changing type for field ls_salesdif_smallerprofits
# 190) changing type for field ls_salesdif_damageandlosses
# 191) changing type for field ls_salesdif_lowdemand
# 192) changing type for field ls_salesdif_lowprices
# 193) changing type for field ls_salesdif_slaughterhouse
# 194) changing type for field ls_salesdif_processing
# 195) changing type for field ls_salesdif_other
# 196) changing type for field ls_salesdif_dk
# 197) changing type for field ls_salesdif_ref
# 198) changing type for field ls_salesprice
# 199) changing type for field ls_proc
# 200) changing type for field ls_proc_slaughter
# 201) changing type for field ls_proc_meatprocess
# 202) changing type for field ls_proc_dairyprocess
# 203) changing type for field ls_proc_leather
# 204) changing type for field ls_proc_other
# 205) changing type for field ls_proc_dk
# 206) changing type for field ls_proc_ref
# 207) changing type for field ls_proc_fac_priv_cold_transp
# 208) changing type for field ls_proc_fac_coop_cold_transp
# 209) changing type for field ls_proc_fac_slaughterinncomm
# 210) changing type for field ls_proc_fac_slaughteroutofcomm
# 211) changing type for field ls_proc_fac_farm_dairy
# 212) changing type for field ls_proc_fac_coop_dairy
# 213) changing type for field ls_proc_fac_other
# 214) changing type for field ls_proc_fac_none
# 215) changing type for field ls_proc_fac_dk
# 216) changing type for field ls_proc_fac_ref
# 217) changing type for field ls_proc_fac_state
# 218) changing type for field fish_main_coastal
# 219) changing type for field fish_main_opensea
# 220) changing type for field fish_main_lakespondsrivers
# 221) changing type for field fish_main_aquaculture
# 222) changing type for field fish_main_dk
# 223) changing type for field fish_main_ref
# 224) changing type for field fish_change
# 225) changing type for field fish_proddif
# 226) changing type for field fish_proddif_find
# 227) changing type for field fish_proddif_covid
# 228) changing type for field fish_proddif_fuel
# 229) changing type for field fish_proddif_inputs
# 230) changing type for field fish_proddif_labour
# 231) changing type for field fish_proddif_other
# 232) changing type for field fish_proddif_dk
# 233) changing type for field fish_proddif_ref
# 234) changing type for field fish_inputdif_bait
# 235) changing type for field fish_inputdif_net
# 236) changing type for field fish_inputdif_gear
# 237) changing type for field fish_inputdif_ice
# 238) changing type for field fish_inputdif_fuel
# 239) changing type for field fish_inputdif_boatrepairs
# 240) changing type for field fish_inputdif_other
# 241) changing type for field fish_inputdif_dk
# 242) changing type for field fish_inputdif_ref
# 243) changing type for field fish_salesmain
# 244) changing type for field fish_salesmain_other
# 245) changing type for field fish_salesdif_1
# 246) changing type for field fish_saledif_smallerprofits
# 247) changing type for field fish_saledif_damageandlosses
# 248) changing type for field fish_saledif_lowdemand
# 249) changing type for field fish_saledif_lowprices
# 250) changing type for field fish_saledif_processing
# 251) changing type for field fish_saledif_other
# 252) changing type for field fish_saledif_dk
# 253) changing type for field fish_saledif_ref
# 254) changing type for field fish_salesprice
# 255) changing type for field fies_worried
# 256) changing type for field fies_healthy
# 257) changing type for field fies_fewfoods
# 258) changing type for field fies_skipped
# 259) changing type for field fies_ateless
# 260) changing type for field fies_ranout
# 261) changing type for field fies_ranout_hhs
# 262) changing type for field fies_hungry
# 263) changing type for field fies_hungry_hhs
# 264) changing type for field fies_whlday
# 265) changing type for field fies_whlday_hhs
# 266) changing type for field cs_stress_hh_assets
# 267) changing type for field cs_stress_spent_savings
# 268) changing type for field cs_stress_sold_more_animals
# 269) changing type for field cs_stress_eat_elsewhere
# 270) changing type for field cs_stress_borrowed_or_helped
# 271) changing type for field cs_stress_credit
# 272) changing type for field cs_stress_borrowed_money
# 273) changing type for field cs_stress_changed_school
# 274) changing type for field cs_crisis_sold_productive_asset
# 275) changing type for field cs_crisis_no_school
# 276) changing type for field cs_crisis_reduced_health_exp
# 277) changing type for field cs_crisis_harv_immature_crops
# 278) changing type for field cs_crisis_consumed_seed_stocks
# 279) changing type for field cs_crisis_decr_agric_input_exp
# 280) changing type for field cs_emergency_sold_house
# 281) changing type for field cs_emergency_begged
# 282) changing type for field cs_emergency_illegal
# 283) changing type for field cs_emergency_sold_last_female
# 284) changing type for field cs_emergency_hh_migration
# 285) changing type for field hdds_cereals
# 286) changing type for field hdds_rootstubers
# 287) changing type for field hdds_vegetables
# 288) changing type for field hdds_fruits
# 289) changing type for field hdds_meat
# 290) changing type for field hdds_eggs
# 291) changing type for field hdds_fish
# 292) changing type for field hdds_legumes
# 293) changing type for field hdds_milkdairy
# 294) changing type for field hdds_oils
# 295) changing type for field hdds_sugar
# 296) changing type for field hdds_condiments
# 297) changing type for field need
# 298) changing type for field need_seeds
# 299) changing type for field need_fertilizers
# 300) changing type for field need_pesticides
# 301) changing type for field need_tools
# 302) changing type for field need_accesstoirrigationwater
# 303) changing type for field need_accesstoland
# 304) changing type for field need_animalfeed
# 305) changing type for field need_veterinaryservices
# 306) changing type for field need_veterinaryinputs
# 307) changing type for field need_animalsalemingarantdprice
# 308) changing type for field need_restockinganimals
# 309) changing type for field need_supportforprocessprod
# 310) changing type for field need_supptransofanimalsorprod
# 311) changing type for field need_acstomechanisedequipprod
# 312) changing type for field need_marketingsupport
# 313) changing type for field need_cashassistance
# 314) changing type for field need_loans
# 315) changing type for field need_storageequipmentorfaci
# 316) changing type for field need_techsupporextensionserv
# 317) changing type for field need_landrehabilitation
# 318) changing type for field need_fishequiorothersuppforfish
# 319) changing type for field need_infoonsafetymeasures
# 320) changing type for field need_other
# 321) changing type for field need_dk
# 322) changing type for field need_ref
# 323) changing type for field need_received_food
# 324) changing type for field need_received_cashvouchers
# 325) changing type for field need_received_seeds
# 326) changing type for field need_received_extensionservices
# 327) changing type for field need_received_livestockfeed
# 328) changing type for field need_received_other
# 329) changing type for field need_received_noassistreceived
# 330) changing type for field need_received_dk
# 331) changing type for field need_received_ref
# 332) changing type for field callback
# 333) changing type for field language2

# %%
def create_and_apply_domain(master_table, domain_table, field_name, domain_already_exists):
    # Process: Create the coded value domain
    domName = '%s_dom' % domain_table
    if not domain_already_exists:
        if domain_table == 'crp_main':
            field_type = "TEXT"
        else:
            field_type = "SHORT"
        try:
            arcpy.CreateDomain_management(output_gdb, domName, field_type= field_type)
        except:
            print('domain exists')
        # Store all the domain values in a dictionary with the domain code as the "key" 
        # and the domain description as the "value" (domDict[code])

        domDict = make_attribute_dict(domain_table, 'code', 'label')
        print(domDict)

        #   dict example:  {"CI":"Cast iron", "DI": "Ductile iron", "PVC": "PVC", 
        #                "ACP": "Asbestos concrete", "COP": "Copper"}

        # Process: Add valid material types to the domain
        # use a for loop to cycle through all the domain codes in the dictionary
        for code in domDict:
            try:
                arcpy.AddCodedValueToDomain_management(output_gdb, domName, code, domDict[code])
            except:
                print("AddCodedValueToDomain_management failed")


    arcpy.AssignDomainToField_management(master_table, field_name, domName)

# %%
##THis section of the script searches for all domains tables in the GDB
##then, for each table  it creates a new domain,
###it stores all domain values in a dictionary, it add each code domain, and finally assign the domain to the right field (having same name)

# Set the current workspace
arcpy.env.workspace = output_gdb

# Get and print a list of tables
tables = arcpy.ListTables()
master_table = os.path.join(output_gdb,'hh_master_table')

print("---APPLYING DOMAINS FOR SINGLE CHOICE FIELDS---")
counter = 0
for table in tables:
    if 'master_table' not in table and table not in useless_fields and  'derived_fields' not in table:
        #print(table)
        if table == "yes_no":
            yes_no_table_for_later = table ##we dont have a yes_no field to which apply the domain
        else:
            counter += 1
            print ("%s) Creating and Applying (new) domain for field %s" % (counter, table))
            create_and_apply_domain(master_table, table, table, False) #domain_table has the same name of the field where it should be applied
# Out:
# ---APPLYING DOMAINS FOR SINGLE CHOICE FIELDS---
# 1) Creating and Applying (new) domain for field resp_language
# {1: 'English', 2: 'Other options (add as many as necessary)'}
# 2) Creating and Applying (new) domain for field resp_agree
# {1: 'Yes', 2: 'Not now but another time in the week', 3: 'No'}
# 3) Creating and Applying (new) domain for field resp_gender
# {1: 'Male', 2: 'Female', 3: "Don't know", 4: 'Refused'}
# 4) Creating and Applying (new) domain for field hh_agricactivity
# {1: 'Yes - crop production', 2: 'Yes - livestock production', 3: 'Yes - both crop and livestock production', 4: 'No', 5: "Don't know", 6: 'Refused'}
# 5) Creating and Applying (new) domain for field hh_gender
# {1: 'Male', 2: 'Female', 3: "Don't know", 4: 'Refused'}
# 6) Creating and Applying (new) domain for field hh_education
# {1: 'None or did not complete primary school', 2: 'Completed primary school', 3: 'Completed secondary school', 4: 'Completed higher education (university, college) degree', 5: 'Islamic or other religious education', 6: "Don't know", 7: 'Refused'}
# 7) Creating and Applying (new) domain for field hh_wealth_toilet
# {1: 'Flush latrine (toilet with water)', 2: 'Traditional pit latrine (no water)', 3: 'Open pit (whole in the ground for excrement without water, roof or wall)', 4: 'Communal latrine (with or without water)', 5: 'None – bush', 6: "Don't know", 7: 'Refused'}
# 8) Creating and Applying (new) domain for field hh_wealth_light
# {1: 'Electricity (from generator or electrical grid)', 2: 'Candle', 3: 'Petrol lamp', 4: 'Lamp with batteries', 5: 'Other (no electric supply to the house)', 6: "Don't know", 7: 'Refused'}
# 9) Creating and Applying (new) domain for field hh_residencetype
# {1: 'Permanent resident - you have been living in your village, town for longer than two years and this is what you consider your habitual residence', 2: 'Recent migrant not forcefully displaced - you have been living in your current place of residence for less than two years and you moved there voluntarily for work, family or other reasons that are not related to conflict or natural disaster', 3: 'Returnee - you have only come back to this residence in the last two years after having been forced to move to another location having fled conflict or natural disaster (if return was over 2 years ago the respondent is considered a permanent resident)', 4: 'Internally displaced person (IDP) - you were forced to flee your village or town because of conflict or natural disaster and you are now an internally displaced person in your current place of residence', 5: 'Refugee - you were forced to flee your country because of conflict or natural disaster and you are now a refugee in your current place of residence', 6: "Don't know", 7: 'Refused'}
# 10) Creating and Applying (new) domain for field hh_maritalstat
# {1: 'Single, never married', 2: 'Married', 3: 'Separated', 4: 'Divorced', 5: 'Widowed', 6: 'Don’t know', 7: 'Refused'}
# 11) Creating and Applying (new) domain for field hh_age
# {1: 'Under 18', 2: '18 to 40', 3: '41 to 65', 4: 'Over 65', 5: "Don't know", 6: 'Refused'}
# 12) Creating and Applying (new) domain for field income_main
# {1: 'Farmer, production and sale of staple crops', 2: 'Farmer, production and sale of vegetable or fruit', 3: 'Farmer, production and sale of cashcrops', 4: 'Farmer, production and sale of livestock and livestock products', 5: 'Farmer, production and sale of fish', 6: 'Collection and sale of forestry or bush products', 7: 'Informal agricultural trade excluding producers', 8: 'Formal agricultural trade excluding producers', 9: 'Daily wage on farms and other casual employment in agricultural sector', 10: 'Stable employment in agricultural sector', 11: 'Non-agricultural self-employed or liberal profession, doctor, architect, lawyer, including restaurant', 12: 'Off-farm daily wages and other non-agricultural casual employment', 13: 'Stable employment in non-agricultural sector', 14: 'Public employment', 15: 'Income not derived from work, charity', 16: 'Income not derived from work, welfare transfer, pension, humanitarian aid', 17: 'Income not derived from work, remittances', 18: 'Income not derived from work, income from other rents', 19: 'No income source in the last 3 months and used exclusively savings', 20: 'No income source in the last 3 months and used exclusively debt', 21: 'Refused'}
# 13) Creating and Applying (new) domain for field income_main_comp
# {1: 'A lot more (increased by more than 50%)', 2: 'More', 3: 'Same', 4: 'Less', 5: 'A lot less (less than half as much)', 6: "Don't know", 7: 'Refused'}
# 14) Creating and Applying (new) domain for field income_sec
# {1: 'Farmer, production and sale of staple crops', 2: 'Farmer, production and sale of vegetable or fruit', 3: 'Farmer, production and sale of cashcrops', 4: 'Farmer, production and sale of livestock and livestock products', 5: 'Farmer, production and sale of fish', 6: 'Collection and sale of forestry or bush products', 7: 'Informal agricultural trade excluding producers', 8: 'Formal agricultural trade excluding producers', 9: 'Daily wage on farms and other casual employment in agricultural sector', 10: 'Stable employment in agricultural sector', 11: 'Non-agricultural self-employed or liberal profession, doctor, architect, lawyer, including restaurant', 12: 'Off-farm daily wages and other non-agricultural casual employment', 13: 'Stable employment in non-agricultural sector', 14: 'Public employment', 15: 'Income not derived from work, charity', 16: 'Income not derived from work, welfare transfer, pension, humanitarian aid', 17: 'Income not derived from work, remittances', 18: 'Income not derived from work, income from other rents', 19: 'No second most important source of income', 20: "Don't know", 21: 'Refused'}
# 15) Creating and Applying (new) domain for field income_sec_comp
# {1: 'A lot more (increased by more than 50%)', 2: 'More', 3: 'Same', 4: 'Less', 5: 'A lot less (less than half as much)', 6: "Don't know", 7: 'Refused'}
# 16) Creating and Applying (new) domain for field income_third
# {1: 'Farmer, production and sale of staple crops', 2: 'Farmer, production and sale of vegetable or fruit', 3: 'Farmer, production and sale of cashcrops', 4: 'Farmer, production and sale of livestock and livestock products', 5: 'Farmer, production and sale of fish', 6: 'Collection and sale of forestry or bush products', 7: 'Informal agricultural trade excluding producers', 8: 'Formal agricultural trade excluding producers', 9: 'Daily wage on farms and other casual employment in agricultural sector', 10: 'Stable employment in agricultural sector', 11: 'Non-agricultural self-employed or liberal profession, doctor, architect, lawyer, including restaurant', 12: 'Off-farm daily wages and other non-agricultural casual employment', 13: 'Stable employment in non-agricultural sector', 14: 'Public employment', 15: 'Income not derived from work, charity', 16: 'Income not derived from work, welfare transfer, pension, humanitarian aid', 17: 'Income not derived from work, remittances', 18: 'Income not derived from work, income from other rents', 19: 'No third most important source of income', 20: "Don't know", 21: 'Refused'}
# 17) Creating and Applying (new) domain for field income_third_comp
# {1: 'A lot more (increased by more than 50%)', 2: 'More', 3: 'Same', 4: 'Less', 5: 'A lot less (less than half as much)', 6: "Don't know", 7: 'Refused'}
# 18) Creating and Applying (new) domain for field crp_main
# {'1,1': 'Rice', '1,2': 'Wheat', '1,3': 'Millet', '1,4': 'Sorghum', '1,5': 'Maize', '1,6': 'Barley', '1,99': 'Other cereal', '2,1': 'Cassava', '2,2': 'Potatoe', '2,3': 'Sweet potatoes', '2,4': 'Yams', '2,5': 'Carrots', '2,6': 'Cocoyam', '2,99': 'Other tubers', '3,1': 'Beans', '3,2': 'Lentils', '3,3': 'Peas', '3,4': 'Soybeans', '3,99': 'Other pulses', '4,1': 'Cabbage', '4,2': 'Lettuce', '4,3': 'Spinach-amaranth', '4,4': 'Cassava leaves', '4,5': 'Potatoe leaves', '4,6': 'Moringa', '4,7': 'Sorrel hibiscus', '4,8': 'Rosselle', '4,99': 'Other leafy vegetables', '5,1': 'Tomatoes', '5,2': 'Cucumber', '5,3': 'Pumpkin', '5,4': 'Eggplant/aubergine', '5,5': 'Zucchini', '5,6': 'Okra', '5,7': 'Pepper', '5,8': 'Onions', '5,99': 'Other non leafy vegs', '6,1': 'Orange', '6,2': 'Lemon', '6,3': 'Grapefruit', '6,99': 'Other citrus fruit', '7,1': 'Sweet banana', '7,2': 'Plantains', '7,3': 'Papaya', '7,4': 'Mango', '7,5': 'Guava', '7,6': 'Pineapple', '7,7': 'Avocado', '7,8': 'Watermelon', '7,9': 'Dates', '7,10': 'Figs', '7,11': 'Grapes', '7,12': 'Olives', '7,99': 'Other fruit', '8,1': 'Coconuts', '8,2': 'Groundnut/peanut', '8,3': 'Cashew nut', '8,4': 'Kola nut', '8,5': 'Sesame', '8,6': 'Bambara nut', '8,99': 'Other nuts', '9,1': 'Cocoa', '9,2': 'Coffee', '9,3': 'Tea', '9,4': 'Sugarcane', '9,5': 'Sunflower', '9,99': 'Other food cash crop', '10,1': 'Cotton', '10,2': 'Rubber', '10,3': 'Jute', '10,4': 'Fodder', '10,99': 'Other non-food cash crop', '777': 'No crop production', '888': "Don't know", '999': 'Refused'}
# 19) Creating and Applying (new) domain for field crp_landsize
# {1: 'Less than 1 ha', 2: '1 to 5 ha', 3: '5 to 10 ha', 4: 'More than 10 ha', 5: 'Don’t know', 6: 'Refused'}
# 20) Creating and Applying (new) domain for field crp_landright
# {1: 'Inherited', 2: 'Right given by community leader', 3: 'Cleared from bush or forest', 4: 'Purchased', 5: 'Received from state', 6: 'Sharecrop', 7: 'Rental', 8: 'Other ', 9: "Don't know", 10: 'Refused'}
# 21) Creating and Applying (new) domain for field crp_irrigation
# {1: 'Rainfed', 2: 'Canal', 3: 'Pump or mechanized', 4: 'Manually from water surface, well or other water source', 5: 'Flood irrigation', 6: 'Other ', 7: "Don't know", 8: 'Refused'}
# 22) Creating and Applying (new) domain for field crp_area_change
# {1: 'A lot more (increased by more than 50%)', 2: 'More', 3: 'Same', 4: 'Less', 5: 'A lot less (less than half as much)', 6: "Don't know", 7: 'Refused'}
# 23) Creating and Applying (new) domain for field crp_harv_change
# {1: 'A lot more (increased by more than 50%)', 2: 'More', 3: 'Same', 4: 'Less', 5: 'A lot less (less than half as much)', 6: "Don't know", 7: 'Refused'}
# 24) Creating and Applying (new) domain for field crp_proddif
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# 25) Creating and Applying (new) domain for field crp_salesdif
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# 26) Creating and Applying (new) domain for field crp_salesprice
# {1: 'A lot more (increased by more than 50%)', 2: 'More', 3: 'Same', 4: 'Less', 5: 'A lot less (less than half as much)', 6: "Don't know", 7: 'Refused'}
# 27) Creating and Applying (new) domain for field crp_proc
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# 28) Creating and Applying (new) domain for field crp_proc_state
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# 29) Creating and Applying (new) domain for field ls_main
# {1: 'Cattle (cow, beef, veal, yak, buffalo)', 2: 'Goats', 3: 'Sheeps', 4: 'Swine', 5: 'Equine (donkey, horse, etc)', 6: 'Small domesticated mammals (rabbits, minks, guinea pigs, etc)', 7: 'Poultry (chicken, guineafowl, duck, etc)', 8: 'Camelids', 9: 'Other ', 10: "Don't know", 11: 'Refused'}
# 30) Creating and Applying (new) domain for field ls_proddif
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# 31) Creating and Applying (new) domain for field ls_salesmain
# {1: 'Cattle (cow, beef, veal, yak, buffalo)', 2: 'Goats', 3: 'Sheeps', 4: 'Swine', 5: 'Equine (donkey, horse, etc.)', 6: 'Small domesticated mammals (rabbits, minks, guinea pigs, etc)', 7: 'Poultry (chicken, guineafowl, duck, etc.)', 8: 'Camelids', 9: 'Eggs', 10: 'Milk or dairy products', 11: 'Skin or leather', 12: "Don't know", 13: 'Refused'}
# 32) Creating and Applying (new) domain for field ls_salesdif
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# 33) Creating and Applying (new) domain for field ls_salesprice
# {1: 'A lot more (increased by more than 50%)', 2: 'More', 3: 'Same', 4: 'Less', 5: 'A lot less (less than half as much)', 6: "Don't know", 7: 'Refused'}
# 34) Creating and Applying (new) domain for field ls_proc
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# 35) Creating and Applying (new) domain for field ls_proc_fac_state
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# 36) Creating and Applying (new) domain for field fish_change
# {1: 'A lot more (increased by more than 50%)', 2: 'More', 3: 'Same', 4: 'Less', 5: 'A lot less (less than half as much)', 6: "Don't know", 7: 'Refused'}
# 37) Creating and Applying (new) domain for field fish_proddif
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# 38) Creating and Applying (new) domain for field fish_salesmain
# {1: 'Fresh fish (any kind)', 2: 'Dry fish (any kind)', 3: 'Smoked fish', 4: 'Seafood (any kind)', 5: 'Other ', 6: "Don't know", 7: 'Refused'}
# 39) Creating and Applying (new) domain for field fish_salesdif_1
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# 40) Creating and Applying (new) domain for field fish_salesprice
# {1: 'A lot more (increased by more than 50%)', 2: 'More', 3: 'Same', 4: 'Less', 5: 'A lot less (less than half as much)', 6: "Don't know", 7: 'Refused'}
# 41) Creating and Applying (new) domain for field fies_worried
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# 42) Creating and Applying (new) domain for field fies_healthy
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# 43) Creating and Applying (new) domain for field fies_fewfoods
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# 44) Creating and Applying (new) domain for field fies_skipped
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# 45) Creating and Applying (new) domain for field fies_ateless
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# 46) Creating and Applying (new) domain for field fies_ranout
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# 47) Creating and Applying (new) domain for field fies_ranout_hhs
# {1: 'Rarely (once or twice)', 2: 'Sometimes (in some weeks but not every week)', 3: 'Often (every week)', 4: "Don't know", 5: 'Refused'}
# 48) Creating and Applying (new) domain for field fies_hungry
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# 49) Creating and Applying (new) domain for field fies_hungry_hhs
# {1: 'Rarely (once or twice)', 2: 'Sometimes (in some weeks but not every week)', 3: 'Often (every week)', 4: "Don't know", 5: 'Refused'}
# 50) Creating and Applying (new) domain for field fies_whlday
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# 51) Creating and Applying (new) domain for field fies_whlday_hhs
# {1: 'Rarely (once or twice)', 2: 'Sometimes (in some weeks but not every week)', 3: 'Often (every week)', 4: "Don't know", 5: 'Refused'}
# 52) Creating and Applying (new) domain for field cs_stress_hh_assets
# {1: 'Yes', 2: 'No - because it wasn’t necessary', 3: 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it', 4: 'Not applicable', 5: "Don't know", 6: 'Refused'}
# 53) Creating and Applying (new) domain for field cs_stress_spent_savings
# {1: 'Yes', 2: 'No - because it wasn’t necessary', 3: 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it', 4: 'Not applicable', 5: "Don't know", 6: 'Refused'}
# 54) Creating and Applying (new) domain for field cs_stress_sold_more_animals
# {1: 'Yes', 2: 'No - because it wasn’t necessary', 3: 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it', 4: 'Not applicable', 5: "Don't know", 6: 'Refused'}
# 55) Creating and Applying (new) domain for field cs_stress_eat_elsewhere
# {1: 'Yes', 2: 'No - because it wasn’t necessary', 3: 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it', 4: 'Not applicable', 5: "Don't know", 6: 'Refused'}
# 56) Creating and Applying (new) domain for field cs_stress_borrowed_or_helped
# {1: 'Yes', 2: 'No - because it wasn’t necessary', 3: 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it', 4: 'Not applicable', 5: "Don't know", 6: 'Refused'}
# 57) Creating and Applying (new) domain for field cs_stress_credit
# {1: 'Yes', 2: 'No - because it wasn’t necessary', 3: 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it', 4: 'Not applicable', 5: "Don't know", 6: 'Refused'}
# 58) Creating and Applying (new) domain for field cs_stress_borrowed_money
# {1: 'Yes', 2: 'No - because it wasn’t necessary', 3: 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it', 4: 'Not applicable', 5: "Don't know", 6: 'Refused'}
# 59) Creating and Applying (new) domain for field cs_stress_changed_school
# {1: 'Yes', 2: 'No - because it wasn’t necessary', 3: 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it', 4: 'Not applicable', 5: "Don't know", 6: 'Refused'}
# 60) Creating and Applying (new) domain for field cs_crisis_sold_productive_asset
# {1: 'Yes', 2: 'No - because it wasn’t necessary', 3: 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it', 4: 'Not applicable', 5: "Don't know", 6: 'Refused'}
# 61) Creating and Applying (new) domain for field cs_crisis_no_school
# {1: 'Yes', 2: 'No - because it wasn’t necessary', 3: 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it', 4: 'Not applicable', 5: "Don't know", 6: 'Refused'}
# 62) Creating and Applying (new) domain for field cs_crisis_reduced_health_exp
# {1: 'Yes', 2: 'No - because it wasn’t necessary', 3: 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it', 4: 'Not applicable', 5: "Don't know", 6: 'Refused'}
# 63) Creating and Applying (new) domain for field cs_crisis_harv_immature_crops
# {1: 'Yes', 2: 'No - because it wasn’t necessary', 3: 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it', 4: 'Not applicable', 5: "Don't know", 6: 'Refused'}
# 64) Creating and Applying (new) domain for field cs_crisis_consumed_seed_stocks
# {1: 'Yes', 2: 'No - because it wasn’t necessary', 3: 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it', 4: 'Not applicable', 5: "Don't know", 6: 'Refused'}
# 65) Creating and Applying (new) domain for field cs_crisis_decr_agric_input_exp
# {1: 'Yes', 2: 'No - because it wasn’t necessary', 3: 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it', 4: 'Not applicable', 5: "Don't know", 6: 'Refused'}
# 66) Creating and Applying (new) domain for field cs_emergency_sold_house
# {1: 'Yes', 2: 'No - because it wasn’t necessary', 3: 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it', 4: 'Not applicable', 5: "Don't know", 6: 'Refused'}
# 67) Creating and Applying (new) domain for field cs_emergency_begged
# {1: 'Yes', 2: 'No - because it wasn’t necessary', 3: 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it', 4: 'Not applicable', 5: "Don't know", 6: 'Refused'}
# 68) Creating and Applying (new) domain for field cs_emergency_illegal
# {1: 'Yes', 2: 'No - because it wasn’t necessary', 3: 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it', 4: 'Not applicable', 5: "Don't know", 6: 'Refused'}
# 69) Creating and Applying (new) domain for field cs_emergency_sold_last_female
# {1: 'Yes', 2: 'No - because it wasn’t necessary', 3: 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it', 4: 'Not applicable', 5: "Don't know", 6: 'Refused'}
# 70) Creating and Applying (new) domain for field cs_emergency_hh_migration
# {1: 'Yes', 2: 'No - because it wasn’t necessary', 3: 'No - because you already sold those assets or did this activity within the last 12 months and you cannot continue to do it', 4: 'Not applicable', 5: "Don't know", 6: 'Refused'}
# 71) Creating and Applying (new) domain for field need
# {1: 'Yes', 2: 'No', 3: "Don't know", 4: 'Refused'}
# 72) Creating and Applying (new) domain for field callback
# {1: 'Yes', 2: 'No'}
# 73) Creating and Applying (new) domain for field language2
# {1: 'English', 2: 'Other languages (consistent with resp_language)'}

# %%
print("---APPLYING DOMAINS FOR MULTIPLE CHOICE DERIVED FIELDS---")
yes_no_domain_created = False
counter = 0
for derived_field in all_derived_fieldnames:
    if derived_field not in all_answers_with_other_option: #'other' fields, are strings without domains
        counter +=1
        if not yes_no_domain_created:
            print ("%s) Creating and applying new YES-NO domain (table %s) for derivate field %s" % (counter, yes_no_table_for_later,derived_field))
            create_and_apply_domain(master_table, yes_no_table_for_later, derived_field, False)
            yes_no_domain_created = True
        else:
            print ("%s) Applying existing YES-NO domain for derivate field %s" % (counter,derived_field))
            create_and_apply_domain(master_table, yes_no_table_for_later, derived_field, True)
# Out:
# ---APPLYING DOMAINS FOR MULTIPLE CHOICE DERIVED FIELDS---
# 1) Creating and applying new YES-NO domain (table yes_no) for derivate field hh_wealth_water_pvttap
# {1: 'Yes', 0: 'No'}
# 2) Applying existing YES-NO domain for derivate field hh_wealth_water_publictap
# 3) Applying existing YES-NO domain for derivate field hh_wealth_water_protectwell
# 4) Applying existing YES-NO domain for derivate field hh_wealth_water_bottle
# 5) Applying existing YES-NO domain for derivate field hh_wealth_water_othersafe
# 6) Applying existing YES-NO domain for derivate field hh_wealth_water_river
# 7) Applying existing YES-NO domain for derivate field hh_wealth_water_unprotectwell
# 8) Applying existing YES-NO domain for derivate field hh_wealth_water_spring
# 9) Applying existing YES-NO domain for derivate field hh_wealth_water_canalsurface
# 10) Applying existing YES-NO domain for derivate field hh_wealth_water_otherunsafe
# 11) Applying existing YES-NO domain for derivate field hh_wealth_water_dk
# 12) Applying existing YES-NO domain for derivate field hh_wealth_water_ref
# 13) Applying existing YES-NO domain for derivate field covid_goodstransp
# 14) Applying existing YES-NO domain for derivate field covid_marketclosed
# 15) Applying existing YES-NO domain for derivate field covid_borderclosed
# 16) Applying existing YES-NO domain for derivate field covid_stayhome
# 17) Applying existing YES-NO domain for derivate field covid_gatherings
# 18) Applying existing YES-NO domain for derivate field covid_processclosed
# 19) Applying existing YES-NO domain for derivate field covid_none
# 20) Applying existing YES-NO domain for derivate field covid_dk
# 21) Applying existing YES-NO domain for derivate field covid_ref
# 22) Applying existing YES-NO domain for derivate field shock_noshock
# 23) Applying existing YES-NO domain for derivate field shock_sicknessordeathofhh
# 24) Applying existing YES-NO domain for derivate field shock_lostemplorwork
# 25) Applying existing YES-NO domain for derivate field shock_otherintrahhshock
# 26) Applying existing YES-NO domain for derivate field shock_higherfoodprices
# 27) Applying existing YES-NO domain for derivate field shock_higherfuelprices
# 28) Applying existing YES-NO domain for derivate field shock_cantworkordobusiness
# 29) Applying existing YES-NO domain for derivate field shock_othereconomicshock
# 30) Applying existing YES-NO domain for derivate field shock_pestoutbreak
# 31) Applying existing YES-NO domain for derivate field shock_plantdisease
# 32) Applying existing YES-NO domain for derivate field shock_animaldisease
# 33) Applying existing YES-NO domain for derivate field shock_napasture
# 34) Applying existing YES-NO domain for derivate field shock_othercropandlivests
# 35) Applying existing YES-NO domain for derivate field shock_coldtemporhail
# 36) Applying existing YES-NO domain for derivate field shock_flood
# 37) Applying existing YES-NO domain for derivate field shock_hurricane
# 38) Applying existing YES-NO domain for derivate field shock_drought
# 39) Applying existing YES-NO domain for derivate field shock_earthquake
# 40) Applying existing YES-NO domain for derivate field shock_landslides
# 41) Applying existing YES-NO domain for derivate field shock_firenatural
# 42) Applying existing YES-NO domain for derivate field shock_othernathazard
# 43) Applying existing YES-NO domain for derivate field shock_violenceinsecconf
# 44) Applying existing YES-NO domain for derivate field shock_theftofprodassets
# 45) Applying existing YES-NO domain for derivate field shock_fire
# 46) Applying existing YES-NO domain for derivate field shock_othermanmadehazard
# 47) Applying existing YES-NO domain for derivate field shock_dk
# 48) Applying existing YES-NO domain for derivate field shock_ref
# 49) Applying existing YES-NO domain for derivate field crp_seed_ownprod
# 50) Applying existing YES-NO domain for derivate field crp_seed_market
# 51) Applying existing YES-NO domain for derivate field crp_seed_company
# 52) Applying existing YES-NO domain for derivate field crp_seed_freedist
# 53) Applying existing YES-NO domain for derivate field crp_seed_bank
# 54) Applying existing YES-NO domain for derivate field crp_seed_gov
# 55) Applying existing YES-NO domain for derivate field crp_seed_dk
# 56) Applying existing YES-NO domain for derivate field crp_seed_ref
# 57) Applying existing YES-NO domain for derivate field crp_proddif_plantdisease
# 58) Applying existing YES-NO domain for derivate field crp_proddif_seedquality
# 59) Applying existing YES-NO domain for derivate field crp_proddif_lostordamaged
# 60) Applying existing YES-NO domain for derivate field crp_proddif_naplot
# 61) Applying existing YES-NO domain for derivate field crp_proddif_nafertilizer
# 62) Applying existing YES-NO domain for derivate field crp_proddif_naseeds
# 63) Applying existing YES-NO domain for derivate field crp_proddif_nainsecticides
# 64) Applying existing YES-NO domain for derivate field crp_proddif_nalabour
# 65) Applying existing YES-NO domain for derivate field crp_proddif_namachinery
# 66) Applying existing YES-NO domain for derivate field crp_proddif_nafuelorelect
# 67) Applying existing YES-NO domain for derivate field crp_proddif_soilerosion
# 68) Applying existing YES-NO domain for derivate field crp_proddif_irrigation
# 69) Applying existing YES-NO domain for derivate field crp_proddif_dk
# 70) Applying existing YES-NO domain for derivate field crp_proddif_ref
# 71) Applying existing YES-NO domain for derivate field crp_saledif_marketing_cost
# 72) Applying existing YES-NO domain for derivate field crp_saledif_damagelosses
# 73) Applying existing YES-NO domain for derivate field crp_saledif_lowdemand
# 74) Applying existing YES-NO domain for derivate field crp_saledif_lowprice
# 75) Applying existing YES-NO domain for derivate field crp_saledif_dif_processing
# 76) Applying existing YES-NO domain for derivate field crp_saledif_dk
# 77) Applying existing YES-NO domain for derivate field crp_saledif_ref
# 78) Applying existing YES-NO domain for derivate field crp_proc_mach_mill
# 79) Applying existing YES-NO domain for derivate field crp_proc_mach_thresher
# 80) Applying existing YES-NO domain for derivate field crp_proc_mach_dryingfacilit
# 81) Applying existing YES-NO domain for derivate field crp_proc_mach_none
# 82) Applying existing YES-NO domain for derivate field crp_proc_mach_dk
# 83) Applying existing YES-NO domain for derivate field crp_proc_mach_ref
# 84) Applying existing YES-NO domain for derivate field crp_proc_owner_yours
# 85) Applying existing YES-NO domain for derivate field crp_proc_owner_farmin
# 86) Applying existing YES-NO domain for derivate field crp_proc_owner_farmout
# 87) Applying existing YES-NO domain for derivate field crp_proc_owner_millin
# 88) Applying existing YES-NO domain for derivate field crp_proc_owner_millout
# 89) Applying existing YES-NO domain for derivate field crp_proc_owner_dk
# 90) Applying existing YES-NO domain for derivate field crp_proc_owner_ref
# 91) Applying existing YES-NO domain for derivate field ls_num_nochange
# 92) Applying existing YES-NO domain for derivate field ls_num_inc_didnotsellasmany
# 93) Applying existing YES-NO domain for derivate field ls_num_inc_moreborn
# 94) Applying existing YES-NO domain for derivate field ls_num_inc_purchbarterdmore
# 95) Applying existing YES-NO domain for derivate field ls_num_inc_receivedfree
# 96) Applying existing YES-NO domain for derivate field ls_num_dec_animalsdied
# 97) Applying existing YES-NO domain for derivate field ls_num_dec_soldmoregoodprice
# 98) Applying existing YES-NO domain for derivate field ls_num_dec_soldmoredistsale
# 99) Applying existing YES-NO domain for derivate field ls_num_dec_anmlescloststolen
# 100) Applying existing YES-NO domain for derivate field ls_num_dec_killedorgaveanml
# 101) Applying existing YES-NO domain for derivate field ls_num_inc_dec_dk
# 102) Applying existing YES-NO domain for derivate field ls_num_inc_dec_ref
# 103) Applying existing YES-NO domain for derivate field ls_food_supply_openpasture
# 104) Applying existing YES-NO domain for derivate field ls_food_supply_commngpastureland
# 105) Applying existing YES-NO domain for derivate field ls_food_supply_fieldselfprodfod
# 106) Applying existing YES-NO domain for derivate field ls_food_supply_purchasefeedorfodderonmarkets
# 107) Applying existing YES-NO domain for derivate field ls_food_supply_dk
# 108) Applying existing YES-NO domain for derivate field ls_food_supply_ref
# 109) Applying existing YES-NO domain for derivate field ls_proddif_diffeedpurchase
# 110) Applying existing YES-NO domain for derivate field ls_proddif_constaccesstopasture
# 111) Applying existing YES-NO domain for derivate field ls_proddif_constaccesstowater
# 112) Applying existing YES-NO domain for derivate field ls_proddif_difaccessvetserv
# 113) Applying existing YES-NO domain for derivate field ls_proddif_difaccessvetinp
# 114) Applying existing YES-NO domain for derivate field ls_proddif_diseases
# 115) Applying existing YES-NO domain for derivate field ls_proddif_theftorinsecurity
# 116) Applying existing YES-NO domain for derivate field ls_proddif_pooraccesstolmarket
# 117) Applying existing YES-NO domain for derivate field ls_proddif_noaccesstocredit
# 118) Applying existing YES-NO domain for derivate field ls_proddif_lackoflabour
# 119) Applying existing YES-NO domain for derivate field ls_proddif_dk
# 120) Applying existing YES-NO domain for derivate field ls_proddif_ref
# 121) Applying existing YES-NO domain for derivate field ls_salesdif_smallerprofits
# 122) Applying existing YES-NO domain for derivate field ls_salesdif_damageandlosses
# 123) Applying existing YES-NO domain for derivate field ls_salesdif_lowdemand
# 124) Applying existing YES-NO domain for derivate field ls_salesdif_lowprices
# 125) Applying existing YES-NO domain for derivate field ls_salesdif_slaughterhouse
# 126) Applying existing YES-NO domain for derivate field ls_salesdif_processing
# 127) Applying existing YES-NO domain for derivate field ls_salesdif_dk
# 128) Applying existing YES-NO domain for derivate field ls_salesdif_ref
# 129) Applying existing YES-NO domain for derivate field ls_proc_slaughter
# 130) Applying existing YES-NO domain for derivate field ls_proc_meatprocess
# 131) Applying existing YES-NO domain for derivate field ls_proc_dairyprocess
# 132) Applying existing YES-NO domain for derivate field ls_proc_leather
# 133) Applying existing YES-NO domain for derivate field ls_proc_dk
# 134) Applying existing YES-NO domain for derivate field ls_proc_ref
# 135) Applying existing YES-NO domain for derivate field ls_proc_fac_priv_cold_transp
# 136) Applying existing YES-NO domain for derivate field ls_proc_fac_coop_cold_transp
# 137) Applying existing YES-NO domain for derivate field ls_proc_fac_slaughterinncomm
# 138) Applying existing YES-NO domain for derivate field ls_proc_fac_slaughteroutofcomm
# 139) Applying existing YES-NO domain for derivate field ls_proc_fac_farm_dairy
# 140) Applying existing YES-NO domain for derivate field ls_proc_fac_coop_dairy
# 141) Applying existing YES-NO domain for derivate field ls_proc_fac_none
# 142) Applying existing YES-NO domain for derivate field ls_proc_fac_dk
# 143) Applying existing YES-NO domain for derivate field ls_proc_fac_ref
# 144) Applying existing YES-NO domain for derivate field fish_main_coastal
# 145) Applying existing YES-NO domain for derivate field fish_main_opensea
# 146) Applying existing YES-NO domain for derivate field fish_main_lakespondsrivers
# 147) Applying existing YES-NO domain for derivate field fish_main_aquaculture
# 148) Applying existing YES-NO domain for derivate field fish_main_dk
# 149) Applying existing YES-NO domain for derivate field fish_main_ref
# 150) Applying existing YES-NO domain for derivate field fish_proddif_find
# 151) Applying existing YES-NO domain for derivate field fish_proddif_covid
# 152) Applying existing YES-NO domain for derivate field fish_proddif_fuel
# 153) Applying existing YES-NO domain for derivate field fish_proddif_inputs
# 154) Applying existing YES-NO domain for derivate field fish_proddif_labour
# 155) Applying existing YES-NO domain for derivate field fish_proddif_dk
# 156) Applying existing YES-NO domain for derivate field fish_proddif_ref
# 157) Applying existing YES-NO domain for derivate field fish_inputdif_bait
# 158) Applying existing YES-NO domain for derivate field fish_inputdif_net
# 159) Applying existing YES-NO domain for derivate field fish_inputdif_gear
# 160) Applying existing YES-NO domain for derivate field fish_inputdif_ice
# 161) Applying existing YES-NO domain for derivate field fish_inputdif_fuel
# 162) Applying existing YES-NO domain for derivate field fish_inputdif_boatrepairs
# 163) Applying existing YES-NO domain for derivate field fish_inputdif_dk
# 164) Applying existing YES-NO domain for derivate field fish_inputdif_ref
# 165) Applying existing YES-NO domain for derivate field fish_saledif_smallerprofits
# 166) Applying existing YES-NO domain for derivate field fish_saledif_damageandlosses
# 167) Applying existing YES-NO domain for derivate field fish_saledif_lowdemand
# 168) Applying existing YES-NO domain for derivate field fish_saledif_lowprices
# 169) Applying existing YES-NO domain for derivate field fish_saledif_processing
# 170) Applying existing YES-NO domain for derivate field fish_saledif_dk
# 171) Applying existing YES-NO domain for derivate field fish_saledif_ref
# 172) Applying existing YES-NO domain for derivate field hdds_cereals
# 173) Applying existing YES-NO domain for derivate field hdds_rootstubers
# 174) Applying existing YES-NO domain for derivate field hdds_vegetables
# 175) Applying existing YES-NO domain for derivate field hdds_fruits
# 176) Applying existing YES-NO domain for derivate field hdds_meat
# 177) Applying existing YES-NO domain for derivate field hdds_eggs
# 178) Applying existing YES-NO domain for derivate field hdds_fish
# 179) Applying existing YES-NO domain for derivate field hdds_legumes
# 180) Applying existing YES-NO domain for derivate field hdds_milkdairy
# 181) Applying existing YES-NO domain for derivate field hdds_oils
# 182) Applying existing YES-NO domain for derivate field hdds_sugar
# 183) Applying existing YES-NO domain for derivate field hdds_condiments
# 184) Applying existing YES-NO domain for derivate field need_seeds
# 185) Applying existing YES-NO domain for derivate field need_fertilizers
# 186) Applying existing YES-NO domain for derivate field need_pesticides
# 187) Applying existing YES-NO domain for derivate field need_tools
# 188) Applying existing YES-NO domain for derivate field need_accesstoirrigationwater
# 189) Applying existing YES-NO domain for derivate field need_accesstoland
# 190) Applying existing YES-NO domain for derivate field need_animalfeed
# 191) Applying existing YES-NO domain for derivate field need_veterinaryservices
# 192) Applying existing YES-NO domain for derivate field need_veterinaryinputs
# 193) Applying existing YES-NO domain for derivate field need_animalsalemingarantdprice
# 194) Applying existing YES-NO domain for derivate field need_restockinganimals
# 195) Applying existing YES-NO domain for derivate field need_supportforprocessprod
# 196) Applying existing YES-NO domain for derivate field need_supptransofanimalsorprod
# 197) Applying existing YES-NO domain for derivate field need_acstomechanisedequipprod
# 198) Applying existing YES-NO domain for derivate field need_marketingsupport
# 199) Applying existing YES-NO domain for derivate field need_cashassistance
# 200) Applying existing YES-NO domain for derivate field need_loans
# 201) Applying existing YES-NO domain for derivate field need_storageequipmentorfaci
# 202) Applying existing YES-NO domain for derivate field need_techsupporextensionserv
# 203) Applying existing YES-NO domain for derivate field need_landrehabilitation
# 204) Applying existing YES-NO domain for derivate field need_fishequiorothersuppforfish
# 205) Applying existing YES-NO domain for derivate field need_infoonsafetymeasures
# 206) Applying existing YES-NO domain for derivate field need_dk
# 207) Applying existing YES-NO domain for derivate field need_ref
# 208) Applying existing YES-NO domain for derivate field need_received_food
# 209) Applying existing YES-NO domain for derivate field need_received_cashvouchers
# 210) Applying existing YES-NO domain for derivate field need_received_seeds
# 211) Applying existing YES-NO domain for derivate field need_received_extensionservices
# 212) Applying existing YES-NO domain for derivate field need_received_livestockfeed
# 213) Applying existing YES-NO domain for derivate field need_received_noassistreceived
# 214) Applying existing YES-NO domain for derivate field need_received_dk
# 215) Applying existing YES-NO domain for derivate field need_received_ref

# %%
print("Adding Global ID")
arcpy.AddGlobalIDs_management(master_table)
# Out:
# Adding Global ID
# <Result 'C:\\temp\\data_processing_exports\\fGDB_with_coded_values_20210609181129.gdb\\master_table'>

# %%
print("Execution time: ", datetime.now() - startTime)
# Out:
# Execution time:  0:40:03.774514

# %%
arcpy.management.AlterField(master_table, field, {new_field_name}, {new_field_alias}, {field_type}, {field_length}, {field_is_nullable}, {clear_field_alias})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# In  [76]:
# Line 1:     arcpy.management.AlterField(master_table, field, {new_field_name}, {new_field_alias}, {field_type}, {field_length}, {field_is_nullable}, {clear_field_alias})
#
# NameError: name 'new_field_name' is not defined
# ---------------------------------------------------------------------------
